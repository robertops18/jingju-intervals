# %% [markdown]
# # Jingju dataset intervals analysis

# %%
from music21 import *
import matplotlib.pyplot as plt

# %% [markdown]
# First we defined the classes that will be used in order to perform the analysis of the Jingju interval analysis based on the Jingju dataset provided by Rafael.
#
# We will used two different classes in order to parse the csv file containing all the scores:
#
#  - The first one will be the Jingju score. This class will have 6 attributes: the reference to the xml file, the opera type (xipi or erhuang), the rhythm used in the score, an array of lines (each element of the array will be a dictionary with the opening and finishing line of each part of the score), the voice and instrumental staffs, and the intervals present in the whole score.
#  - The line object will contain if it is an open or finish line, the character that performs the line, the lyrics and the boundary offsets of each line.

# %%
class Jingju:        
    def __init__(self, scoreXML = '', operaType = '', lines = [], voiceStaff = 0, instrumentalStaff = 0, intervals = {}):
        self.scoreXML = scoreXML
        self.operaType = operaType
        self.lines = lines
        self.voiceStaff = voiceStaff
        self.instrumentalStaff = instrumentalStaff
        self.intervals = intervals
    
    def __str__(self):
        return self.scoreXML

class Line:
    def __init__(self, isOpen = True, character = '', rhythm = '', lyrics = '', initOffset = '', finishOffset = ''):
        self.isOpen = isOpen
        self.character = character
        self.rhythm = rhythm
        self.lyrics  = lyrics
        self.initOffset = initOffset
        self.finishOffset = finishOffset
        
    def __str__(self):
        return self.lyrics

# %% [markdown]
# After the class definition, the lines_data.csv file has to be parsed in order to create all the objects needed to perform the analysis.
#
# In order to perform the analysis of the csv file, we wont't consider the jingjus containing two parts to ease the parsing of the file. Instead of using 92 scores, we will use 86 after deleting the specified ones.

# %%
# Method for printing the jingju list parsed from the csv file
def print_jingju_list(jingjuList):
    print('{} Jingju scores parsed'.format(len(jingjuList)))
    for j in jingjuList:
        print('Jingju {} containing {} lines'.format(j.scoreXML, len(j.lines)))
        print('Voice staff: {}'.format(j.voiceStaff))
        print('Instrumental staff: {}'.format(j.instrumentalStaff))
        print('Intervals: {}'.format(j.intervals))
        count = 1
        for l in j.lines:
            print('\tLine number {}'.format(count))
            print('\tOpen line: {}'.format(l['openLine']))
            if l['kLine'] != '':
                print('\tK line: {}'.format(l['kLine']))
            print('\tFinish line: {}'.format(l['finishLine']))
            print('\n')
            count += 1

# %%
import csv
path_folder = '../JingjuMusicScoresCollection/MusicXML/'

lines_data_path = path_folder + 'lines_data.csv'
jingjuList = [] # Array to store all Jingju objects created when parsing the csv file

count = 0

with open(lines_data_path, 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        if row[0] != '': # Start of a new Jingju
            # As we have come across a new Jingju, we need to store the previously created one.
            # However, we need to skip the first one because no jingju has been created
            if count != 0:
                jingju.lines = jingju_lines
                jingjuList.append(jingju)
            
            # Update the jingju object with a new one
            scoreXML = row[0]
            operaType = row[2]
            jingju = Jingju(scoreXML, operaType)
            jingju_lines = [] # Init the lines array of the Jingju
            
        # Check if there is a currentLine created
        currentLines_exists = 'currentLines' in locals() or 'currentLines' in globals()
        if not currentLines_exists or currentLines['finishLine'] != '':
            currentLines = {'openLine': '', 'finishLine': '', 'kLine': ''}
        
        # Create a new Line object
        line = Line()
        line.character = row[1]
        line.rhythm = row[3]
        
        lineType = row[4]
        line.isOpen = True if lineType.startswith('s') else False
        
        line.lyrics = row[5]
        line.initOffset = row[6]
        line.finishOffset = row[7]
        
        if line.isOpen:
            currentLines['openLine'] = line
        else:
            if lineType.startswith('k'):
                currentLines['kLine'] = line
            else:
                currentLines['finishLine'] = line
            
        # Check if there exists
        
        # If the currentLines are finished, we append it to the jingju lines
        if currentLines['finishLine'] != '':
            jingju_lines.append(currentLines)
            
        # Increment the row count
        count += 1
    
    # We need to store the last jingju
    jingju.lines = jingju_lines
    jingjuList.append(jingju)

# Uncomment the following line to take a look to the list of jingjus
# print_jingju_list(jingjuList)

# %% [markdown]
# Now that we have each jingju score well defined and structured, we can start the analysis of the voice-instrumental interval relation.
#
# The first thing that we have to consider is that some scores could have the instrumental and voice part in any of the staffs. So, we will have to annotate each jingju of the list with the staff number where each part is located

# %%
for j in jingjuList:
    s = converter.parse(path_folder + j.scoreXML)
    p0 = s.parts[0]
    
    p0_notes = p0.flat.notes.stream()
    isP0Voice = False
    
    # Check all the notes in a part. If any contains a lyric, that is the voice part of the Jingju
    for n in p0_notes:
        if n.lyric != None:
            isP0Voice = True
    
    if isP0Voice == True:
        j.voiceStaff = 0
        j.instrumentalStaff = 1
    else:
        j.voiceStaff = 1
        j.instrumentalStaff = 0

# %% [markdown]
# Once we have annotated each jingju with the voice and instrumental staffs, we can start the analysis of the interval relationship between both parts of the score.
#
# We have defined the **calcIntervals** function, which receives a Jingju object and calculate the intervals present in the score comparing the note in each offset in the voice and instrumental parts.

# %%
def calcIntervals(j):
    s = converter.parse(path_folder + j.scoreXML)

    pi = s.parts[j.instrumentalStaff] # Instrumental part
    pv = s.parts[j.voiceStaff] # Vocal part

    ni = pi.flat.notes.stream() # All notes from the instrumental part
    nv = pv.flat.notes.stream() # All notes for the vocal part

    intervals = {}

    for n1 in ni:
        if n1.quarterLength > 0: # Skip grace notes
            o = n1.offset
            # Retrieve the notes in the vocal part that occur at the instrumental note's offset.
            # The mustBeginInSpan=False parameter allows retrieving notes that started before that
            # offset are still sounding at that position.
            # The result is a stream, which might contain more than one note in case there are
            # grace notes, which share the offset with the main note.
            nStr = nv.getElementsByOffset(o, mustBeginInSpan=False).stream()
            for n2 in nStr:
                if n2.quarterLength > 0: # Skip grace notes
                    itv = interval.Interval(n1, n2)
                    intervals[itv.name] = intervals.get(itv.name, 0) + 1
    
    j.intervals = intervals
    return intervals

# %% [markdown]
# Then, two lists will be defined: one for the xipi intervals and the other for the erhuang ones. Depending on the operaType of each Jingju object, the interval will be stored in one list or the other.

# %%
xipi_intervals = []
erhuang_intervals = []
for j in jingjuList:
    intervals = calcIntervals(j)
    
    if j.operaType == 'xipi':
        xipi_intervals.append(intervals)
    else:
        erhuang_intervals.append(intervals)

print_jingju_list(jingjuList)
# Out:
# 86 Jingju scores parsed
# Jingju daeh-CanQiQi-WuLongZuo.xml containing 2 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 342, 'm7': 39, 'm6': 7, 'P4': 7, 'P1': 35, 'P5': 6, 'M9': 17, 'm3': 6, 'm10': 6, 'M6': 4, 'M2': 3, 'M7': 1, 'P12': 2, 'P11': 2, 'm2': 1, 'M10': 1}
# 	Line number 1
# 	Open line: 惨凄凄唤苍天天不应响，
# 	Finish line: 叹红颜多薄命父母双亡。
#
#
# 	Line number 2
# 	Open line: 千金休哪曾受磨房景况，
# 	Finish line: 担几肩头晕转体若筛糠。
#
#
# Jingju daeh-LiYanFei-DaBaoGuo.xml containing 5 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 李艳妃设早朝龙书案下，
# 	Finish line: 文站东武列西朝贺哀家。
#
#
# 	Line number 2
# 	Open line: 太师爷奏一本进贡年下，
# 	Finish line: 各国的众王侯朝贺中华。
#
#
# 	Line number 3
# 	Open line: 将江山让太师权且代贺，
# 	Finish line: 候幼主成了龙原业归家。
#
#
# 	Line number 4
# 	Open line: 写文约我且把玉玺打下，
# 	Finish line: 宣太师上金殿披红插花。
#
#
# 	Line number 5
# 	Open line: 赐你的上方剑朝房问话，
# 	Finish line: 压定了文武臣均要画押。
#
#
# Jingju daeh-LiYanFei-ErJinGong.xml containing 3 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 李艳妃坐昭阳自思自想，
# 	Finish line: 想起了朝中事好不惨伤！
#
#
# 	Line number 2
# 	Open line: 耳边厢又听得朝靴响亮，
# 	Finish line: 想必是徐杨将进了昭阳。
#
#
# 	Line number 3
# 	Open line: 有几句话儿我不好言讲，
# 	Finish line: 我只得怀抱太子两泪汪汪口口声声哭的是先王。
#
#
# Jingju daeh-NaRiFeng-YuanXiaoMi.xml containing 4 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 那日风波平地起，
# 	Finish line: 死里逃生甚惨凄。
#
#
# 	Line number 2
# 	Open line: 舅父前来出主意，
# 	Finish line: 我与母亲两分离。
#
#
# 	Line number 3
# 	Open line: 母女隔断三千里，
# 	Finish line: 那厢流泪这厢啼。
#
#
# 	Line number 4
# 	Open line: 我今绝少人生趣，
# 	Finish line: 不如早死命归西。
#
#
# Jingju daeh-NuZiYou-TouJunBieYao.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 奴自幼在闺阁娇生惯养，
# 	Finish line: 为薛郎我父女断绝情长。
#
#
# 	Line number 2
# 	Open line: 但愿得去投军功名有望，
# 	Finish line: 也不枉我二人苦度时光。
#
#
# Jingju daeh-SunShangXiang-BieHuangGong.xml containing 5 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 孙尚香坐宫院自思自叹，
# 	Finish line: 想起了已往事心内痛酸。
#
#
# 	Line number 2
# 	Open line: 遭不幸父王爷把驾来晏，
# 	Finish line: 留下了孙仲谋执掌江南。
#
#
# 	Line number 3
# 	Open line: 与周郎定巧计把皇叔来骗，
# 	Finish line: 又谁知弄假成真反配凤鸾。
#
#
# 	Line number 4
# 	Open line: 回荆州未三载诓我回转，
# 	Finish line: 阿斗儿行中途被子龙追还。
#
#
# 	Line number 5
# 	Open line: 恨只恨我兄长把事错办，
# 	Finish line: 叹一声不由人珠泪涟涟。
#
#
# Jingju daeh-TanHongYan-HuoXiaoYu.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 386, 'm7': 32, 'm10': 6, 'm6': 11, 'P1': 89, 'P4': 9, 'm3': 7, 'M9': 18, 'M2': 6, 'M6': 5, 'M3': 4, 'P11': 2, 'm2': 5, 'P5': 7}
# 	Line number 1
# 	Open line: 叹红颜薄命前生就，
# 	Finish line: 美满姻缘付东流。
#
#
# 	Line number 2
# 	Open line: 薄幸冤家音信无有，
# 	Finish line: 啼花泣月在暗里（呀）添愁。
#
#
# 	Line number 3
# 	Open line: 枕边泪（呀）共（那）阶前雨，
# 	Finish line: 隔着窗儿点滴不休。
#
#
# Jingju daeh-WangChunE-SanNiangJiaoZi.xml containing 4 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 470, 'm7': 52, 'm6': 16, 'M9': 27, 'm10': 10, 'M6': 9, 'P5': 15, 'M2': 14, 'P1': 46, 'm3': 15, 'M7': 1, 'P4': 6, 'P12': 4, 'P11': 2, 'M10': 2}
# 	Line number 1
# 	Open line: 王春娥坐草堂自思自叹，
# 	Finish line: 想起了我老爷好不惨然。
#
#
# 	Line number 2
# 	Open line: 春娥女好一此失群孤雁，
# 	Finish line: 老薛保好一似浪里舟船。
#
#
# 	Line number 3
# 	Open line: 薛倚儿他好比无弓之箭，
# 	Finish line: 每日里在书房苦读圣贤。
#
#
# 	Line number 4
# 	Open line: 将身儿来至在机房织绢，
# 	Finish line: 等候了薛倚儿转回家园。
#
#
# Jingju daeh-WuDuanQiao-BiYuZan.xml containing 4 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 508, 'm7': 60, 'M9': 16, 'm10': 10, 'm6': 7, 'P5': 19, 'P1': 94, 'm3': 20, 'M7': 1, 'M6': 15, 'P4': 3, 'M2': 4, 'P11': 1, 'M3': 1}
# 	Line number 1
# 	Open line: 无端巧计将人陷，
# 	Finish line: 薄命自伤怨红颜。
#
#
# 	Line number 2
# 	Open line: 独处闺房愁无限，
# 	Finish line: 落得孤身病恹恹。
#
#
# 	Line number 3
# 	Open line: 今生若被郎轻贱，
# 	Finish line: 满腹冤屈向谁言。
#
#
# 	Line number 4
# 	Open line: 一心早想寻短见，
# 	Finish line: 又怕丑名误流传。
#
#
# Jingju daeh-XiaoNuCai-SanNiangJiaoZi.xml containing 3 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 小奴才他一言问住我，
# 	Finish line: 闭口无言王春娥。
#
#
# 	Line number 2
# 	Open line: 哭一声亡故夫在阴曹等我，
# 	Finish line: 等候了你妻子同见阎罗。
#
#
# 	Line number 3
# 	Open line: 怒气不息在机房闷坐，
# 	Finish line: 叹一声不由人珠泪如梭。
#
#
# Jingju daeh-ZaoBuXing-HeHouMaDian.xml containing 7 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 遭不幸老王爷晏了御驾，
# 	Finish line: 贼昏王篡了位谋乱邦家。
#
#
# 	Line number 2
# 	Open line: 把一个皇太子逼死殿下，
# 	Finish line: 反倒说为嫂我拦阻有差，
#
#
# 	Line number 3
# 	Open line: 贼好比王莽贼称孤道寡，
# 	Finish line: 贼好比曹阿瞒半点不差，
#
#
# 	Line number 4
# 	Open line: 贼好比秦赵高指鹿为马，
# 	Finish line: 贼好比那司马师搅乱中华。
#
#
# 	Line number 5
# 	Open line: 只骂得贼昏王装聋作哑，
# 	Finish line: 只骂得贼昏王扭转身驱、闭目合晴、羞羞惭惭一语不发，
#
#
# 	Line number 6
# 	Open line: 只骂得贼昏王无言对答。
# 	Finish line: 两旁的文武臣珠泪如麻，
#
#
# 	Line number 7
# 	Open line: 搬一把金交椅娘且坐下，
# 	Finish line: 你叔王不让位再去骂他。
#
#
# Jingju daeh-ZiNaRi-ErJinGong.xml containing 7 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 725, 'M6': 37, 'P5': 47, 'm10': 24, 'm7': 121, 'm6': 39, 'M9': 52, 'M2': 51, 'P1': 113, 'M3': 2, 'm3': 39, 'P4': 19, 'P12': 4, 'M7': 4, 'm2': 3, 'M10': 1, 'm9': 2}
# 	Line number 1
# 	Open line: 自那日与徐杨决裂以后，
# 	Finish line: 独坐在寒宫院闷闷悠悠。
#
#
# 	Line number 2
# 	Open line: 先王爷晏驾后太子年幼，
# 	Finish line: 太师爷一心心想篡龙楼。
#
#
# 	Line number 3
# 	Open line: 他那里父女情全然无有，
# 	Finish line: 竟把我孤儿寡母当做了马牛。
#
#
# 	Line number 4
# 	Open line: 徐小姐把守在宫门口，
# 	Finish line: 看一看不觉到八月中秋。
#
#
# 	Line number 5
# 	Open line: 李艳妃坐昭阳自思自想，
# 	Finish line: 想起了老王爷好不惨伤。
#
#
# 	Line number 6
# 	Open line: 耳边厢又听得朝靴响亮，
# 	Finish line: 想必是徐杨进了昭阳。
#
#
# 	Line number 7
# 	Open line: 有一句话儿不好言讲，
# 	Finish line: 我只得怀抱太子两泪汪汪口口声声哭的是先王！
#
#
# Jingju daeh-ZiNaRi-ZhuangYuanMei-1.xml containing 8 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P8': 20, 'm7': 8, 'M6': 1, 'P5': 2, 'M9': 4, 'M10': 1}
# 	Line number 1
# 	Open line: 自那日与六郎姻缘相见，
# 	Finish line: 行不安坐不宁情态缠绵。
#
#
# 	Line number 2
# 	Open line: 在潼台被贼擒在命好险，
# 	Finish line: 乱军中多亏他救我回还。
#
#
# 	Line number 3
# 	Open line: 这桩事闷得我柔肠百转，
# 	Finish line: 不知道他与我是否一般。
#
#
# 	Line number 4
# 	Open line: 百姓们闺房乐如花美眷，
# 	Finish line: 帝王家深宫院似水流年。
#
#
# 	Line number 5
# 	Open line: 幸喜得珍珠衫称心如愿，
# 	Finish line: 宋天子主婚姻此事成全。
#
#
# 	Line number 6
# 	Open line: 但愿得令公令婆别无异见，
# 	Finish line: 但愿得杨六郎心如石坚，
#
#
# 	Line number 7
# 	Open line: 但愿得状元媒月老引线，
# 	Finish line: 但愿得八主贤王从中周旋，早成姻眷，扫狼烟，叫那胡儿不敢进犯保叔王锦绣江山。
#
#
# 	Line number 8
# 	Open line: 愿天下有情人都成姻眷，
# 	Finish line: 愿天下从此后国泰民安。
#
#
# Jingju daeh-ZiNaRi-ZhuangYuanMei-2.xml containing 8 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 446, 'P1': 70, 'M2': 19, 'M9': 35, 'M6': 18, 'm10': 19, 'm7': 103, 'm6': 20, 'm3': 14, 'P4': 19, 'P5': 20, 'M3': 5, 'm2': 1, 'M10': 2, 'm9': 2, 'P11': 2}
# 	Line number 1
# 	Open line: 自那日与六郎阵前相见，
# 	Finish line: 行不安坐不宁情态缠绵。
#
#
# 	Line number 2
# 	Open line: 在潼台被贼擒性命好险，
# 	Finish line: 乱军中多亏他救我回还。
#
#
# 	Line number 3
# 	Open line: 这桩事闷得我柔肠百转，
# 	Finish line: 不知道他与我是否一般。
#
#
# 	Line number 4
# 	Open line: 百姓们闺房乐如花美眷，
# 	Finish line: 帝王家深宫怨似水流年。
#
#
# 	Line number 5
# 	Open line: 幸喜得珍珠衫称心如愿，
# 	Finish line: 宋天子主婚姻此事成全。
#
#
# 	Line number 6
# 	Open line: 但愿得令公令婆别无意见，
# 	Finish line: 但愿得杨六郎心如石坚。
#
#
# 	Line number 7
# 	Open line: 但愿得状元媒月老引线，
# 	Finish line: 但愿得八主贤王从中周旋早成美眷、扫狼烟叫那胡儿不敢进犯、保叔王锦锈江山。
#
#
# 	Line number 8
# 	Open line: 愿天下有情人都成姻眷，
# 	Finish line: 愿邦家从此后国泰民安。
#
#
# Jingju daeh-ZuoChunGui-XiShi.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 坐春闺只觉得光明似箭，
# 	Finish line: 无限的闲愁恨尽上眉尖。
#
#
# 	Line number 2
# 	Open line: 奴这里心中痛玉颜清减，
# 	Finish line: 夜不眠朝慵起又向谁言。
#
#
# Jingju daeh-ZuoRiGong-TaiZhenWaiChuan.xml containing 2 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 133, 'm7': 18, 'm6': 1, 'm9': 1, 'm10': 2, 'P1': 23, 'M9': 3, 'P5': 3, 'M2': 1, 'P4': 1}
# 	Line number 1
# 	Open line: 昨日宫中何等宠幸，
# 	Finish line: 有谁知一时错被逐宫廷。
#
#
# 	Line number 2
# 	Open line: 思想起从前事心中悔恨，
# 	Finish line: 但不知何日里再沐圣明。
#
#
# Jingju daxp-ChenSanLiang-ChenSanLiangPaTang.xml containing 3 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 6, 'M2': 6, 'P4': 1, 'P5': 1}
# 	Line number 1
# 	Open line: 陈三两在大堂把话云，
# 	Finish line: 公正的老爷细听分明。
#
#
# 	Line number 2
# 	Open line: 我本是被骗进的富春院，
# 	Finish line: 发奋自强日夜读诗文。
#
#
# 	Line number 3
# 	Open line: 诗书易礼都学会，
# 	Finish line: 最可恨鸨儿叫我接客人。
#
#
# Jingju daxp-ChunQiuTing-SuoLinNang.xml containing 17 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 春秋亭外风雨暴，
# 	Finish line: 何处悲声破寂寥。
#
#
# 	Line number 2
# 	Open line: 在隔帘只见这一花轿，
# 	Finish line: 想必是新婚渡鹊桥，
#
#
# 	Line number 3
# 	Open line: 吉日良辰当欢笑，
# 	Finish line: 为何鲛珠化泪抛？
#
#
# 	Line number 4
# 	Open line: 此时却又明白了，
# 	Finish line: 世上何尝尽富豪，
#
#
# 	Line number 5
# 	Open line: 亦有饥寒悲怀抱，
# 	Finish line: 也有失意痛哭嚎啕，
#
#
# 	Line number 6
# 	Open line: 轿内的人儿弹别调，
# 	Finish line: 必有隐情在心潮。
#
#
# 	Line number 7
# 	Open line: 耳听得悲声惨心中如捣，
# 	Finish line: 同遇人为什么这样嚎啕？
#
#
# 	Line number 8
# 	Open line: 莫不是夫郎丑难谐女貌？
# 	Finish line: 莫不是强婚配鸦占鸾巢？
#
#
# 	Line number 9
# 	Open line: 叫梅香你把那好言相告，
# 	Finish line: 问那厢因何故痛哭无聊。
#
#
# 	Line number 10
# 	Open line: 听薛良一语来相告，
# 	Finish line: 满腹骄矜顿雪潇，
#
#
# 	Line number 11
# 	Open line: 人情冷暖凭天造，
# 	Finish line: 谁能移动他半分毫。
#
#
# 	Line number 12
# 	Open line: 我在不足他正少，
# 	Finish line: 他为饥寒我为娇。
#
#
# 	Line number 13
# 	Open line: 分我一枝珊瑚宝，
# 	Finish line: 安他半世凤凰巢。
#
#
# 	Line number 14
# 	Open line: 忙把梅香低声儿叫，
# 	Finish line: 莫把姓名你信口晓，
#
#
# 	Line number 15
# 	Open line: 这都是神话凭空造，
# 	Finish line: 自把珠玉夸富豪，
#
#
# 	Line number 16
# 	Open line: 麟儿那有神送到，
# 	Finish line: 积德才生玉树苗，
#
#
# 	Line number 17
# 	Open line: 小小囊儿何足道，
# 	Finish line: 救她饥渴胜琼瑶。
#
#
# Jingju daxp-DangRiLi-SuoLinNang.xml containing 11 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 191, 'm7': 19, 'P1': 588, 'm3': 58, 'M9': 8, 'M2': 106, 'm2': 17, 'P5': 5, 'P4': 8, 'M6': 1, 'm10': 2, 'M3': 2}
# 	Line number 1
# 	Open line: 当日里好风光忽觉转变，
# 	Finish line: 霎时间日色淡似坠西山。
#
#
# 	Line number 2
# 	Open line: 在轿中只觉得天昏地暗。
# 	Finish line: 耳听得风声断，雨声喧，雷声乱，乐声阑珊，人声呐喊，都道说是大雨倾天。
#
#
# 	Line number 3
# 	Open line: 那花轿必定是因陋就简，
# 	Finish line: 隔帘儿我也曾侧目偷观。
#
#
# 	Line number 4
# 	Open line: 虽然是古青庐以朴为俭，
# 	Finish line: 哪有这短花帘，旧花幔，参差流苏，残破不全。
#
#
# 	Line number 5
# 	Open line: 轿中人必定有一腔幽怨，
# 	Finish line: 她泪自弹、声续断、似杜鹃、啼别院、巴峡哀猿动人心弦，好不惨然。
#
#
# 	Line number 6
# 	Open line: 于归日理应当喜形于面，
# 	Finish line: 为什么悲切切哭得可怜。
#
#
# 	Line number 7
# 	Open line: 那时节奴妆奁不下百万，
# 	Finish line: 怎奈我在轿中赤手空拳。
#
#
# 	Line number 8
# 	Open line: 急切里想起了锁麟囊一（呀）件，
# 	Finish line: 囊虽小却能做续命泉源。
#
#
# 	Line number 9
# 	Open line: 有金珠和珍宝光华灿烂，
# 	Finish line: 红珊瑚碧翡翠样样倶全。
#
#
# 	Line number 10
# 	Open line: 还有那夜明珠粒粒成串，
# 	Finish line: 还有那赤金链，紫瑛簪，白玉环，双凤錾，八宝钗钏一个个宝孕光含。
#
#
# 	Line number 11
# 	Open line: 这囊儿虽非是千古罕见，
# 	Finish line: 换衣食也够她生活几年。
#
#
# Jingju daxp-DiTouLi-NvQiJie.xml containing 4 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 3, 'm10': 1, 'm7': 1, 'P1': 82, 'P5': 1, 'M2': 21, 'm3': 24, 'm2': 4, 'P4': 10}
# 	Line number 1
# 	Open line: 低头离了洪洞县，
# 	Finish line: 将身来在大街前。
#
#
# 	Line number 2
# 	Open line: 未曾开言我心好惨，
# 	Finish line: 过往的君子听我言。
#
#
# 	Line number 3
# 	Open line: 哪一位去往南京转，
# 	Finish line: 与我那三郎把信传。
#
#
# 	Line number 4
# 	Open line: 就说苏三把命断，
# 	Finish line: 来生变犬马我当报还。
#
#
# Jingju daxp-DuiLingHua-BiYuZan.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 对菱花暗地里芳心自转，
# 	Finish line: 听她言不由人喜上眉尖。
#
#
# 	Line number 2
# 	Open line: 果然是成佳偶两心欢恋，
# 	Finish line: 也算得人世间美满姻缘。
#
#
# Jingju daxp-ErDeFu-HongNiGuan.xml containing 4 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 儿的父为国家阵前命丧，
# 	Finish line: 撇下了奴一人好不悲凉。
#
#
# 	Line number 2
# 	Open line: 奴这里只把那结婚思量，
# 	Finish line: 倒不如与伯党匹配鸾凰。
#
#
# 	Line number 3
# 	Open line: 清早起我和他一度商量，
# 	Finish line: 不想到狠心郎一味猖狂。
#
#
# 	Line number 4
# 	Open line: 奴本当把关印付他执掌，
# 	Finish line: 又恐怕众将官说短论长。
#
#
# Jingju daxp-ErTingDe-SuoLinNang.xml containing 16 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P8': 15, 'P1': 424, 'm3': 40, 'M2': 41, 'M3': 4, 'm2': 2, 'P4': 5, 'm7': 1}
# 	Line number 1
# 	Open line: 耳听得悲声惨心中如捣，
# 	Finish line: 同遇人为什么这样嚎啕。
#
#
# 	Line number 2
# 	Open line: 莫不是夫郎丑难谐女貌，
# 	Finish line: 莫不是强婚配鸦占鸾巢。
#
#
# 	Line number 3
# 	Open line: 叫梅香你把那好言相告，
# 	Finish line: 问那厢因何故痛哭无聊？
#
#
# 	Line number 4
# 	Open line: 梅香说话好颠倒，
# 	Finish line: 不该人前乱解嘲。
#
#
# 	Line number 5
# 	Open line: 怜贫济困是正道，
# 	Finish line: 哪有个袖手旁观在壁上瞧。
#
#
# 	Line number 6
# 	Open line: 蠢才问话太潦草，
# 	Finish line: 难免怀疑在心梢。
#
#
# 	Line number 7
# 	Open line: 你不该人前逞骄傲，
# 	Finish line: 不该词费又滔滔。
#
#
# 	Line number 8
# 	Open line: 休要噪且站了，
# 	Finish line: 薛良与我去问一遭。
#
#
# 	Line number 9
# 	Open line: 听薛良一语来相告，
# 	Finish line: 满腹骄矜顿雪潇。
#
#
# 	Line number 10
# 	Open line: 人情冷暖凭空造，
# 	Finish line: 谁能移动它半分毫。
#
#
# 	Line number 11
# 	Open line: 我正不足她正少，
# 	Finish line: 她为饥寒我为骄。
#
#
# 	Line number 12
# 	Open line: 分我一枝珊瑚宝，
# 	Finish line: 安她半世凤凰剿。
#
#
# 	Line number 13
# 	Open line: 忙把梅香低声叫，
# 	Finish line: 莫把姓名你信口哓。
#
#
# 	Line number 14
# 	Open line: 这都是神话凭空造，
# 	Finish line: 自把珠玉夸富豪。
#
#
# 	Line number 15
# 	Open line: 麟儿哪有神送到，
# 	Finish line: 积德才生玉树苗。
#
#
# 	Line number 16
# 	Open line: 小小囊儿何足道，
# 	Finish line: 救她饥渴胜琼瑶。
#
#
# Jingju daxp-FeiShiWo-TaoHuaCun.xml containing 9 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 11, 'm10': 1, 'm7': 1, 'P1': 294, 'm3': 20, 'P5': 1, 'M2': 16, 'm6': 2, 'm2': 6, 'P4': 4, 'M3': 2}
# 	Line number 1
# 	Open line: 非是我嘱咐叮咛把话讲，
# 	Finish line: 只怪你呆头呆脑慌慌张张。
#
#
# 	Line number 2
# 	Open line: 今夜晚非比那西厢待月、你懂提防、莫轻狂，
# 	Finish line: 关系你患难鸳鸯永宿在池塘。
#
#
# 	Line number 3
# 	Open line: 已然错请生波浪，
# 	Finish line: 怎能够粗心大意你再荒唐。
#
#
# 	Line number 4
# 	Open line: 鼓打二更准时往，
# 	Finish line: 桃花村口莫彷徨。
#
#
# 	Line number 5
# 	Open line: 你不要高声不要嚷，
# 	Finish line: 你必须眼观六路耳听八方。
#
#
# 	Line number 6
# 	Open line: 不但要仔细听、还要仔细想，
# 	Finish line: 是不是有人拍巴掌。
#
#
# 	Line number 7
# 	Open line: 响一声你就还一掌，
# 	Finish line: 响两声你就凑近身旁。
#
#
# 	Line number 8
# 	Open line: 倘若是你响她也响，
# 	Finish line: 那就是来了我西厢带路的小红娘。
#
#
# 	Line number 9
# 	Open line: 你把我当做诸葛亮，
# 	Finish line: 听我的号令上战场。
#
#
# Jingju daxp-LaoDieDie-DaYuShaJia-1.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 6, 'm3': 2, 'P4': 3, 'm6': 1, 'M2': 2, 'm2': 1}
# 	Line number 1
# 	Open line: 老爹爹清晨起前去出首，
# 	Finish line: 到叫我桂英儿挂在心头；
#
#
# 	Line number 2
# 	Open line: 将身儿坐至在草堂等候，
# 	Finish line: 等候了爹爹回细问根由。
#
#
# Jingju daxp-LaoDieDie-DaYuShaJia-2.xml containing 2 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 88, 'm10': 1, 'P8': 51, 'm7': 6, 'm3': 7, 'P4': 3, 'M2': 8, 'm6': 2, 'M6': 1, 'P5': 1}
# 	Line number 1
# 	Open line: 老爹爹清晨起前去出首，
# 	Finish line: 倒叫我桂英儿挂在心头。
#
#
# 	Line number 2
# 	Open line: 将身儿坐至在草堂等候，
# 	Finish line: 等候了爹爹回细问根由。
#
#
# Jingju daxp-LaoDieDie-SanJiZhang-1.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 174, 'P8': 79, 'M6': 5, 'P5': 3, 'P4': 4, 'M9': 6, 'm7': 8, 'm3': 13, 'M2': 14, 'm10': 4, 'M3': 6, 'm2': 3, 'm6': 1}
# 	Line number 1
# 	Open line: 老爹爹请息（呀）怒容儿细讲，
# 	Finish line: 我立志不嫁那状元才郎。
#
#
# 	Line number 2
# 	Open line: 父休笑薛平贵是花郎模样，
# 	Finish line: 贫穷人得了志比富还强。
#
#
# Jingju daxp-LaoDieDie-SanJiZhang-2.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P4': 1}
# 	Line number 1
# 	Open line: 老爹爹请息怒容儿细讲，
# 	Finish line: 儿命苦怎配着状元才郎？
#
#
# 	Line number 2
# 	Open line: 父道那薛平贵是那化郎模样，
# 	Finish line: 这样人得了志比父还强。
#
#
# Jingju daxp-LaoDieDie-YuZhouFeng.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 97, 'P8': 44, 'm7': 9, 'P5': 8, 'P11': 1, 'm10': 1, 'm3': 6, 'M7': 1, 'M2': 12, 'M6': 6, 'm6': 2, 'M3': 1, 'P4': 5, 'm2': 1}
# 	Line number 1
# 	Open line: 老爹爹发恩德将本修上，
# 	Finish line: 明早朝上金殿面奏吾皇。
#
#
# 	Line number 2
# 	Open line: 倘若是有道君皇恩浩荡，
# 	Finish line: 观此本免了儿一门祸殃。
#
#
# 	Line number 3
# 	Open line: 老爹爹在朝中官高爵显，
# 	Finish line: 却为何贪富贵不顾羞惭。
#
#
# Jingju daxp-MengJunZi-ChunQiuPei-1.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 186, 'P8': 77, 'm10': 2, 'M6': 5, 'M9': 1, 'M2': 13, 'P4': 4, 'm2': 4, 'P5': 3, 'M3': 2, 'm7': 4, 'm3': 4}
# 	Line number 1
# 	Open line: 蒙君子至殷勤再三问话，
# 	Finish line: 虽然是男女别不得不答。
#
#
# 	Line number 2
# 	Open line: 家住在罗郡城魁星楼下，
# 	Finish line: 我的父名姜绍贸易天涯。
#
#
# 	Line number 3
# 	Open line: 在家中受不过继母拷打，
# 	Finish line: 莫奈何到荒郊我就来捡芦花。
#
#
# Jingju daxp-MengJunZi-ChunQiuPei-2.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 36, 'M9': 2, 'm7': 9, 'M6': 15, 'P5': 7, 'P1': 189, 'M2': 19, 'm3': 26, 'm6': 3, 'P4': 7, 'm2': 6, 'M3': 4, 'm10': 1}
# 	Line number 1
# 	Open line: 蒙君子至诚心再三问话，
# 	Finish line: 虽然是不相识我就不得不答。
#
#
# 	Line number 2
# 	Open line: 家住在罗郡城魁星楼下，
# 	Finish line: 我爹爹名姜绍贸易天涯。
#
#
# 	Line number 3
# 	Open line: 身有病还受那继母拷打，
# 	Finish line: 因此上到郊外来捡芦花（呀）。
#
#
# Jingju daxp-MengTingDe-MuiGuiYingGuaShuai.xml containing 4 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 2, 'm7': 2, 'P1': 97, 'm3': 10, 'M2': 10, 'm2': 1, 'P4': 1, 'M3': 1}
# 	Line number 1
# 	Open line: 猛听得金鼓响画角声震，
# 	Finish line: 唤起我破天门状志凌云。
#
#
# 	Line number 2
# 	Open line: 想当年桃花马上威风凛凛，
# 	Finish line: 敌血飞溅石榴裙。
#
#
# 	Line number 3
# 	Open line: 有生之日责当尽，
# 	Finish line: 寸土怎能够属于他人。
#
#
# 	Line number 4
# 	Open line: 番王小丑何足论，
# 	Finish line: 我一剑能挡百万兵。
#
#
# Jingju daxp-MuQinBu-FengHuanChao.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 67, 'M2': 3, 'm3': 2, 'P4': 1, 'm6': 1, 'P5': 2}
# 	Line number 1
# 	Open line: 母亲不必心太偏，
# 	Finish line: 女儿言来听根源。
#
#
# 	Line number 2
# 	Open line: 自古常言道得好，
# 	Finish line: 女儿清白最为先。
#
#
# 	Line number 3
# 	Open line: 人生不知顾脸面，
# 	Finish line: 活在世上也枉然。
#
#
# Jingju daxp-NiDeFu-FenHeWan.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P8': 2, 'm7': 1, 'M2': 1}
# 	Line number 1
# 	Open line: 你的父去投军无音信，
# 	Finish line: 全仗你打雁养娘亲，
#
#
# 	Line number 2
# 	Open line: 把弓带和鱼镖与儿带定，
# 	Finish line: 不等到日落及早回程。
#
#
# Jingju daxp-QiaoLouShang-HuangShanLei.xml containing 8 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 638, 'M2': 60, 'm3': 48, 'P8': 178, 'm7': 23, 'm10': 8, 'M9': 8, 'M6': 15, 'P4': 9, 'P5': 4, 'm6': 5, 'M3': 7, 'M7': 2, 'm2': 5}
# 	Line number 1
# 	Open line: 谯楼上二更鼓声声送听，
# 	Finish line: 父子们去采药未见回程。
#
#
# 	Line number 2
# 	Open line: 对孤灯思远道心神不定，
# 	Finish line: 不知他在荒山何处安身。
#
#
# 	Line number 3
# 	Open line: 到三更真个是月明人静，
# 	Finish line: 猛听得窗儿外似有人行。
#
#
# 	Line number 4
# 	Open line: 忙移步隔花荫留神听定，
# 	Finish line: 原来是秋风起扫叶之声。
#
#
# 	Line number 5
# 	Open line: 听画鼓报四更愈添凄冷，
# 	Finish line: 看娇儿正酣睡恐被风侵。
#
#
# 	Line number 6
# 	Open line: 我不免引寒机伴奴坐等，
# 	Finish line: 又思来又想去越不安宁。
#
#
# 	Line number 7
# 	Open line: 数更等交五鼓空房愈冷，
# 	Finish line: 果然是晓鸡唱天已黎明。
#
#
# 	Line number 8
# 	Open line: 我不免唤琏儿到街前探问，
# 	Finish line: 你爹爹到如今未转家门。
#
#
# Jingju daxp-SuSanLi-NvQiJie.xml containing 4 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P8': 2, 'm7': 2, 'P1': 79, 'P5': 1, 'M2': 10, 'm3': 20, 'P4': 11, 'm6': 4, 'm10': 1, 'm2': 2}
# 	Line number 1
# 	Open line: 苏三离了洪洞县，
# 	Finish line: 将身来在大街前。
#
#
# 	Line number 2
# 	Open line: 未曾开言心内惨，
# 	Finish line: 过往的君子听我言。
#
#
# 	Line number 3
# 	Open line: 哪一位去往南京转，
# 	Finish line: 与我那三郎把信传。
#
#
# 	Line number 4
# 	Open line: 言说苏三把命断，
# 	Finish line: 来生变犬马我当报还！
#
#
# Jingju daxp-TingTaYan-ZuoGong.xml containing 4 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'m7': 8, 'P8': 9, 'm10': 1, 'P1': 116, 'm3': 17, 'P4': 6, 'M2': 13, 'm2': 1, 'M3': 1}
# 	Line number 1
# 	Open line: 听他言吓得我浑身是汗，
# 	Finish line: 十五载到今日才吐真言。
#
#
# 	Line number 2
# 	Open line: 原来是杨家将把名姓改换，
# 	Finish line: 他思家乡想骨肉就不能团圆。
#
#
# 	Line number 3
# 	Open line: 我这里走向前再把礼见，
# 	Finish line: 尊一声驸马爷细听咱言。
#
#
# 	Line number 4
# 	Open line: 早晚间休怪我言语怠慢，
# 	Finish line: 不知者不怪罪你的海量放宽。
#
#
# Jingju daxp-WoDeNiang-XinAnYi.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 我的娘她忘了女生外姓，
# 	Finish line: 奴年交十九岁还守闺门。
#
#
# 	Line number 2
# 	Open line: 这几日身不爽心中烦闷，
# 	Finish line: 却原来母亲到儿未知情。
#
#
# Jingju daxp-WoHeNi-SangYuanHui.xml containing 1 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 我和你有什么夫妻的情，
# 	Finish line: 谁认你狼心狗肺的人！
#
#
# Jingju daxp-WoZhuYe-SiLangTanMu.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 78, 'm7': 14, 'P5': 5, 'M2': 32, 'M6': 6, 'P4': 16, 'm10': 4, 'P1': 342, 'm3': 16, 'm6': 5, 'm2': 2, 'M3': 3}
# 	Line number 1
# 	Open line: 我主爷金沙滩早把命丧，
# 	Finish line: 众文武扶哀家执掌军房。
#
#
# 	Line number 2
# 	Open line: 众卿随忙挂点亲率官员，
# 	Finish line: 一心心要夺取宋室江山。
#
#
# 	Line number 3
# 	Open line: 叫番儿忙摆驾银安殿，
# 	Finish line: 阅兵书看何人前来何安。
#
#
# Jingju daxp-XiRiLi-LongFengChengXiang.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 165, 'M6': 12, 'M2': 47, 'P1': 323, 'P5': 4, 'P4': 13, 'M9': 8, 'm7': 17, 'm2': 11, 'm3': 21, 'M3': 10, 'M7': 2, 'm10': 1, 'm6': 2, 'm9': 1, 'P11': 1}
# 	Line number 1
# 	Open line: 昔日里梁鸿配孟光，
# 	Finish line: 今朝仙女会襄王。
#
#
# 	Line number 2
# 	Open line: 暗地堪笑奴兄长，
# 	Finish line: 安排虎计害刘王。
#
#
# 	Line number 3
# 	Open line: 月老本是乔国丈，
# 	Finish line: 纵有大事料无妨。
#
#
# Jingju daxp-XiRiLiang-LongFengChengXiang.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P8': 102, 'm7': 10, 'P1': 177, 'P5': 4, 'P4': 4, 'm3': 7, 'M2': 6, 'M9': 3, 'M3': 2, 'M6': 4}
# 	Line number 1
# 	Open line: 昔日梁鸿配孟光，
# 	Finish line: 今朝仙女会襄王。
#
#
# 	Line number 2
# 	Open line: 暗地堪笑我兄长，
# 	Finish line: 安排巧计害刘王。
#
#
# Jingju daxp-XiShiNv-XiShi.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 94, 'P5': 10, 'M2': 67, 'M6': 12, 'P1': 352, 'P4': 16, 'm7': 16, 'm3': 28, 'M9': 5, 'M3': 3, 'm6': 6, 'm10': 2, 'm2': 6, 'd5': 1, 'M7': 1}
# 	Line number 1
# 	Open line: 西施女生长在苎萝村里，
# 	Finish line: 难得有开怀事常锁双眉。
#
#
# 	Line number 2
# 	Open line: 只为着守清寒柴门近水，
# 	Finish line: 每日里浣纱去又傍清溪。
#
#
# 	Line number 3
# 	Open line: 怕只怕损玉颜姣容自惜，
# 	Finish line: 对清溪时照影自整罗农。
#
#
# Jingju lseh-JinZhongXiang-ShangTianTai.xml containing 3 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 金钟响玉磬应王登龙庭，
# 	Finish line: 寡人喜的是五谷丰登。
#
#
# 	Line number 2
# 	Open line: 文凭着邓先生策划有准，
# 	Finish line: 武仗着姚皇兄保定乾坤。
#
#
# 	Line number 3
# 	Open line: 内侍臣忙摆驾九龙口进，
# 	Finish line: 又听得殿角下大放悲声。
#
#
# Jingju lseh-LaoZhangBu-WuPenJi.xml containing 4 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 222, 'm3': 14, 'M2': 55, 'M6': 2, 'P5': 3, 'P8': 13, 'M3': 7, 'P4': 7, 'm2': 1, 'm7': 3}
# 	Line number 1
# 	Open line: 老丈不（哇）必胆怕惊，
# 	Finish line: 我有言来你是（喏）听。
#
#
# 	Line number 2
# 	Open line: 休把我当作了妖魔论，
# 	Finish line: 我本屈死一鬼魂。
#
#
# 	Line number 3
# 	Open line: 我忙将树（呃）枝摆摇（哇）动，
# 	Finish line: 抓一（呀）把沙土扬灰尘。
#
#
# 	Line number 4
# 	Open line: 我和你远无冤近无有仇恨，
# 	Finish line: 望求老丈把冤伸。
#
#
# Jingju lseh-NiangZiBu-SouGuJiuGu.xml containing 7 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 257, 'M2': 64, 'm3': 21, 'P4': 15, 'P8': 17, 'M3': 12, 'P5': 9, 'M6': 6, 'm2': 1, 'm9': 1, 'm10': 1}
# 	Line number 1
# 	Open line: 娘子不（哇）必太烈性，
# 	Finish line: 卑（呀）人言来你是（喏）听。
#
#
# 	Line number 2
# 	Open line: 赵屠二家有仇恨，
# 	Finish line: 三百余口命赴幽冥。
#
#
# 	Line number 3
# 	Open line: 我与那公孙杵臼把计定，
# 	Finish line: 他舍命来你我舍亲生。
#
#
# 	Line number 4
# 	Open line: 舍子搭救忠（呃）良的后，
# 	Finish line: 老天爷不绝我的后代根。
#
#
# 	Line number 5
# 	Open line: 你今舍了亲生子，
# 	Finish line: 来年必定降麒麟。
#
#
# 	Line number 6
# 	Open line: 千言万（哪）语她不肯，
# 	Finish line: 不舍娇儿难救孤身。
#
#
# 	Line number 7
# 	Open line: 无奈何我只得双（呃）膝跪，
# 	Finish line: 哀求娘子（喏）舍亲（呐）生。
#
#
# Jingju lseh-TanXiongDi-SangYuanJiZi.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 171, 'm3': 14, 'P5': 12, 'M2': 43, 'P4': 10, 'P8': 16, 'M6': 10, 'M3': 5, 'm10': 2, 'm7': 3}
# 	Line number 1
# 	Open line: 叹兄兀弟遭不幸一旦丧命，
# 	Finish line: 丢下了年幼儿好不伤情。
#
#
# 	Line number 2
# 	Open line: 眼望着孤坟台珠泪难忍，
# 	Finish line: 见坟台不见人刀割我心。
#
#
# Jingju lseh-TuZeiZuo-SouGuJiuGu.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 屠贼做事心太狠，
# 	Finish line: 诬杀赵家一满门。
#
#
# 	Line number 2
# 	Open line: 眼见得忠良无救应，
# 	Finish line: 大事还要问程婴。
#
#
# Jingju lseh-WeiGuoJia-HongYangDong-1.xml containing 2 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 163, 'P5': 4, 'M2': 37, 'm3': 11, 'm2': 1, 'M3': 1, 'P4': 6, 'M6': 3, 'P8': 10, 'm9': 1}
# 	Line number 1
# 	Open line: 为国家那何曾半日闲空，
# 	Finish line: 我也曾平服了塞北西东。
#
#
# 	Line number 2
# 	Open line: 官封到节度使（喏）皇王恩重，
# 	Finish line: 身不爽不由人瞌睡朦胧（呃）。
#
#
# Jingju lseh-WeiGuoJia-HongYangDong-2.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 为国家哪何曾半日闲空，
# 	Finish line: 我也曾平服了塞北西东。
#
#
# 	Line number 2
# 	Open line: 官封到节度使（喏）皇王恩重，
# 	Finish line: 身不爽不由人瞌睡朦胧（呃）（哪）。
#
#
# Jingju lseh-WeiGuoJia-HongYangDong-3.xml containing 2 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 168, 'P4': 11, 'M2': 41, 'm3': 12, 'M3': 9, 'M6': 2, 'P5': 1, 'm6': 1, 'P8': 6, 'm7': 1}
# 	Line number 1
# 	Open line: 为国家哪何曾半日闲空，
# 	Finish line: 我也曾平服了塞北西东。
#
#
# 	Line number 2
# 	Open line: 官封到节度史（喏）皇王恩重，
# 	Finish line: 身不爽不由人瞌睡朦胧。
#
#
# Jingju lseh-WeiKaiYan-RangXuZhou.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 178, 'M2': 44, 'm3': 24, 'P8': 23, 'P4': 6, 'M3': 3, 'm2': 3, 'P5': 4, 'm6': 1, 'm10': 2, 'M6': 3, 'm7': 1, 'M7': 1}
# 	Line number 1
# 	Open line: 未开言不由人（呐）珠泪滚滚，
# 	Finish line: 天卸重任我就要（哇）你担承。
#
#
# 	Line number 2
# 	Open line: 二犬子（呃）皆年幼（哇）难当（呃）重任，
# 	Finish line: 老朽年迈我也不能够担承。
#
#
# 	Line number 3
# 	Open line: 望使君放开怀慨然（呐）应（呐）允，
# 	Finish line: 救生灵（呐）积阴（呐）功也免得我坐卧不宁。
#
#
# Jingju lseh-XinZhongYou-WenZhaoGuan.xml containing 10 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 2, 'M2': 2, 'M3': 1, 'P4': 1}
# 	Line number 1
# 	Open line: 心中有事难合眼，
# 	Finish line: 翻来复去睡不安。
#
#
# 	Line number 2
# 	Open line: 背地里只把东皋公怨，
# 	Finish line: 叫人难解巧机关。
#
#
# 	Line number 3
# 	Open line: 若是真心来救我，
# 	Finish line: 为何几日他不言，
#
#
# 	Line number 4
# 	Open line: 贪图富贵来害我，
# 	Finish line: 你就该把我献与昭关。
#
#
# 	Line number 5
# 	Open line: 哭一声爹娘不能相见，
# 	K line: 不能（呃）哎见，爹娘（呃）。
# 	Finish line: 要相逢除非是梦（呃）里团圆。
#
#
# 	Line number 6
# 	Open line: 鸡鸣犬吠五更（呃）天，
# 	Finish line: 越思越想好伤惨，
#
#
# 	Line number 7
# 	Open line: 想当初在朝为官宦，
# 	Finish line: 朝臣待漏五更寒。
#
#
# 	Line number 8
# 	Open line: 到如今夜宿在荒村院，
# 	Finish line: 我冷冷清清向谁言（呃）。
#
#
# 	Line number 9
# 	Open line: 我本当拔宝剑自寻短见，
# 	K line: 寻短（呃）哎见爹娘（呃）。
# 	Finish line: 父母的冤仇化尘烟，
#
#
# 	Line number 10
# 	Open line: 对天发下宏誓愿，
# 	Finish line: 我不杀平王我的心怎甘。
#
#
# Jingju lseh-XiRiLi-BaoLianDeng.xml containing 8 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P4': 5, 'P5': 3, 'M2': 3, 'P1': 3, 'm3': 2, 'M3': 1}
# 	Line number 1
# 	Open line: 昔日里有一个孤竹君，
# 	Finish line: 伯夷叔齐二大贤人，
#
#
# 	Line number 2
# 	Open line: 都只为孤（哇）竹君身染重病（哪），
# 	Finish line: 传口诏命次子即位为君，
#
#
# 	Line number 3
# 	Open line: 那叔齐分长幼不能担任，
# 	Finish line: 那伯夷尊父命也不能应承，
#
#
# 	Line number 4
# 	Open line: 弟让兄来兄不能应（呐）允，
# 	Finish line: 兄（呃）推弟来两不能够担承。
#
#
# 	Line number 5
# 	Open line: 那伯夷出午门无（哇）有踪（呃）影，
# 	Finish line: 那叔齐逃出了后宰门，
#
#
# 	Line number 6
# 	Open line: 首阳山前冻饿死（喏）。
# 	Finish line: 留得美名万古存，
#
#
# 	Line number 7
# 	Open line: 为父的怎比得孤竹君，
# 	Finish line: 二娇儿也难比那两个贤人。
#
#
# 	Line number 8
# 	Open line: 打死了别家子父能作主，
# 	Finish line: 打死个秦官保父不能担承。
#
#
# Jingju lseh-XuMaoGong-QinQiongFaPei.xml containing 3 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 徐茂公阴阳多奥妙，
# 	Finish line: 文韬武略智谋高。
#
#
# 	Line number 2
# 	Open line: 既是为我前来到，
# 	Finish line: 缘何不救我出笼牢。
#
#
# 	Line number 3
# 	Open line: 是是是（呀）来我明白了，
# 	Finish line: 其中必有这巧（哇）妙高。
#
#
# Jingju lseh-YangYanZhao-PengBei.xml containing 3 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 杨延昭奉父命巡查大营，
# 	Finish line: 在中途得一信甚是不明。
#
#
# 	Line number 2
# 	Open line: 迈虎步我且把宝帐来进，
# 	Finish line: 又只见老爹爹瞌睡沉沉。
#
#
# 	Line number 3
# 	Open line: 我本当将此事对他来论，
# 	Finish line: 又恐怕惊动了年迈之人。
#
#
# Jingju lseh-YiLunMing-WenZhaoGuan-1.xml containing 18 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 1079, 'm3': 83, 'm2': 9, 'P4': 18, 'M2': 171, 'P5': 10, 'm7': 13, 'P8': 50, 'M6': 10, 'M3': 24, 'm10': 2, 'm6': 4, 'm9': 1}
# 	Line number 1
# 	Open line: 一轮明月照窗前，
# 	Finish line: 愁人心（哪）中似箭穿。
#
#
# 	Line number 2
# 	Open line: 实指（惹）望到吴国借兵回转，
# 	Finish line: 谁知昭关有阻拦。
#
#
# 	Line number 3
# 	Open line: 幸遇那东皋公行方便，
# 	Finish line: 他将我隐藏在后花园。
#
#
# 	Line number 4
# 	Open line: 一连几天我的眉不（哇）展，
# 	Finish line: 夜夜何曾得安眠。
#
#
# 	Line number 5
# 	Open line: 俺伍员好一似丧家犬，
# 	Finish line: 满腹的含冤我向谁言（哪）！
#
#
# 	Line number 6
# 	Open line: 我好（哇）比哀哀长空雁，
# 	Finish line: 我好比龙游在浅沙滩。
#
#
# 	Line number 7
# 	Open line: 我好（哇）比鱼儿吞了钩线，
# 	Finish line: 我好（哇）比波浪中失舵的舟船（哪）。
#
#
# 	Line number 8
# 	Open line: 思来想去我的肝肠断，
# 	Finish line: 今夜晚怎能够盼到明天。
#
#
# 	Line number 9
# 	Open line: 心中有事难合眼，
# 	Finish line: 翻来覆去睡不（哇）安。
#
#
# 	Line number 10
# 	Open line: 背地里只把东皋公怨，
# 	Finish line: 叫人难解巧机关，
#
#
# 	Line number 11
# 	Open line: 若是真心来救我，
# 	Finish line: 为何几日他不言。
#
#
# 	Line number 12
# 	Open line: 贪图富贵来害我，
# 	Finish line: 你就该把我献与昭关。
#
#
# 	Line number 13
# 	Open line: 哭一声爹娘不能相见，
# 	K line: 不能（哪）哎见爹娘（兀）！
# 	Finish line: 要相逢陈非是梦（兀）里团圆。
#
#
# 	Line number 14
# 	Open line: 鸡鸣犬吠五更（哪）天，
# 	Finish line: 越思越想好伤惨，
#
#
# 	Line number 15
# 	Open line: 想当初在朝为官宦，
# 	Finish line: 朝臣待漏（哇）五更寒，
#
#
# 	Line number 16
# 	Open line: 到如今夜宿在荒村院，
# 	Finish line: 我冷冷清清向谁言（哪）。
#
#
# 	Line number 17
# 	Open line: 我本当拔宝剑自寻短见，
# 	K line: 寻短（哪）哎见爹娘（兀）！
# 	Finish line: 父母的冤仇化尘烟，
#
#
# 	Line number 18
# 	Open line: 对天发不宏誓愿，
# 	Finish line: 我不杀平王我的心怎甘（哪）。
#
#
# Jingju lseh-YiLunMing-WenZhaoGuan-2.xml containing 8 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 516, 'm3': 39, 'P4': 16, 'M2': 68, 'M3': 14, 'P5': 9, 'm7': 7, 'P8': 34, 'M6': 12, 'm10': 2, 'm9': 1, 'm6': 5, 'm2': 3}
# 	Line number 1
# 	Open line: 一轮明月照窗前，
# 	Finish line: 愁人心（呐）中似箭穿。
#
#
# 	Line number 2
# 	Open line: 实指望到吴国借兵回转，
# 	Finish line: 谁知昭关有阻拦。
#
#
# 	Line number 3
# 	Open line: 幸遇那东皋公行方便，
# 	Finish line: 他将我隐藏在后花园。
#
#
# 	Line number 4
# 	Open line: 一连几天我的眉不（呃）展，
# 	Finish line: 夜夜何曾得安眠。
#
#
# 	Line number 5
# 	Open line: 俺伍员好一似丧家犬，
# 	Finish line: 满腹的含冤我向谁言（喏）。
#
#
# 	Line number 6
# 	Open line: 我好（呃）比哀哀长空雁，
# 	Finish line: 我好比龙游在浅沙滩。
#
#
# 	Line number 7
# 	Open line: 我好（呃）比鱼儿吞了钩线，
# 	Finish line: 我好（呃）比波浪中失舵的舟船（喏）。
#
#
# 	Line number 8
# 	Open line: 思来想去我的肝肠断，
# 	Finish line: 今夜晚怎能够盼到明天。
#
#
# Jingju lseh-YiLunMing-ZhuoFangCao-1.xml containing 13 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 698, 'M2': 162, 'm3': 47, 'M3': 27, 'P8': 81, 'P4': 25, 'P5': 15, 'P11': 1, 'M6': 29, 'm2': 7, 'm7': 5, 'm6': 3, 'm9': 1, 'm10': 2}
# 	Line number 1
# 	Open line: 一轮明月照窗下，
# 	Finish line: 陈宫心（呐）中乱如麻，
#
#
# 	Line number 2
# 	Open line: 悔不该心猿并意马。
# 	Finish line: 悔不该随他人到吕家，
#
#
# 	Line number 3
# 	Open line: 吕伯奢可算得义气（呀）大，
# 	Finish line: 杀猪（喏）沽（哇）酒款待于他，
#
#
# 	Line number 4
# 	Open line: 又谁知此贼的疑心（呐）太（呀）大，
# 	Finish line: 拔出剑将他的满门杀，
#
#
# 	Line number 5
# 	Open line: 一家人倶丧在宝剑之（喏）下，
# 	Finish line: 年迈的老丈命（呐）染黄沙。
#
#
# 	Line number 6
# 	Open line: 屈死的冤鬼魂休来怨（呐）咱，
# 	Finish line: 自有那神灵（啊）天地鉴察。
#
#
# 	Line number 7
# 	Open line: 听谯楼打罢了二（喏）更鼓下，
# 	Finish line: 越思越想把事来作差。
#
#
# 	Line number 8
# 	Open line: 悔不该把家属一（呀）旦撇下，
# 	Finish line: 悔不该弃县今抛却了乌（哇）纱，
#
#
# 	Line number 9
# 	Open line: 我只说贼是个宽宏量大，
# 	Finish line: 汉室后来贼是个惹祸的根芽。
#
#
# 	Line number 10
# 	Open line: 观此贼睡卧真（呐）潇洒，
# 	Finish line: 安眠好似井底之蛙，
#
#
# 	Line number 11
# 	Open line: 贼好比蛟龙未生鳞甲，
# 	Finish line: 贼好比猛虎未（呀）曾长牙，
#
#
# 	Line number 12
# 	Open line: 虎在笼中我不打，
# 	Finish line: 我岂肯放虎归山又（哇）把人抓。
#
#
# 	Line number 13
# 	Open line: 执宝剑将贼的（呀）头割下，
# 	Finish line: 险些儿把事（喏）又（哇）作差。
#
#
# Jingju lseh-YiLunMing-ZhuoFangCao-2.xml containing 6 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 380, 'P4': 8, 'M3': 5, 'M2': 67, 'm3': 22, 'P8': 57, 'm7': 4, 'P11': 1, 'M6': 6, 'm10': 4, 'P5': 3, 'm2': 1}
# 	Line number 1
# 	Open line: 一轮明月照窗下，
# 	Finish line: 陈宫心中乱如麻。
#
#
# 	Line number 2
# 	Open line: 悔不该心猿并意马，
# 	Finish line: 悔不该随他人到吕家。
#
#
# 	Line number 3
# 	Open line: 吕伯奢可算得义气大，
# 	Finish line: 杀猪沽酒款待与他。
#
#
# 	Line number 4
# 	Open line: 又谁知此贼的疑心太大，
# 	Finish line: 拔出剑将他的满门杀。
#
#
# 	Line number 5
# 	Open line: 一家人倶丧在宝剑之下，
# 	Finish line: 年迈老丈命染黄沙。
#
#
# 	Line number 6
# 	Open line: 屈死的冤鬼魂休要怨咱，
# 	Finish line: 自有那神灵儿天地鉴察。
#
#
# Jingju lseh-YiLunMing-ZhuoFangSuDian.xml containing 6 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 3, 'M2': 5, 'M3': 2, 'm2': 1, 'm3': 1}
# 	Line number 1
# 	Open line: 一轮明月照窗下，
# 	Finish line: 陈宫心（呐）中乱如麻，
#
#
# 	Line number 2
# 	Open line: 悔不该心猿并意马，
# 	Finish line: 悔不该随他人到吕家。
#
#
# 	Line number 3
# 	Open line: 吕伯奢可算得义气（呀）大，
# 	Finish line: 杀猪（喏）沽酒款待与他，
#
#
# 	Line number 4
# 	Open line: 又谁知此贼的疑心（呐）太（呀）大，
# 	Finish line: 拔出剑将他的满门杀，
#
#
# 	Line number 5
# 	Open line: 一家人倶丧在宝剑之（喏）下，
# 	Finish line: 年迈的老丈命（呐）染黄沙。
#
#
# 	Line number 6
# 	Open line: 屈死的怨鬼魂休要怨（呐）咱，
# 	Finish line: 自有那神灵儿天地鉴察。
#
#
# Jingju lseh-ZenNengGou-BaDaChui.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 怎能够思一计番营来进，
# 	Finish line: 前后话对文龙细说衷情。
#
#
# 	Line number 2
# 	Open line: 前也思（喏）后又想无有计定，
# 	Finish line: 倒不如上公安观看古今。
#
#
# Jingju lseh-ZiNaRi-HongYangDong.xml containing 5 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 自（喏）那日朝罢归身（呐）染重病，
# 	Finish line: 三更时梦（呃）见（呐）了年迈爹尊（呐）。
#
#
# 	Line number 2
# 	Open line: 我前番命孟良骸骨搬（呐）请，
# 	Finish line: 那乃是萧天佐以（呀）假成真；
#
#
# 	Line number 3
# 	Open line: 二次（喏）里命孟良番营来进，
# 	Finish line: 又谁知焦克明他私（呀）自后跟（呐），
#
#
# 	Line number 4
# 	Open line: 老军报他二人在洪洋（呃）洞丧（呃）命，
# 	Finish line: 去了我左右膀难以飞行。
#
#
# 	Line number 5
# 	Open line: 为此事终（啊）日里忧成疾病，
# 	Finish line: 因此上臣的病重（呃）加十分、千岁爷呀！
#
#
# Jingju lsxp-CiShiJian-HuaiHeYing-1.xml containing 4 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 74, 'M2': 15, 'm3': 11, 'P4': 3, 'P8': 65, 'm7': 4, 'M6': 9, 'M3': 1, 'm10': 2, 'M10': 1, 'M9': 2}
# 	Line number 1
# 	Open line: 此时间不可闹笑话，
# 	Finish line: 胡言乱语怎瞒（呐）咱。
#
#
# 	Line number 2
# 	Open line: 在长安是你夸大话，
# 	Finish line: 为什么事到如今耍奸滑。
#
#
# 	Line number 3
# 	Open line: 左手拉住了李左车，
# 	Finish line: 右手再把栾布拉。
#
#
# 	Line number 4
# 	Open line: 三人同把那鬼门关上踏（啊），
# 	Finish line: 生死二字（喏）且由他。
#
#
# Jingju lsxp-CiShiJian-HuaiHeYing-2.xml containing 4 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 78, 'M2': 19, 'M3': 4, 'P4': 4, 'm3': 12, 'P8': 50, 'm7': 8, 'M6': 11, 'P5': 2, 'm10': 2, 'M9': 2, 'M10': 1, 'm9': 1}
# 	Line number 1
# 	Open line: 此时间不可闹笑话，
# 	Finish line: 胡言乱语怎瞒（呐）咱！
#
#
# 	Line number 2
# 	Open line: 在长安是你夸大话，
# 	Finish line: 为什么事到如今耍奸滑？
#
#
# 	Line number 3
# 	Open line: 左手拉住了李左车，
# 	Finish line: 右手再把栾布拉，
#
#
# 	Line number 4
# 	Open line: 三人同把那鬼门关上爬，
# 	Finish line: 生死二字（喏）且由他！
#
#
# Jingju lsxp-HenPingWang-WenZhaoGuan.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 78, 'M2': 13, 'm3': 8, 'M3': 6, 'm2': 4, 'P4': 1, 'P5': 3, 'm7': 1, 'P8': 8, 'M6': 1, 'M9': 1, 'P11': 1}
# 	Line number 1
# 	Open line: 恨平王无道乱楚宫（兀），
# 	Finish line: 父纳子（呃）妻礼难容，
#
#
# 	Line number 2
# 	Open line: 我的（呀）父谏奏反把命（哪）送，
# 	Finish line: 满门的家着血染红。
#
#
# Jingju lsxp-JiangShenEr-SanJiaDian.xml containing 8 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P8': 51, 'M6': 6, 'P4': 13, 'P1': 189, 'm3': 21, 'M2': 37, 'P11': 3, 'M9': 5, 'm9': 1, 'm7': 2, 'm2': 1, 'M3': 2}
# 	Line number 1
# 	Open line: 将身儿来至在大街口，
# 	Finish line: 尊一声过往的宾朋听从头：
#
#
# 	Line number 2
# 	Open line: 一不是响马与贼寇，
# 	Finish line: 二不是歹人（呐）把城偷。
#
#
# 	Line number 3
# 	Open line: 杨林与我来争斗，
# 	Finish line: 因此上发配到登州。
#
#
# 	Line number 4
# 	Open line: 舍不得太爷的恩情厚，
# 	Finish line: 舍不得衙役们众班头。
#
#
# 	Line number 5
# 	Open line: 实难舍街坊四邻与我的好朋友，
# 	Finish line: 舍不得老娘（呃）白了头。
#
#
# 	Line number 6
# 	Open line: 娘生儿连心肉，
# 	Finish line: 儿行千里母担忧。
#
#
# 	Line number 7
# 	Open line: 儿想娘亲难叩首，
# 	Finish line: 娘想儿来泪双流。
#
#
# 	Line number 8
# 	Open line: 眼见得红日坠落在西山后，
# 	Finish line: 叫一声解差把店役。
#
#
# Jingju lsxp-JianMaSu-ZhanMaSu.xml containing 2 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {}
# 	Line number 1
# 	Open line: 见马谡（唩）跪帐下，
# 	Finish line: 不由老夫咬钢牙，
#
#
# 	Line number 2
# 	Open line: 大胆不听我的话，
# 	Finish line: 失去了街亭差不差。
#
#
# Jingju lsxp-LiangGuoJiao-ShiJieTing-1.xml containing 3 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 两国交（哇）锋龙虎斗，
# 	Finish line: 各为其主统貔貅，
#
#
# 	Line number 2
# 	Open line: 管待三（哪）军要宽厚，
# 	Finish line: 赏罚中公（呃）平莫要自由。
#
#
# 	Line number 3
# 	Open line: 此一番领兵去镇守，
# 	Finish line: 靠山近水把营收。
#
#
# Jingju lsxp-LiangGuoJiao-ShiJieTing-2.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 131, 'M2': 38, 'm3': 23, 'P4': 12, 'P5': 2, 'P8': 5, 'M6': 1, 'M3': 3}
# 	Line number 1
# 	Open line: 两国交锋龙虎斗，
# 	Finish line: 各为其（呀）主统貔貅。
#
#
# 	Line number 2
# 	Open line: 管带三（呐）军要宽厚，
# 	Finish line: 赏罚中公（呃）平莫要自由。
#
#
# 	Line number 3
# 	Open line: 此一番领（呃）兵去镇守，
# 	Finish line: 靠山近水把营收。
#
#
# Jingju lsxp-QingGongYan-FaDongWu.xml containing 2 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 庆功宴上把酒饮，
# 	Finish line: 想起桃园结拜情。
#
#
# 	Line number 2
# 	Open line: 弟兄们创业多艰难，
# 	Finish line: 又谁知中途两离分。
#
#
# Jingju lsxp-ShenGongWu-LongFengChengXiang.xml containing 2 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 93, 'M3': 1, 'm3': 10, 'M2': 20, 'P4': 5, 'P8': 4, 'm7': 1}
# 	Line number 1
# 	Open line: 深宫无（哇）处不飞花，
# 	Finish line: 年老得配女娇娃。
#
#
# 	Line number 2
# 	Open line: 朝欢暮乐无牵挂，
# 	Finish line: 耳听笙歌闹喧哗。
#
#
# Jingju lsxp-TingTaYan-ZhuoFangCao-1.xml containing 4 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 210, 'M2': 22, 'm3': 22, 'm7': 6, 'P5': 4, 'P8': 120, 'M6': 11, 'M9': 8, 'P4': 6, 'm2': 2, 'P11': 5, 'm9': 1, 'M3': 6, 'm10': 7}
# 	Line number 1
# 	Open line: 听他言吓得我心（呐）惊胆怕，
# 	Finish line: 背转身只埋怨我自（呃）己作差，
#
#
# 	Line number 2
# 	Open line: 我先前只望他宽宏量（呃）大，
# 	Finish line: 却原（呐）来贼是个无（哇）义（呀）的冤家！
#
#
# 	Line number 3
# 	Open line: 马行在来道内我难（呐）以回（呀）马，
# 	Finish line: 这才是花随水水不（哇）能恋（呐）花。
#
#
# 	Line number 4
# 	Open line: 这时候我只得暂且忍耐在心下，
# 	Finish line: 既同行共（呃）大事必须要劝解于他（呀呃）。
#
#
# Jingju lsxp-TingTaYan-ZhuoFangCao-2.xml containing 4 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 212, 'm3': 26, 'M2': 30, 'm7': 7, 'P5': 4, 'P8': 128, 'M6': 13, 'M9': 9, 'P4': 10, 'm2': 2, 'P11': 5, 'm9': 1, 'M3': 6, 'm10': 8, 'M10': 1}
# 	Line number 1
# 	Open line: 听他言吓得我心（呐）惊胆怕，
# 	Finish line: 背转身自埋怨我自（呃）已做差。
#
#
# 	Line number 2
# 	Open line: 我先前只望他宽宏量（呃）大，
# 	Finish line: 却愿（呐）来贼是个无（哇）义（呀）的冤家！
#
#
# 	Line number 3
# 	Open line: 马行在来道内我难（呐）以回（呀）马，
# 	Finish line: 这才是花随水水不（哇）能恋（呐）花。
#
#
# 	Line number 4
# 	Open line: 这时候我只得暂且忍耐在心下，
# 	Finish line: 既同行共（呃）大事必须要劝解于他（呀呃）。
#
#
# Jingju lsxp-WeiCengKai-QiYuanBao.xml containing 5 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 114, 'm3': 13, 'm2': 1, 'M3': 2, 'M2': 20, 'P4': 8, 'm7': 1}
# 	Line number 1
# 	Open line: 未曾开言泪汪汪，
# 	Finish line: 尊一声太爷听端详。
#
#
# 	Line number 2
# 	Open line: 家住在南阳太平庄，
# 	Finish line: 姓刘名安字世昌。
#
#
# 	Line number 3
# 	Open line: 奉母命京城往，
# 	Finish line: 贩卖绸缎转还乡。
#
#
# 	Line number 4
# 	Open line: 行至在中途把雨降，
# 	Finish line: 借宿一宵起祸殃。
#
#
# 	Line number 5
# 	Open line: 赵大夫妻图财害命害我一命亡，
# 	Finish line: 望求太爷与我作主张（啊）。
#
#
# Jingju lsxp-WoBenShi-KongChengJi-1.xml containing 5 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {'P1': 2, 'M2': 2, 'm3': 2, 'P4': 2, 'P8': 4, 'P5': 1, 'M6': 2, 'M9': 1}
# 	Line number 1
# 	Open line: 我本是卧龙岗散淡（哪）的人，
# 	Finish line: 论阴阳如反掌保定乾坤。
#
#
# 	Line number 2
# 	Open line: 先帝（呀）爷下南阳御（呀）驾三请，
# 	Finish line: 算就了汉家的业鼎足（哇）三分。
#
#
# 	Line number 3
# 	Open line: 官封到武乡侯（哇）执掌帅印，
# 	Finish line: 东西战南北剿博古通（呃）今。
#
#
# 	Line number 4
# 	Open line: 周文王访姜尚周室大振，
# 	Finish line: 俺诸（喏）葛怎比得前辈（呀）的先（哪）生。
#
#
# 	Line number 5
# 	Open line: 闲无（哇）事在敌楼（哇）我亮（呃）一亮琴（哪）音，
# 	Finish line: 我面前缺少个知（呃）音的人。
#
#
# Jingju lsxp-WoBenShi-KongChengJi-2.xml containing 5 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 278, 'M2': 29, 'm2': 7, 'm3': 27, 'P8': 101, 'm10': 10, 'm7': 9, 'M9': 5, 'M6': 10, 'M10': 1, 'P4': 10, 'm9': 3, 'm14': 1, 'M3': 8, 'P5': 3, 'm6': 2, 'P12': 1}
# 	Line number 1
# 	Open line: 我本是卧龙岗散淡（呐）的人，
# 	Finish line: 凭阴阳如反掌保定乾坤。
#
#
# 	Line number 2
# 	Open line: 先帝（呀）爷下南阳（呃）御驾三（呃）请，
# 	Finish line: 算就了汉家的业鼎足（呃）三分。
#
#
# 	Line number 3
# 	Open line: 官封到武乡侯（呃）执掌帅印，
# 	Finish line: 东西战南北剿博古（呃）通（哦）今。
#
#
# 	Line number 4
# 	Open line: 周文王访姜尚周室大振，
# 	Finish line: 我诸葛怎比得前辈（呃）的先（呃）生。
#
#
# 	Line number 5
# 	Open line: 闲无（呃）事在敌楼（呃）我亮一亮琴（呢）音，
# 	Finish line: 我面前却少个知（呃）音的人。
#
#
# Jingju lsxp-WoZhuYe-ZhuiHanXin.xml containing 8 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 141, 'm3': 24, 'M2': 25, 'P8': 64, 'P5': 3, 'P11': 5, 'M6': 6, 'M9': 6, 'P4': 9, 'm10': 4, 'm2': 1, 'M3': 1}
# 	Line number 1
# 	Open line: 我主爷起义在芒砀，
# 	Finish line: 拔剑斩蛇天下扬。
#
#
# 	Line number 2
# 	Open line: 怀王也曾把旨降，
# 	Finish line: 两路分（呐）兵定咸阳。
#
#
# 	Line number 3
# 	Open line: 先进咸阳为皇上，
# 	Finish line: 后进咸阳扶保在朝纲。
#
#
# 	Line number 4
# 	Open line: 也是我主洪福广，
# 	Finish line: 一路上得遇陆贾、郦生与张良。
#
#
# 	Line number 5
# 	Open line: 一路上秋毫无犯军威壮，
# 	Finish line: 我也曾约法定过三章。
#
#
# 	Line number 6
# 	Open line: 项羽不遵怀王约，
# 	Finish line: 反将我主贬汉王。
#
#
# 	Line number 7
# 	Open line: 今日里萧何荐良将，
# 	Finish line: 但愿得言听计从重整汉家邦、一同回故乡。
#
#
# 	Line number 8
# 	Open line: 撩袍端带我把金殿上，
# 	Finish line: 扬尘舞蹈见大王。
#
#
# Jingju lsxp-YiShiWu-YuCangJian.xml containing 5 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 一事无成两鬓斑，
# 	Finish line: 叹光明一去不回还（呐）；
#
#
# 	Line number 2
# 	Open line: 日月轮流催晓（哇）箭，
# 	Finish line: 靠山绿（哇）水常在面前。
#
#
# 	Line number 3
# 	Open line: 恨平王无道纲常乱，
# 	Finish line: 信用无极狗奸谗。
#
#
# 	Line number 4
# 	Open line: 他害我满门（呐）真悲惨，
# 	Finish line: 我与奸贼不共戴天！
#
#
# 	Line number 5
# 	Open line: 实指（喏）望到吴国借兵（呐）转，
# 	Finish line: 行至在昭关有阻拦。
#
#
# Jingju lsxp-YiZhuangZhuang-QunYingHui.xml containing 1 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 一桩桩一件件倶已办就，
# 	Finish line: 请先生到江边即刻登舟。
#
#
# Jingju lsxp-ZhangGongDao-ZhuangYuanPu.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 150, 'M3': 3, 'm3': 25, 'M2': 24, 'm2': 2, 'P4': 7, 'P8': 29, 'm7': 4, 'M9': 4, 'P5': 2, 'M6': 4, 'm13': 1, 'm9': 1}
# 	Line number 1
# 	Open line: 张公道三十五六（哇）子有靠，
# 	Finish line: 陈伯愚年半百无有后苗。
#
#
# 	Line number 2
# 	Open line: 为（呀）儿（啼）女我也曾朝山拜庙，
# 	Finish line: 为儿（喏）女我也曾补路修桥。
#
#
# 	Line number 3
# 	Open line: 怕将（呃）来老天爷无（哇）有果报，
# 	Finish line: 眼睁（呐）睁有何人去（呀）把纸烧。
#
#
# Jingju lsxp-ZheYiFeng-DingJunShan.xml containing 6 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {}
# 	Line number 1
# 	Open line: 这一封（呃）书信来得巧，
# 	Finish line: 天助黄忠成功劳。
#
#
# 	Line number 2
# 	Open line: 站立在营门三军叫，
# 	Finish line: 大小儿郎听根苗，
#
#
# 	Line number 3
# 	Open line: 头通（呃）鼓战饭造，
# 	Finish line: 二通（呃）鼓紧战袍，
#
#
# 	Line number 4
# 	Open line: 三通鼓刀出鞘，
# 	Finish line: 四通（呃）鼓把兵交。
#
#
# 	Line number 5
# 	Open line: 向前各各有赏犒，
# 	Finish line: 退后的项上吃一刀。
#
#
# 	Line number 6
# 	Open line: 三军与（呀）爷归营号，
# 	Finish line: 到明天午时三刻要成功劳。
#
#
# Jingju lsxp-ZiCongQian-ZhuLianZhai.xml containing 3 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 自从千岁离朝后，
# 	Finish line: 满朝中文武臣泪双流。
#
#
# 	Line number 2
# 	Open line: 为千岁懒把朝房走，
# 	Finish line: 为千岁懒观五凤楼。
#
#
# 	Line number 3
# 	Open line: 山高路远少来问候，
# 	Finish line: 望千岁恕学生礼貌不周。
#
#
# Jingju lsxp-ZiGuDao-HuangHeLou.xml containing 3 lines
# Voice staff: 0
# Instrumental staff: 1
# Intervals: {}
# 	Line number 1
# 	Open line: 自古道吉人有天相，
# 	Finish line: 主公不必加愁肠。
#
#
# 	Line number 2
# 	Open line: 曾记得当年赴河梁，
# 	Finish line: 二将军保架过长江。
#
#
# 	Line number 3
# 	Open line: 今日主公把宴上，
# 	Finish line: 四将军保架料也无妨。
#
#
# Jingju lsxp-ZouYingLong-DaYanSong.xml containing 7 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {}
# 	Line number 1
# 	Open line: 忽听得万岁宣应龙，
# 	Finish line: 在朝房来了我这保国忠。
#
#
# 	Line number 2
# 	Open line: 那一日打从大街进，
# 	Finish line: 偶遇见小小的顽童放悲声，
#
#
# 	Line number 3
# 	Open line: 我问顽童啼哭因何故，
# 	Finish line: 他言道严嵩老贼害他的举家一满门。
#
#
# 	Line number 4
# 	Open line: 我劝顽童你休流泪，免悲声，邹老爷就是尔的报仇人。
# 	Finish line: 站立在殿角用目来观定，
#
#
# 	Line number 5
# 	Open line: 上面坐的是有道君，
# 	Finish line: 那一旁坐的就是严阁老，
#
#
# 	Line number 6
# 	Open line: 他本是我朝中上欺天子下压臣谋朝篡位卖国的奸贼他名叫严嵩，
# 	Finish line: 我本当金（哪）殿奏一本怎奈我官卑职小不能够参大臣。
#
#
# 	Line number 7
# 	Open line: 罢、罢、罢，暂且忍却我的心头恨，
# 	Finish line: 在品级台（呀）前臣见君。
#
#
# Jingju lsxp-ZuoRiLi-YuanMenZhanZi.xml containing 3 lines
# Voice staff: 1
# Instrumental staff: 0
# Intervals: {'P1': 53, 'M2': 9, 'm3': 5, 'M3': 1}
# 	Line number 1
# 	Open line: 昨日里斩八将头挂营外，
# 	Finish line: 老娘亲为什么不讲情来？
#
#
# 	Line number 2
# 	Open line: 今日里斩宗保娘把儿怪，
# 	Finish line: 哭啼啼坐宝帐所为何来。
#
#
# 	Line number 3
# 	Open line: 叫焦赞将宝剑悬挂帐外，
# 	Finish line: 老娘亲再讲情儿自刎头来。

# %% [markdown]
# Since we now have the xipi and erhuang intervals in two different lists, we can make an 'overall interval' of each type by calculating the mean appeareance of each interval in each jingju type.

# %%
# Create a dictionary with the equivalence of each interval's size in semitones and its name.
intervalsOrder = {}
for k in jingjuList[0].intervals.keys():
    itv = interval.Interval(k)
    intervalsOrder[itv.semitones] = k
    
# Ordered list of intervals by semitones size
xValues = sorted(intervalsOrder.keys())
# Oredred list of interval names by their semitiones size to be use as ticks for the x axis.
xTicks = [intervalsOrder[i] for i in xValues]
# Ordered list of y axis values
yValues = [jingjuList[0].intervals[i] for i in xTicks]

plt.bar(xValues, yValues)
plt.xticks(xValues, xTicks)
plt.show()
