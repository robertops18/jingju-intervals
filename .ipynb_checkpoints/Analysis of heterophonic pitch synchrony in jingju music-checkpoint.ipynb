# %% [markdown]
# # Analysis of heterophonic pitch synchrony in jingju music
#
# This notebook performs statistical analyses to extract insights about level of heterophonic pitch synchrony between the vocal melody and the instrumental accompaniment in jingju music.
#
# Jingju singing is accompanied by an instrumental ensemble in heterophony. Here, the level of heterophonic pitch synchrony is revealed by the distribution of the musical intervals formed between the vocal melody and the lead instrument in the ensemble (jinghu).
#
# These analyses are significantly inspired and use the <a href = "https://compmusic.upf.edu/node/348">Jingju Music Scores Collection</a> from: Repetto, R. C., & Serra, X. (2017). <a href = "https://repositori.upf.edu/handle/10230/32603">A collection of music scores for corpus based jingju singing research</a>. This collection is part of the corpus gathered in the <a href = "https://compmusic.upf.edu/">CompMusic</a> project for jingju music research and offers a comprehensive and complete resource for the study of jingju singing in terms of its musical system.
#
# Note: Each cell begins with a comment that explains what is done in that cell.

# %%
# imports 
import csv
import matplotlib.pyplot as plt
from music21 import *

# %% [markdown]
# The next cell defines three different classes that are used to parse the csv files that come with the score collection and to store the intervals provided by the analyses.
#
# The `Score` class has 7 attributes:
# - `title` (in Chinese)
# - `couplets`: dictionary with line types as keys and instantiations of the line class as values.
# - `voiceStaves`: staves with lyrics in the collection
# - `instrumentalStaves`: staves without lyrics in the collection
# - `separatedAccompaniment`: 'yes' or 'no' the original score contained a separated line for the accompaniment.
# - `intervalsSS`: intervals that sound simultaneously (instance of the interval class)
# - `intervalsPS`: intervals that are played simultaneously (instance of the interval class)
#
#
# The `Line` class has 6 attributes:
# - `shengqiang`
# - `banshi`
# - `role type`
# - `lyrics`
# - `startOffset`
# - `endOffset`
#
# The `Interval` class is designed to store intervals according to three categories (` shengqiang`, `banshi` and` role type`) which in turn are its attributes.

# %%
# class definitions
class Score:        
    def __init__(self, title):
        self.title = title
        self.couplets = []
        self.voiceStaves = []
        self.instrumentalStaves = []
        self.separatedAccompaniment = ''
        self.intervalsSS = Intervals()
        self.intervalsPS = Intervals()
    
    def __str__(self):
        return self.title

class Line:
    def __init__(self, shengqiang = '', banshi = '', roleType = '', lyrics = '', startOffset = '', endOffset = ''):
        self.shengqiang = shengqiang
        self.banshi = banshi
        self.roleType = roleType
        self.lyrics  = lyrics
        self.startOffset = startOffset
        self.endOffset = endOffset
        
    def __str__(self):
        return self.lyrics

    
class Intervals:
    def __init__(self):
        self.shengqiang = {}
        self.banshi = {}
        self.roleType = {}

    def __str__(self):
        return 'shengqiang:' + str(self.shengqiang) + ', banshi' + str(self.banshi) + ', roleType' + str(self.roleType)

# %%
# This cell instantiates 92 Score objects when parsing the csv files that come with the score collection
path_folder = './JingjuMusicScoresCollection/MusicXML/'

lines_data_path = path_folder + 'lines_data.csv'
scoreList = [] # Score objects created when parsing the csv file
Couplet = {'openingLine': '', 'kLine': '', 'closingLine': ''}
row_count = 0

with open(lines_data_path, 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        # Store the previous score if a new one is found
        if row[0] != '': # Start of a new score
            if row_count != 0: # Skip the first score
                score.couplets = score_couplets
                scoreList.append(score)
            
            # Updating the score object with a new one
            title = row[0]
            score = Score(title)
            score_couplets = [] # Init the couplet array of the score
        
        if row[1] != '': # important for scores with multiple voice staves
            if Couplet['closingLine'] != '':
                Couplet = {'openingLine': '', 'kLine': '', 'closingLine': ''}

            # Create a new Line object
            line = Line()
            line.roleType = row[1]
            line.shengqiang = row[2]            
            line.banshi = row[3]
            lineType = row[4]
            line.lyrics = row[5]
            line.startOffset = row[6]
            line.endOffset = row[7]

            if lineType.startswith('s'):
                Couplet['openingLine'] = line
            else:
                if lineType.startswith('k'):
                    Couplet['kLine'] = line
                else:
                    Couplet['closingLine'] = line

            # Append the couplet if the current line is a closing line 
            if Couplet['closingLine'] != '':
                score_couplets.append(Couplet)
            
            # Increment the row count
            row_count += 1
    
    # Store the last score
    score.couplets = score_couplets
    scoreList.append(score)
    
print('{} Scores parsed'.format(len(scoreList)))
# Out:
# 92 Scores parsed

# %% [markdown]
# The scores in the collection have two or three parts. There is no agreement between the original sources about which parts correspond to the voice staves and which parts correspond to the lead instrument. The following cell automatically classifies and keeps track of the vocal parts as those that have lyrics, and the instrumental parts as those that don't.

# %%
# classifying and keeping track of parts
for score in scoreList:
    s = converter.parse(path_folder + score.title)

    vocalParts = []
    instrumentalPart = []
    for staff, p in enumerate(s.parts):
        nn = p.flat.notes.stream() # only notes are needed when looking for lyrics
        i = 0
        if len(nn) != 0: # for a special case: lsxp-YiZhuangZhuang-QunYingHui
            n = nn[i]
            while n.quarterLength == 0: # lyrics are only attached to main notes
                i += 1
                n = nn[i]
            if n.lyric != None:
                vocalParts.append(staff)
            else:
                instrumentalPart.append(staff)
        else:
            instrumentalPart.append(staff)
            
    score.voiceStaves = vocalParts
    score.instrumentalStaves = instrumentalPart

# Special cases
# lsxp-YiZhuangZhuang-QunYingHui - the instrumental staff is all silence
# sdxp-DangNianHan-SanJiZhang - there is no have instrumental staff

# %% [markdown]
# The score collection transnotations almost always (except for the `sdxp-DangNianHan-SanJiZhang` score) present each voice line and the jinghu line in independent staves. For these analyses, only those scores whose vocal part does not have exactly the same melody as the instrumental part (when there is voice melody) are useful, and in the collection are those whose original scores contain a separate line for the accompaniment.
#
# In the following cell, first the `separatedAccompaniment` attribute of the `Score` objects is set with the appropriate annotation from the `scores_data.csv` file of the collection, and then the `ScoreList` is filtered to consider only these scores.
#
# Of the 92 scores, 53 (57.61 %) of them contain a separate line for the accompaniment.

# %%
# filtering scores with separatedAccompaniment

# setting separatedAccompaniment attribute
path_folder = './JingjuMusicScoresCollection/MusicXML/'
lines_data_path = path_folder + 'scores_data.csv'

with open(lines_data_path, 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        score = list(filter(lambda x : x.title == row[0]+'.xml', scoreList))[0]
        score.separatedAccompaniment = row[5]
        
filteredScoreList = list(filter(lambda x : x.separatedAccompaniment == 'yes', scoreList))

print('{} filtered scores'.format(len(filteredScoreList)))
# Out:
# 53 filtered scores

# %% [markdown]
# The following two cells define the functions that compute the number of intervals per type and per category (` shengqiang`, `banshi` and` role type`) in each score. These intervals are store in the `intervalsSS` and `intervalsPS` attributes of the `Score` objects.
#
# The `compIntervalsSS` function deals with the intervals between notes that sound simultaneously, that is to say, intervals formed between each note in the accompaniment and the corresponding sounding note in the singing melody.
#
# The `compIntervalsPS` function deals with the intervals between notes that are played simultaneously, that is to say, intervals formed between the singing and accompaniment notes that are played at the same time.

# %%
# computing the number of intervals per type and per category between notes that sound simultaneously
def compIntervalsSS(score):
    path_folder = './JingjuMusicScoresCollection/MusicXML/'
    
    s = converter.parse(path_folder + score.title)

    pi = s.parts[score.instrumentalStaves[0]] # Instrumental part
    ni = pi.flat.notes.stream() # All notes from the instrumental part
        
    for vS in score.voiceStaves:
        pv = s.parts[vS] # Vocal part
        nv = pv.flat.notes.stream() # All notes for the vocal part

        for n1 in ni:
            if n1.quarterLength > 0: # Skip grace notes
                o = n1.offset
                
                flag_found = 0
                for lines in score.couplets:
                    for line in lines.values():
                        if line != '': # skip kLine when it does not exist
                            if o >= float(line.startOffset) and o <= float(eval(line.endOffset)):
                                shengqiang = line.shengqiang
                                banshi = line.banshi
                                roleType = line.roleType
                                flag_found = 1
                                break
                    if flag_found:
                        break
                
                # Retrieve the notes in the vocal part that occur at the instrumental note's offset.
                # The mustBeginInSpan=False parameter allows retrieving notes that started before that
                # offset and are still sounding at that position.
                # The result is a stream, which might contain more than one note in case there are
                # grace notes, which share the offset with the main note.
                nStr = nv.getElementsByOffset(o, mustBeginInSpan=False).stream()
                for n2 in nStr:
                    if n2.quarterLength > 0: # Skip grace notes
                        itv = interval.Interval(n1, n2)

                        iSSShengqiang = score.intervalsSS.shengqiang # simplified notation with a reference
                        if iSSShengqiang.get(shengqiang) == None: # create if not exist
                            iSSShengqiang[shengqiang] = {} 
                        iSSShengqiang[shengqiang][itv.name] = iSSShengqiang[shengqiang].get(itv.name, 0) + 1

                        iSSBanshi = score.intervalsSS.banshi # simplified notation with a reference
                        if iSSBanshi.get(banshi) == None: # create if not exist
                            iSSBanshi[banshi] = {} 
                        iSSBanshi[banshi][itv.name] = iSSBanshi[banshi].get(itv.name, 0) + 1

                        iSSRoleType = score.intervalsSS.roleType # simplified notation with a reference
                        if iSSRoleType.get(roleType) == None: # create if not exist
                            iSSRoleType[roleType] = {} 
                        iSSRoleType[roleType][itv.name] = iSSRoleType[roleType].get(itv.name, 0) + 1

# %%
# computing the number of intervals per type and per category between notes that are played simultaneously
def compIntervalsPS(score):
    path_folder = './JingjuMusicScoresCollection/MusicXML/'
    
    s = converter.parse(path_folder + score.title)

    pi = s.parts[score.instrumentalStaves[0]] # Instrumental part
    ni = pi.flat.notes.stream() # All notes from the instrumental part
        
    for vS in score.voiceStaves:
        pv = s.parts[vS] # Vocal part
        nv = pv.flat.notes.stream() # All notes for the vocal part

        for n1 in ni:
            if n1.quarterLength > 0: # Skip grace notes
                o = n1.offset
                
                flag_found = 0
                for lines in score.couplets:
                    for line in lines.values():
                        if line != '': # skip kLine when it does not exist
                            if o >= float(line.startOffset) and o <= float(eval(line.endOffset)):
                                shengqiang = line.shengqiang
                                banshi = line.banshi
                                roleType = line.roleType
                                flag_found = 1
                                break
                    if flag_found:
                        break
                
                nStr = nv.getElementsByOffset(o).stream()
                for n2 in nStr:
                    if n2.quarterLength > 0: # Skip grace notes
                        itv = interval.Interval(n1, n2)

                        iPSShengqiang = score.intervalsPS.shengqiang # simplified notation with a reference
                        if iPSShengqiang.get(shengqiang) == None: # create if not exist
                            iPSShengqiang[shengqiang] = {} 
                        iPSShengqiang[shengqiang][itv.name] = iPSShengqiang[shengqiang].get(itv.name, 0) + 1

                        iPSBanshi = score.intervalsPS.banshi # simplified notation with a reference
                        if iPSBanshi.get(banshi) == None: # create if not exist
                            iPSBanshi[banshi] = {} 
                        iPSBanshi[banshi][itv.name] = iPSBanshi[banshi].get(itv.name, 0) + 1

                        iPSRoleType = score.intervalsPS.roleType # simplified notation with a reference
                        if iPSRoleType.get(roleType) == None: # create if not exist
                            iPSRoleType[roleType] = {} 
                        iPSRoleType[roleType][itv.name] = iPSRoleType[roleType].get(itv.name, 0) + 1

# %%
# applying compIntervals functions to the filteredScoreList
for score in filteredScoreList:
    compIntervalsSS(score)
    compIntervalsPS(score)

# %%
# printing the score list
def print_score_list(scoreList):
    print('{} Scores'.format(len(scoreList)))
    for s in scoreList:
        print('Score {} containing {} couplets'.format(s.title, len(s.couplets)))
        print('Voice staves: {}'.format(s.voiceStaves))
        print('Instrumental staves: {}'.format(s.instrumentalStaves))
        print('Separated accompaniment: {}'.format(s.separatedAccompaniment))
        print('IntervalsSS: {}'.format(s.intervalsSS))
        print('IntervalsPS: {}'.format(s.intervalsPS))
        count = 1
        for l in s.couplets:
            print('\tCouplet {}'.format(count))
            print('\tOpening line: {}'.format(l['openingLine']))
            if l['kLine'] != '':
                print('\tK line: {}'.format(l['kLine']))
            print('\tClosing line: {}'.format(l['closingLine']))
            print('\n')
            count += 1

print_score_list(filteredScoreList)
# Out:
# 53 Scores
# Score daeh-CanQiQi-WuLongZuo.xml containing 2 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P8': 342, 'm7': 39, 'm6': 7, 'P4': 7, 'P1': 35, 'P5': 6, 'M9': 17, 'm3': 6, 'm10': 6, 'M6': 4, 'M2': 3, 'M7': 1, 'P12': 2, 'P11': 2, 'm2': 1, 'M10': 1}}, banshi{'manban': {'P8': 342, 'm7': 39, 'm6': 7, 'P4': 7, 'P1': 35, 'P5': 6, 'M9': 17, 'm3': 6, 'm10': 6, 'M6': 4, 'M2': 3, 'M7': 1, 'P12': 2, 'P11': 2, 'm2': 1, 'M10': 1}}, roleType{'dan': {'P8': 342, 'm7': 39, 'm6': 7, 'P4': 7, 'P1': 35, 'P5': 6, 'M9': 17, 'm3': 6, 'm10': 6, 'M6': 4, 'M2': 3, 'M7': 1, 'P12': 2, 'P11': 2, 'm2': 1, 'M10': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P8': 239, 'P1': 30, 'P5': 2, 'M7': 1, 'm10': 3, 'P11': 1, 'm2': 1, 'M6': 2, 'M10': 1, 'm7': 2, 'M9': 1, 'm3': 1}}, banshi{'manban': {'P8': 239, 'P1': 30, 'P5': 2, 'M7': 1, 'm10': 3, 'P11': 1, 'm2': 1, 'M6': 2, 'M10': 1, 'm7': 2, 'M9': 1, 'm3': 1}}, roleType{'dan': {'P8': 239, 'P1': 30, 'P5': 2, 'M7': 1, 'm10': 3, 'P11': 1, 'm2': 1, 'M6': 2, 'M10': 1, 'm7': 2, 'M9': 1, 'm3': 1}}
# 	Couplet 1
# 	Opening line: 惨凄凄唤苍天天不应响，
# 	Closing line: 叹红颜多薄命父母双亡。
#
#
# 	Couplet 2
# 	Opening line: 千金休哪曾受磨房景况，
# 	Closing line: 担几肩头晕转体若筛糠。
#
#
# Score daeh-TanHongYan-HuoXiaoYu.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P8': 386, 'm7': 32, 'm10': 6, 'm6': 11, 'P1': 89, 'P4': 9, 'm3': 7, 'M9': 18, 'M2': 6, 'M6': 5, 'M3': 4, 'P11': 2, 'm2': 5, 'P5': 7}}, banshi{'manban': {'P8': 386, 'm7': 32, 'm10': 6, 'm6': 11, 'P1': 89, 'P4': 9, 'm3': 7, 'M9': 18, 'M2': 6, 'M6': 5, 'M3': 4, 'P11': 2, 'm2': 5, 'P5': 7}}, roleType{'dan': {'P8': 386, 'm7': 32, 'm10': 6, 'm6': 11, 'P1': 89, 'P4': 9, 'm3': 7, 'M9': 18, 'M2': 6, 'M6': 5, 'M3': 4, 'P11': 2, 'm2': 5, 'P5': 7}}
# IntervalsPS: shengqiang:{'erhuang': {'P8': 341, 'P1': 78, 'M9': 1, 'm7': 9, 'M6': 1, 'M3': 3, 'm10': 3, 'M2': 1, 'P4': 3, 'm2': 1, 'P5': 2}}, banshi{'manban': {'P8': 341, 'P1': 78, 'M9': 1, 'm7': 9, 'M6': 1, 'M3': 3, 'm10': 3, 'M2': 1, 'P4': 3, 'm2': 1, 'P5': 2}}, roleType{'dan': {'P8': 341, 'P1': 78, 'M9': 1, 'm7': 9, 'M6': 1, 'M3': 3, 'm10': 3, 'M2': 1, 'P4': 3, 'm2': 1, 'P5': 2}}
# 	Couplet 1
# 	Opening line: 叹红颜薄命前生就，
# 	Closing line: 美满姻缘付东流。
#
#
# 	Couplet 2
# 	Opening line: 薄幸冤家音信无有，
# 	Closing line: 啼花泣月在暗里（呀）添愁。
#
#
# 	Couplet 3
# 	Opening line: 枕边泪（呀）共（那）阶前雨，
# 	Closing line: 隔着窗儿点滴不休。
#
#
# Score daeh-WangChunE-SanNiangJiaoZi.xml containing 4 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P8': 470, 'm7': 52, 'm6': 16, 'M9': 27, 'm10': 10, 'M6': 9, 'P5': 15, 'M2': 14, 'P1': 46, 'm3': 15, 'M7': 1, 'P4': 6, 'P12': 4, 'P11': 2, 'M10': 2}}, banshi{'manban': {'P8': 470, 'm7': 52, 'm6': 16, 'M9': 27, 'm10': 10, 'M6': 9, 'P5': 15, 'M2': 14, 'P1': 46, 'm3': 15, 'M7': 1, 'P4': 6, 'P12': 4, 'P11': 2, 'M10': 2}}, roleType{'dan': {'P8': 470, 'm7': 52, 'm6': 16, 'M9': 27, 'm10': 10, 'M6': 9, 'P5': 15, 'M2': 14, 'P1': 46, 'm3': 15, 'M7': 1, 'P4': 6, 'P12': 4, 'P11': 2, 'M10': 2}}
# IntervalsPS: shengqiang:{'erhuang': {'P8': 366, 'M2': 10, 'M7': 1, 'P1': 30, 'P5': 2, 'm7': 3, 'M9': 3, 'm3': 2, 'm6': 1, 'P4': 1, 'M6': 1, 'M10': 2, 'm10': 1}}, banshi{'manban': {'P8': 366, 'M2': 10, 'M7': 1, 'P1': 30, 'P5': 2, 'm7': 3, 'M9': 3, 'm3': 2, 'm6': 1, 'P4': 1, 'M6': 1, 'M10': 2, 'm10': 1}}, roleType{'dan': {'P8': 366, 'M2': 10, 'M7': 1, 'P1': 30, 'P5': 2, 'm7': 3, 'M9': 3, 'm3': 2, 'm6': 1, 'P4': 1, 'M6': 1, 'M10': 2, 'm10': 1}}
# 	Couplet 1
# 	Opening line: 王春娥坐草堂自思自叹，
# 	Closing line: 想起了我老爷好不惨然。
#
#
# 	Couplet 2
# 	Opening line: 春娥女好一此失群孤雁，
# 	Closing line: 老薛保好一似浪里舟船。
#
#
# 	Couplet 3
# 	Opening line: 薛倚儿他好比无弓之箭，
# 	Closing line: 每日里在书房苦读圣贤。
#
#
# 	Couplet 4
# 	Opening line: 将身儿来至在机房织绢，
# 	Closing line: 等候了薛倚儿转回家园。
#
#
# Score daeh-WuDuanQiao-BiYuZan.xml containing 4 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P8': 508, 'm7': 60, 'M9': 16, 'm10': 10, 'm6': 7, 'P5': 19, 'P1': 94, 'm3': 20, 'M7': 1, 'M6': 15, 'P4': 3, 'M2': 4, 'P11': 1, 'M3': 1}}, banshi{'manban': {'P8': 508, 'm7': 60, 'M9': 16, 'm10': 10, 'm6': 7, 'P5': 19, 'P1': 94, 'm3': 20, 'M7': 1, 'M6': 15, 'P4': 3, 'M2': 4, 'P11': 1, 'M3': 1}}, roleType{'dan': {'P8': 508, 'm7': 60, 'M9': 16, 'm10': 10, 'm6': 7, 'P5': 19, 'P1': 94, 'm3': 20, 'M7': 1, 'M6': 15, 'P4': 3, 'M2': 4, 'P11': 1, 'M3': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P8': 417, 'm10': 1, 'P1': 86, 'M9': 5, 'm3': 5, 'm7': 7, 'P5': 3, 'm6': 2, 'M2': 1, 'M6': 1, 'M3': 1}}, banshi{'manban': {'P8': 417, 'm10': 1, 'P1': 86, 'M9': 5, 'm3': 5, 'm7': 7, 'P5': 3, 'm6': 2, 'M2': 1, 'M6': 1, 'M3': 1}}, roleType{'dan': {'P8': 417, 'm10': 1, 'P1': 86, 'M9': 5, 'm3': 5, 'm7': 7, 'P5': 3, 'm6': 2, 'M2': 1, 'M6': 1, 'M3': 1}}
# 	Couplet 1
# 	Opening line: 无端巧计将人陷，
# 	Closing line: 薄命自伤怨红颜。
#
#
# 	Couplet 2
# 	Opening line: 独处闺房愁无限，
# 	Closing line: 落得孤身病恹恹。
#
#
# 	Couplet 3
# 	Opening line: 今生若被郎轻贱，
# 	Closing line: 满腹冤屈向谁言。
#
#
# 	Couplet 4
# 	Opening line: 一心早想寻短见，
# 	Closing line: 又怕丑名误流传。
#
#
# Score daeh-ZiNaRi-ErJinGong.xml containing 7 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P8': 725, 'M6': 37, 'P5': 47, 'm10': 24, 'm7': 121, 'm6': 39, 'M9': 52, 'M2': 51, 'P1': 113, 'M3': 2, 'm3': 39, 'P4': 19, 'P12': 4, 'M7': 4, 'm2': 3, 'M10': 1, 'm9': 2}}, banshi{'manban': {'P8': 725, 'M6': 37, 'P5': 47, 'm10': 24, 'm7': 121, 'm6': 39, 'M9': 52, 'M2': 51, 'P1': 113, 'M3': 2, 'm3': 39, 'P4': 19, 'P12': 4, 'M7': 4, 'm2': 3, 'M10': 1, 'm9': 2}}, roleType{'dan': {'P8': 725, 'M6': 37, 'P5': 47, 'm10': 24, 'm7': 121, 'm6': 39, 'M9': 52, 'M2': 51, 'P1': 113, 'M3': 2, 'm3': 39, 'P4': 19, 'P12': 4, 'M7': 4, 'm2': 3, 'M10': 1, 'm9': 2}}
# IntervalsPS: shengqiang:{'erhuang': {'P8': 550, 'M6': 8, 'M2': 23, 'm7': 17, 'P1': 73, 'm3': 6, 'M9': 6, 'P5': 14, 'M7': 2, 'm2': 3, 'm6': 2, 'P4': 2, 'm10': 3}}, banshi{'manban': {'P8': 550, 'M6': 8, 'M2': 23, 'm7': 17, 'P1': 73, 'm3': 6, 'M9': 6, 'P5': 14, 'M7': 2, 'm2': 3, 'm6': 2, 'P4': 2, 'm10': 3}}, roleType{'dan': {'P8': 550, 'M6': 8, 'M2': 23, 'm7': 17, 'P1': 73, 'm3': 6, 'M9': 6, 'P5': 14, 'M7': 2, 'm2': 3, 'm6': 2, 'P4': 2, 'm10': 3}}
# 	Couplet 1
# 	Opening line: 自那日与徐杨决裂以后，
# 	Closing line: 独坐在寒宫院闷闷悠悠。
#
#
# 	Couplet 2
# 	Opening line: 先王爷晏驾后太子年幼，
# 	Closing line: 太师爷一心心想篡龙楼。
#
#
# 	Couplet 3
# 	Opening line: 他那里父女情全然无有，
# 	Closing line: 竟把我孤儿寡母当做了马牛。
#
#
# 	Couplet 4
# 	Opening line: 徐小姐把守在宫门口，
# 	Closing line: 看一看不觉到八月中秋。
#
#
# 	Couplet 5
# 	Opening line: 李艳妃坐昭阳自思自想，
# 	Closing line: 想起了老王爷好不惨伤。
#
#
# 	Couplet 6
# 	Opening line: 耳边厢又听得朝靴响亮，
# 	Closing line: 想必是徐杨进了昭阳。
#
#
# 	Couplet 7
# 	Opening line: 有一句话儿不好言讲，
# 	Closing line: 我只得怀抱太子两泪汪汪口口声声哭的是先王！
#
#
# Score daeh-ZiNaRi-ZhuangYuanMei-2.xml containing 8 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P8': 446, 'P1': 70, 'M2': 19, 'M9': 35, 'M6': 18, 'm10': 19, 'm7': 103, 'm6': 20, 'm3': 14, 'P4': 19, 'P5': 20, 'M3': 5, 'm2': 1, 'M10': 2, 'm9': 2, 'P11': 2}}, banshi{'yuanban': {'P8': 446, 'P1': 70, 'M2': 19, 'M9': 35, 'M6': 18, 'm10': 19, 'm7': 103, 'm6': 20, 'm3': 14, 'P4': 19, 'P5': 20, 'M3': 5, 'm2': 1, 'M10': 2, 'm9': 2, 'P11': 2}}, roleType{'dan': {'P8': 446, 'P1': 70, 'M2': 19, 'M9': 35, 'M6': 18, 'm10': 19, 'm7': 103, 'm6': 20, 'm3': 14, 'P4': 19, 'P5': 20, 'M3': 5, 'm2': 1, 'M10': 2, 'm9': 2, 'P11': 2}}
# IntervalsPS: shengqiang:{'erhuang': {'P8': 359, 'P1': 53, 'M9': 9, 'm7': 19, 'M2': 2, 'M6': 4, 'm3': 4, 'P5': 10, 'm10': 8, 'P4': 8, 'M3': 4, 'm2': 1, 'P11': 1, 'm9': 1}}, banshi{'yuanban': {'P8': 359, 'P1': 53, 'M9': 9, 'm7': 19, 'M2': 2, 'M6': 4, 'm3': 4, 'P5': 10, 'm10': 8, 'P4': 8, 'M3': 4, 'm2': 1, 'P11': 1, 'm9': 1}}, roleType{'dan': {'P8': 359, 'P1': 53, 'M9': 9, 'm7': 19, 'M2': 2, 'M6': 4, 'm3': 4, 'P5': 10, 'm10': 8, 'P4': 8, 'M3': 4, 'm2': 1, 'P11': 1, 'm9': 1}}
# 	Couplet 1
# 	Opening line: 自那日与六郎阵前相见，
# 	Closing line: 行不安坐不宁情态缠绵。
#
#
# 	Couplet 2
# 	Opening line: 在潼台被贼擒性命好险，
# 	Closing line: 乱军中多亏他救我回还。
#
#
# 	Couplet 3
# 	Opening line: 这桩事闷得我柔肠百转，
# 	Closing line: 不知道他与我是否一般。
#
#
# 	Couplet 4
# 	Opening line: 百姓们闺房乐如花美眷，
# 	Closing line: 帝王家深宫怨似水流年。
#
#
# 	Couplet 5
# 	Opening line: 幸喜得珍珠衫称心如愿，
# 	Closing line: 宋天子主婚姻此事成全。
#
#
# 	Couplet 6
# 	Opening line: 但愿得令公令婆别无意见，
# 	Closing line: 但愿得杨六郎心如石坚。
#
#
# 	Couplet 7
# 	Opening line: 但愿得状元媒月老引线，
# 	Closing line: 但愿得八主贤王从中周旋早成美眷、扫狼烟叫那胡儿不敢进犯、保叔王锦锈江山。
#
#
# 	Couplet 8
# 	Opening line: 愿天下有情人都成姻眷，
# 	Closing line: 愿邦家从此后国泰民安。
#
#
# Score daeh-ZuoRiGong-TaiZhenWaiChuan.xml containing 2 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P8': 133, 'm7': 18, 'm6': 1, 'm9': 1, 'm10': 2, 'P1': 23, 'M9': 3, 'P5': 3, 'M2': 1, 'P4': 1}}, banshi{'yuanban': {'P8': 133, 'm7': 18, 'm6': 1, 'm9': 1, 'm10': 2, 'P1': 23, 'M9': 3, 'P5': 3, 'M2': 1, 'P4': 1}}, roleType{'dan': {'P8': 133, 'm7': 18, 'm6': 1, 'm9': 1, 'm10': 2, 'P1': 23, 'M9': 3, 'P5': 3, 'M2': 1, 'P4': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P8': 118, 'm7': 3, 'P1': 23, 'P5': 1, 'P4': 1}}, banshi{'yuanban': {'P8': 118, 'm7': 3, 'P1': 23, 'P5': 1, 'P4': 1}}, roleType{'dan': {'P8': 118, 'm7': 3, 'P1': 23, 'P5': 1, 'P4': 1}}
# 	Couplet 1
# 	Opening line: 昨日宫中何等宠幸，
# 	Closing line: 有谁知一时错被逐宫廷。
#
#
# 	Couplet 2
# 	Opening line: 思想起从前事心中悔恨，
# 	Closing line: 但不知何日里再沐圣明。
#
#
# Score daxp-DangRiLi-SuoLinNang.xml containing 11 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 191, 'm7': 19, 'P1': 588, 'm3': 58, 'M9': 8, 'M2': 106, 'm2': 17, 'P5': 5, 'P4': 8, 'M6': 1, 'm10': 2, 'M3': 2}}, banshi{'yuanban': {'P8': 186, 'm7': 18, 'P1': 467, 'm3': 39, 'M9': 8, 'M2': 94, 'm2': 11, 'P5': 5, 'P4': 4, 'M6': 1, 'm10': 2, 'M3': 2}, 'liushui': {'P8': 5, 'm7': 1, 'P1': 121, 'M2': 12, 'm2': 6, 'm3': 19, 'P4': 4}}, roleType{'dan': {'P8': 191, 'm7': 19, 'P1': 588, 'm3': 58, 'M9': 8, 'M2': 106, 'm2': 17, 'P5': 5, 'P4': 8, 'M6': 1, 'm10': 2, 'M3': 2}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 152, 'm7': 3, 'P1': 511, 'M9': 6, 'M2': 43, 'm3': 20, 'P4': 3, 'm10': 1, 'P5': 2, 'M3': 1, 'm2': 1}}, banshi{'yuanban': {'P8': 149, 'm7': 3, 'P1': 407, 'M9': 6, 'M2': 39, 'm3': 12, 'P4': 2, 'm10': 1, 'P5': 2, 'M3': 1, 'm2': 1}, 'liushui': {'P8': 3, 'P1': 104, 'm3': 8, 'M2': 4, 'P4': 1}}, roleType{'dan': {'P8': 152, 'm7': 3, 'P1': 511, 'M9': 6, 'M2': 43, 'm3': 20, 'P4': 3, 'm10': 1, 'P5': 2, 'M3': 1, 'm2': 1}}
# 	Couplet 1
# 	Opening line: 当日里好风光忽觉转变，
# 	Closing line: 霎时间日色淡似坠西山。
#
#
# 	Couplet 2
# 	Opening line: 在轿中只觉得天昏地暗。
# 	Closing line: 耳听得风声断，雨声喧，雷声乱，乐声阑珊，人声呐喊，都道说是大雨倾天。
#
#
# 	Couplet 3
# 	Opening line: 那花轿必定是因陋就简，
# 	Closing line: 隔帘儿我也曾侧目偷观。
#
#
# 	Couplet 4
# 	Opening line: 虽然是古青庐以朴为俭，
# 	Closing line: 哪有这短花帘，旧花幔，参差流苏，残破不全。
#
#
# 	Couplet 5
# 	Opening line: 轿中人必定有一腔幽怨，
# 	Closing line: 她泪自弹、声续断、似杜鹃、啼别院、巴峡哀猿动人心弦，好不惨然。
#
#
# 	Couplet 6
# 	Opening line: 于归日理应当喜形于面，
# 	Closing line: 为什么悲切切哭得可怜。
#
#
# 	Couplet 7
# 	Opening line: 那时节奴妆奁不下百万，
# 	Closing line: 怎奈我在轿中赤手空拳。
#
#
# 	Couplet 8
# 	Opening line: 急切里想起了锁麟囊一（呀）件，
# 	Closing line: 囊虽小却能做续命泉源。
#
#
# 	Couplet 9
# 	Opening line: 有金珠和珍宝光华灿烂，
# 	Closing line: 红珊瑚碧翡翠样样倶全。
#
#
# 	Couplet 10
# 	Opening line: 还有那夜明珠粒粒成串，
# 	Closing line: 还有那赤金链，紫瑛簪，白玉环，双凤錾，八宝钗钏一个个宝孕光含。
#
#
# 	Couplet 11
# 	Opening line: 这囊儿虽非是千古罕见，
# 	Closing line: 换衣食也够她生活几年。
#
#
# Score daxp-DiTouLi-NvQiJie.xml containing 4 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 3, 'm10': 1, 'm7': 1, 'P1': 82, 'P5': 1, 'M2': 21, 'm3': 24, 'm2': 4, 'P4': 10}}, banshi{'liushui': {'P8': 3, 'm10': 1, 'm7': 1, 'P1': 82, 'P5': 1, 'M2': 21, 'm3': 24, 'm2': 4, 'P4': 10}}, roleType{'dan': {'P8': 3, 'm10': 1, 'm7': 1, 'P1': 82, 'P5': 1, 'M2': 21, 'm3': 24, 'm2': 4, 'P4': 10}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 2, 'P1': 57, 'P5': 1, 'M2': 6, 'm3': 11, 'P4': 4}}, banshi{'liushui': {'P8': 2, 'P1': 57, 'P5': 1, 'M2': 6, 'm3': 11, 'P4': 4}}, roleType{'dan': {'P8': 2, 'P1': 57, 'P5': 1, 'M2': 6, 'm3': 11, 'P4': 4}}
# 	Couplet 1
# 	Opening line: 低头离了洪洞县，
# 	Closing line: 将身来在大街前。
#
#
# 	Couplet 2
# 	Opening line: 未曾开言我心好惨，
# 	Closing line: 过往的君子听我言。
#
#
# 	Couplet 3
# 	Opening line: 哪一位去往南京转，
# 	Closing line: 与我那三郎把信传。
#
#
# 	Couplet 4
# 	Opening line: 就说苏三把命断，
# 	Closing line: 来生变犬马我当报还。
#
#
# Score daxp-ErTingDe-SuoLinNang.xml containing 16 couplets
# Voice staves: [0]
# Instrumental staves: [1]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 15, 'P1': 424, 'm3': 40, 'M2': 41, 'M3': 4, 'm2': 2, 'P4': 5, 'm7': 1}}, banshi{'liushui': {'P8': 15, 'P1': 424, 'm3': 40, 'M2': 41, 'M3': 4, 'm2': 2, 'P4': 5, 'm7': 1}}, roleType{'dan': {'P8': 15, 'P1': 424, 'm3': 40, 'M2': 41, 'M3': 4, 'm2': 2, 'P4': 5, 'm7': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 15, 'P1': 383, 'm3': 18, 'M2': 8, 'm2': 2, 'P4': 1}}, banshi{'liushui': {'P8': 15, 'P1': 383, 'm3': 18, 'M2': 8, 'm2': 2, 'P4': 1}}, roleType{'dan': {'P8': 15, 'P1': 383, 'm3': 18, 'M2': 8, 'm2': 2, 'P4': 1}}
# 	Couplet 1
# 	Opening line: 耳听得悲声惨心中如捣，
# 	Closing line: 同遇人为什么这样嚎啕。
#
#
# 	Couplet 2
# 	Opening line: 莫不是夫郎丑难谐女貌，
# 	Closing line: 莫不是强婚配鸦占鸾巢。
#
#
# 	Couplet 3
# 	Opening line: 叫梅香你把那好言相告，
# 	Closing line: 问那厢因何故痛哭无聊？
#
#
# 	Couplet 4
# 	Opening line: 梅香说话好颠倒，
# 	Closing line: 不该人前乱解嘲。
#
#
# 	Couplet 5
# 	Opening line: 怜贫济困是正道，
# 	Closing line: 哪有个袖手旁观在壁上瞧。
#
#
# 	Couplet 6
# 	Opening line: 蠢才问话太潦草，
# 	Closing line: 难免怀疑在心梢。
#
#
# 	Couplet 7
# 	Opening line: 你不该人前逞骄傲，
# 	Closing line: 不该词费又滔滔。
#
#
# 	Couplet 8
# 	Opening line: 休要噪且站了，
# 	Closing line: 薛良与我去问一遭。
#
#
# 	Couplet 9
# 	Opening line: 听薛良一语来相告，
# 	Closing line: 满腹骄矜顿雪潇。
#
#
# 	Couplet 10
# 	Opening line: 人情冷暖凭空造，
# 	Closing line: 谁能移动它半分毫。
#
#
# 	Couplet 11
# 	Opening line: 我正不足她正少，
# 	Closing line: 她为饥寒我为骄。
#
#
# 	Couplet 12
# 	Opening line: 分我一枝珊瑚宝，
# 	Closing line: 安她半世凤凰剿。
#
#
# 	Couplet 13
# 	Opening line: 忙把梅香低声叫，
# 	Closing line: 莫把姓名你信口哓。
#
#
# 	Couplet 14
# 	Opening line: 这都是神话凭空造，
# 	Closing line: 自把珠玉夸富豪。
#
#
# 	Couplet 15
# 	Opening line: 麟儿哪有神送到，
# 	Closing line: 积德才生玉树苗。
#
#
# 	Couplet 16
# 	Opening line: 小小囊儿何足道，
# 	Closing line: 救她饥渴胜琼瑶。
#
#
# Score daxp-FeiShiWo-TaoHuaCun.xml containing 9 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 11, 'm10': 1, 'm7': 1, 'P1': 294, 'm3': 20, 'P5': 1, 'M2': 16, 'm6': 2, 'm2': 6, 'P4': 4, 'M3': 2}}, banshi{'liushui': {'P8': 11, 'm10': 1, 'm7': 1, 'P1': 294, 'm3': 20, 'P5': 1, 'M2': 16, 'm6': 2, 'm2': 6, 'P4': 4, 'M3': 2}}, roleType{'dan': {'P8': 11, 'm10': 1, 'm7': 1, 'P1': 294, 'm3': 20, 'P5': 1, 'M2': 16, 'm6': 2, 'm2': 6, 'P4': 4, 'M3': 2}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 10, 'P1': 267, 'P5': 1, 'm6': 1, 'm3': 3, 'm2': 2, 'M2': 1, 'P4': 1}}, banshi{'liushui': {'P8': 10, 'P1': 267, 'P5': 1, 'm6': 1, 'm3': 3, 'm2': 2, 'M2': 1, 'P4': 1}}, roleType{'dan': {'P8': 10, 'P1': 267, 'P5': 1, 'm6': 1, 'm3': 3, 'm2': 2, 'M2': 1, 'P4': 1}}
# 	Couplet 1
# 	Opening line: 非是我嘱咐叮咛把话讲，
# 	Closing line: 只怪你呆头呆脑慌慌张张。
#
#
# 	Couplet 2
# 	Opening line: 今夜晚非比那西厢待月、你懂提防、莫轻狂，
# 	Closing line: 关系你患难鸳鸯永宿在池塘。
#
#
# 	Couplet 3
# 	Opening line: 已然错请生波浪，
# 	Closing line: 怎能够粗心大意你再荒唐。
#
#
# 	Couplet 4
# 	Opening line: 鼓打二更准时往，
# 	Closing line: 桃花村口莫彷徨。
#
#
# 	Couplet 5
# 	Opening line: 你不要高声不要嚷，
# 	Closing line: 你必须眼观六路耳听八方。
#
#
# 	Couplet 6
# 	Opening line: 不但要仔细听、还要仔细想，
# 	Closing line: 是不是有人拍巴掌。
#
#
# 	Couplet 7
# 	Opening line: 响一声你就还一掌，
# 	Closing line: 响两声你就凑近身旁。
#
#
# 	Couplet 8
# 	Opening line: 倘若是你响她也响，
# 	Closing line: 那就是来了我西厢带路的小红娘。
#
#
# 	Couplet 9
# 	Opening line: 你把我当做诸葛亮，
# 	Closing line: 听我的号令上战场。
#
#
# Score daxp-LaoDieDie-DaYuShaJia-2.xml containing 2 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 88, 'm10': 1, 'P8': 51, 'm7': 6, 'm3': 7, 'P4': 3, 'M2': 8, 'm6': 2, 'M6': 1, 'P5': 1}}, banshi{'yuanban': {'P1': 88, 'm10': 1, 'P8': 51, 'm7': 6, 'm3': 7, 'P4': 3, 'M2': 8, 'm6': 2, 'M6': 1, 'P5': 1}}, roleType{'dan': {'P1': 88, 'm10': 1, 'P8': 51, 'm7': 6, 'm3': 7, 'P4': 3, 'M2': 8, 'm6': 2, 'M6': 1, 'P5': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 76, 'm10': 1, 'P8': 42, 'm3': 2, 'm6': 1, 'P4': 1}}, banshi{'yuanban': {'P1': 76, 'm10': 1, 'P8': 42, 'm3': 2, 'm6': 1, 'P4': 1}}, roleType{'dan': {'P1': 76, 'm10': 1, 'P8': 42, 'm3': 2, 'm6': 1, 'P4': 1}}
# 	Couplet 1
# 	Opening line: 老爹爹清晨起前去出首，
# 	Closing line: 倒叫我桂英儿挂在心头。
#
#
# 	Couplet 2
# 	Opening line: 将身儿坐至在草堂等候，
# 	Closing line: 等候了爹爹回细问根由。
#
#
# Score daxp-LaoDieDie-SanJiZhang-1.xml containing 2 couplets
# Voice staves: [0]
# Instrumental staves: [1]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 174, 'P8': 79, 'M6': 5, 'P5': 3, 'P4': 4, 'M9': 6, 'm7': 8, 'm3': 13, 'M2': 14, 'm10': 4, 'M3': 6, 'm2': 3, 'm6': 1}}, banshi{'manban': {'P1': 174, 'P8': 79, 'M6': 5, 'P5': 3, 'P4': 4, 'M9': 6, 'm7': 8, 'm3': 13, 'M2': 14, 'm10': 4, 'M3': 6, 'm2': 3, 'm6': 1}}, roleType{'dan': {'P1': 174, 'P8': 79, 'M6': 5, 'P5': 3, 'P4': 4, 'M9': 6, 'm7': 8, 'm3': 13, 'M2': 14, 'm10': 4, 'M3': 6, 'm2': 3, 'm6': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 157, 'P8': 61, 'M6': 2, 'm3': 3, 'M3': 3, 'M2': 2, 'm2': 1, 'm6': 1}}, banshi{'manban': {'P1': 157, 'P8': 61, 'M6': 2, 'm3': 3, 'M3': 3, 'M2': 2, 'm2': 1, 'm6': 1}}, roleType{'dan': {'P1': 157, 'P8': 61, 'M6': 2, 'm3': 3, 'M3': 3, 'M2': 2, 'm2': 1, 'm6': 1}}
# 	Couplet 1
# 	Opening line: 老爹爹请息（呀）怒容儿细讲，
# 	Closing line: 我立志不嫁那状元才郎。
#
#
# 	Couplet 2
# 	Opening line: 父休笑薛平贵是花郎模样，
# 	Closing line: 贫穷人得了志比富还强。
#
#
# Score daxp-LaoDieDie-YuZhouFeng.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 97, 'P8': 44, 'm7': 9, 'P5': 8, 'P11': 1, 'm10': 1, 'm3': 6, 'M7': 1, 'M2': 12, 'M6': 6, 'm6': 2, 'M3': 1, 'P4': 5, 'm2': 1}}, banshi{'yuanban': {'P1': 97, 'P8': 44, 'm7': 9, 'P5': 8, 'P11': 1, 'm10': 1, 'm3': 6, 'M7': 1, 'M2': 12, 'M6': 6, 'm6': 2, 'M3': 1, 'P4': 5, 'm2': 1}}, roleType{'dan': {'P1': 97, 'P8': 44, 'm7': 9, 'P5': 8, 'P11': 1, 'm10': 1, 'm3': 6, 'M7': 1, 'M2': 12, 'M6': 6, 'm6': 2, 'M3': 1, 'P4': 5, 'm2': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 81, 'P8': 41, 'm7': 3, 'M6': 2, 'm3': 1, 'P4': 3, 'M2': 1}}, banshi{'yuanban': {'P1': 81, 'P8': 41, 'm7': 3, 'M6': 2, 'm3': 1, 'P4': 3, 'M2': 1}}, roleType{'dan': {'P1': 81, 'P8': 41, 'm7': 3, 'M6': 2, 'm3': 1, 'P4': 3, 'M2': 1}}
# 	Couplet 1
# 	Opening line: 老爹爹发恩德将本修上，
# 	Closing line: 明早朝上金殿面奏吾皇。
#
#
# 	Couplet 2
# 	Opening line: 倘若是有道君皇恩浩荡，
# 	Closing line: 观此本免了儿一门祸殃。
#
#
# 	Couplet 3
# 	Opening line: 老爹爹在朝中官高爵显，
# 	Closing line: 却为何贪富贵不顾羞惭。
#
#
# Score daxp-MengJunZi-ChunQiuPei-1.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 186, 'P8': 77, 'm10': 2, 'M6': 5, 'M9': 1, 'M2': 13, 'P4': 4, 'm2': 4, 'P5': 3, 'M3': 2, 'm7': 4, 'm3': 4}}, banshi{'yuanban': {'P1': 186, 'P8': 77, 'm10': 2, 'M6': 5, 'M9': 1, 'M2': 13, 'P4': 4, 'm2': 4, 'P5': 3, 'M3': 2, 'm7': 4, 'm3': 4}}, roleType{'dan': {'P1': 186, 'P8': 77, 'm10': 2, 'M6': 5, 'M9': 1, 'M2': 13, 'P4': 4, 'm2': 4, 'P5': 3, 'M3': 2, 'm7': 4, 'm3': 4}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 179, 'P8': 74, 'M6': 4, 'm2': 3, 'M2': 1, 'm3': 1, 'M3': 1}}, banshi{'yuanban': {'P1': 179, 'P8': 74, 'M6': 4, 'm2': 3, 'M2': 1, 'm3': 1, 'M3': 1}}, roleType{'dan': {'P1': 179, 'P8': 74, 'M6': 4, 'm2': 3, 'M2': 1, 'm3': 1, 'M3': 1}}
# 	Couplet 1
# 	Opening line: 蒙君子至殷勤再三问话，
# 	Closing line: 虽然是男女别不得不答。
#
#
# 	Couplet 2
# 	Opening line: 家住在罗郡城魁星楼下，
# 	Closing line: 我的父名姜绍贸易天涯。
#
#
# 	Couplet 3
# 	Opening line: 在家中受不过继母拷打，
# 	Closing line: 莫奈何到荒郊我就来捡芦花。
#
#
# Score daxp-MengJunZi-ChunQiuPei-2.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 36, 'M9': 2, 'm7': 9, 'M6': 15, 'P5': 7, 'P1': 189, 'M2': 19, 'm3': 26, 'm6': 3, 'P4': 7, 'm2': 6, 'M3': 4, 'm10': 1}}, banshi{'yuanban': {'P8': 36, 'M9': 2, 'm7': 9, 'M6': 15, 'P5': 7, 'P1': 189, 'M2': 19, 'm3': 26, 'm6': 3, 'P4': 7, 'm2': 6, 'M3': 4, 'm10': 1}}, roleType{'dan': {'P8': 36, 'M9': 2, 'm7': 9, 'M6': 15, 'P5': 7, 'P1': 189, 'M2': 19, 'm3': 26, 'm6': 3, 'P4': 7, 'm2': 6, 'M3': 4, 'm10': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 31, 'm7': 5, 'M6': 6, 'M9': 1, 'P1': 146, 'M2': 6, 'm3': 9, 'P4': 3}}, banshi{'yuanban': {'P8': 31, 'm7': 5, 'M6': 6, 'M9': 1, 'P1': 146, 'M2': 6, 'm3': 9, 'P4': 3}}, roleType{'dan': {'P8': 31, 'm7': 5, 'M6': 6, 'M9': 1, 'P1': 146, 'M2': 6, 'm3': 9, 'P4': 3}}
# 	Couplet 1
# 	Opening line: 蒙君子至诚心再三问话，
# 	Closing line: 虽然是不相识我就不得不答。
#
#
# 	Couplet 2
# 	Opening line: 家住在罗郡城魁星楼下，
# 	Closing line: 我爹爹名姜绍贸易天涯。
#
#
# 	Couplet 3
# 	Opening line: 身有病还受那继母拷打，
# 	Closing line: 因此上到郊外来捡芦花（呀）。
#
#
# Score daxp-MengTingDe-MuiGuiYingGuaShuai.xml containing 4 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 2, 'm7': 2, 'P1': 97, 'm3': 10, 'M2': 10, 'm2': 1, 'P4': 1, 'M3': 1}}, banshi{'liushui': {'P8': 2, 'm7': 2, 'P1': 97, 'm3': 10, 'M2': 10, 'm2': 1, 'P4': 1, 'M3': 1}}, roleType{'dan': {'P8': 2, 'm7': 2, 'P1': 97, 'm3': 10, 'M2': 10, 'm2': 1, 'P4': 1, 'M3': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 2, 'P1': 85, 'm3': 4, 'M2': 2}}, banshi{'liushui': {'P8': 2, 'P1': 85, 'm3': 4, 'M2': 2}}, roleType{'dan': {'P8': 2, 'P1': 85, 'm3': 4, 'M2': 2}}
# 	Couplet 1
# 	Opening line: 猛听得金鼓响画角声震，
# 	Closing line: 唤起我破天门状志凌云。
#
#
# 	Couplet 2
# 	Opening line: 想当年桃花马上威风凛凛，
# 	Closing line: 敌血飞溅石榴裙。
#
#
# 	Couplet 3
# 	Opening line: 有生之日责当尽，
# 	Closing line: 寸土怎能够属于他人。
#
#
# 	Couplet 4
# 	Opening line: 番王小丑何足论，
# 	Closing line: 我一剑能挡百万兵。
#
#
# Score daxp-MuQinBu-FengHuanChao.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 67, 'M2': 3, 'm3': 2, 'P4': 1, 'm6': 1, 'P5': 2}}, banshi{'liushui': {'P1': 67, 'M2': 3, 'm3': 2, 'P4': 1, 'm6': 1, 'P5': 2}}, roleType{'dan': {'P1': 67, 'M2': 3, 'm3': 2, 'P4': 1, 'm6': 1, 'P5': 2}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 64, 'P5': 2, 'M2': 1}}, banshi{'liushui': {'P1': 64, 'P5': 2, 'M2': 1}}, roleType{'dan': {'P1': 64, 'P5': 2, 'M2': 1}}
# 	Couplet 1
# 	Opening line: 母亲不必心太偏，
# 	Closing line: 女儿言来听根源。
#
#
# 	Couplet 2
# 	Opening line: 自古常言道得好，
# 	Closing line: 女儿清白最为先。
#
#
# 	Couplet 3
# 	Opening line: 人生不知顾脸面，
# 	Closing line: 活在世上也枉然。
#
#
# Score daxp-QiaoLouShang-HuangShanLei.xml containing 8 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 638, 'M2': 60, 'm3': 48, 'P8': 178, 'm7': 23, 'm10': 8, 'M9': 8, 'M6': 15, 'P4': 9, 'P5': 4, 'm6': 5, 'M3': 7, 'M7': 2, 'm2': 5}}, banshi{'manban': {'P1': 218, 'M2': 19, 'm3': 17, 'P8': 80, 'm7': 9, 'm10': 3, 'M9': 7, 'M6': 5, 'P4': 3, 'P5': 2, 'm6': 4, 'M3': 1, 'M7': 1}, 'yuanban': {'P1': 272, 'M2': 25, 'm3': 16, 'P8': 69, 'm7': 8, 'M6': 7, 'm10': 4, 'M3': 1, 'P4': 2, 'm2': 3, 'M9': 1, 'M7': 1}, 'erliu': {'P1': 148, 'm3': 15, 'M2': 16, 'M3': 5, 'P4': 4, 'P8': 29, 'm7': 6, 'M6': 3, 'm10': 1, 'm6': 1, 'm2': 2, 'P5': 2}}, roleType{'dan': {'P1': 638, 'M2': 60, 'm3': 48, 'P8': 178, 'm7': 23, 'm10': 8, 'M9': 8, 'M6': 15, 'P4': 9, 'P5': 4, 'm6': 5, 'M3': 7, 'M7': 2, 'm2': 5}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 564, 'P8': 137, 'm7': 6, 'M2': 10, 'm10': 1, 'm3': 14, 'P5': 1, 'm6': 2, 'M3': 2, 'M6': 2, 'M7': 2, 'M9': 1}}, banshi{'manban': {'P1': 187, 'P8': 50, 'm7': 1, 'M2': 4, 'm10': 1, 'm3': 6, 'P5': 1, 'm6': 2, 'M3': 1, 'M6': 1, 'M7': 1}, 'yuanban': {'P1': 247, 'P8': 61, 'm3': 2, 'M9': 1, 'm7': 3, 'M2': 4, 'M7': 1}, 'erliu': {'P1': 130, 'm3': 6, 'P8': 26, 'm7': 2, 'M3': 1, 'M6': 1, 'M2': 2}}, roleType{'dan': {'P1': 564, 'P8': 137, 'm7': 6, 'M2': 10, 'm10': 1, 'm3': 14, 'P5': 1, 'm6': 2, 'M3': 2, 'M6': 2, 'M7': 2, 'M9': 1}}
# 	Couplet 1
# 	Opening line: 谯楼上二更鼓声声送听，
# 	Closing line: 父子们去采药未见回程。
#
#
# 	Couplet 2
# 	Opening line: 对孤灯思远道心神不定，
# 	Closing line: 不知他在荒山何处安身。
#
#
# 	Couplet 3
# 	Opening line: 到三更真个是月明人静，
# 	Closing line: 猛听得窗儿外似有人行。
#
#
# 	Couplet 4
# 	Opening line: 忙移步隔花荫留神听定，
# 	Closing line: 原来是秋风起扫叶之声。
#
#
# 	Couplet 5
# 	Opening line: 听画鼓报四更愈添凄冷，
# 	Closing line: 看娇儿正酣睡恐被风侵。
#
#
# 	Couplet 6
# 	Opening line: 我不免引寒机伴奴坐等，
# 	Closing line: 又思来又想去越不安宁。
#
#
# 	Couplet 7
# 	Opening line: 数更等交五鼓空房愈冷，
# 	Closing line: 果然是晓鸡唱天已黎明。
#
#
# 	Couplet 8
# 	Opening line: 我不免唤琏儿到街前探问，
# 	Closing line: 你爹爹到如今未转家门。
#
#
# Score daxp-SuSanLi-NvQiJie.xml containing 4 couplets
# Voice staves: [0]
# Instrumental staves: [1]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 2, 'm7': 2, 'P1': 79, 'P5': 1, 'M2': 10, 'm3': 20, 'P4': 11, 'm6': 4, 'm10': 1, 'm2': 2}}, banshi{'liushui': {'P8': 2, 'm7': 2, 'P1': 79, 'P5': 1, 'M2': 10, 'm3': 20, 'P4': 11, 'm6': 4, 'm10': 1, 'm2': 2}}, roleType{'dan': {'P8': 2, 'm7': 2, 'P1': 79, 'P5': 1, 'M2': 10, 'm3': 20, 'P4': 11, 'm6': 4, 'm10': 1, 'm2': 2}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 2, 'P1': 63, 'P5': 1, 'm3': 10, 'm6': 1, 'm10': 1, 'P4': 3}}, banshi{'liushui': {'P8': 2, 'P1': 63, 'P5': 1, 'm3': 10, 'm6': 1, 'm10': 1, 'P4': 3}}, roleType{'dan': {'P8': 2, 'P1': 63, 'P5': 1, 'm3': 10, 'm6': 1, 'm10': 1, 'P4': 3}}
# 	Couplet 1
# 	Opening line: 苏三离了洪洞县，
# 	Closing line: 将身来在大街前。
#
#
# 	Couplet 2
# 	Opening line: 未曾开言心内惨，
# 	Closing line: 过往的君子听我言。
#
#
# 	Couplet 3
# 	Opening line: 哪一位去往南京转，
# 	Closing line: 与我那三郎把信传。
#
#
# 	Couplet 4
# 	Opening line: 言说苏三把命断，
# 	Closing line: 来生变犬马我当报还！
#
#
# Score daxp-TingTaYan-ZuoGong.xml containing 4 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'m7': 8, 'P8': 9, 'm10': 1, 'P1': 116, 'm3': 17, 'P4': 6, 'M2': 13, 'm2': 1, 'M3': 1}}, banshi{'liushui': {'m7': 8, 'P8': 9, 'm10': 1, 'P1': 116, 'm3': 17, 'P4': 6, 'M2': 13, 'm2': 1, 'M3': 1}}, roleType{'dan': {'m7': 8, 'P8': 9, 'm10': 1, 'P1': 116, 'm3': 17, 'P4': 6, 'M2': 13, 'm2': 1, 'M3': 1}}
# IntervalsPS: shengqiang:{'xipi': {'m7': 2, 'P8': 7, 'P1': 105, 'm3': 4, 'M2': 2, 'm2': 1, 'P4': 2}}, banshi{'liushui': {'m7': 2, 'P8': 7, 'P1': 105, 'm3': 4, 'M2': 2, 'm2': 1, 'P4': 2}}, roleType{'dan': {'m7': 2, 'P8': 7, 'P1': 105, 'm3': 4, 'M2': 2, 'm2': 1, 'P4': 2}}
# 	Couplet 1
# 	Opening line: 听他言吓得我浑身是汗，
# 	Closing line: 十五载到今日才吐真言。
#
#
# 	Couplet 2
# 	Opening line: 原来是杨家将把名姓改换，
# 	Closing line: 他思家乡想骨肉就不能团圆。
#
#
# 	Couplet 3
# 	Opening line: 我这里走向前再把礼见，
# 	Closing line: 尊一声驸马爷细听咱言。
#
#
# 	Couplet 4
# 	Opening line: 早晚间休怪我言语怠慢，
# 	Closing line: 不知者不怪罪你的海量放宽。
#
#
# Score daxp-WoZhuYe-SiLangTanMu.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 78, 'm7': 14, 'P5': 5, 'M2': 32, 'M6': 6, 'P4': 16, 'm10': 4, 'P1': 342, 'm3': 16, 'm6': 5, 'm2': 2, 'M3': 3}}, banshi{'manban': {'P8': 78, 'm7': 14, 'P5': 5, 'M2': 31, 'M6': 6, 'P4': 14, 'm10': 4, 'P1': 342, 'm3': 14, 'm6': 4, 'm2': 2, 'M3': 3}, 'yaoban': {'m3': 2, 'P4': 2, 'm6': 1, 'M2': 1}}, roleType{'dan': {'P8': 78, 'm7': 14, 'P5': 5, 'M2': 32, 'M6': 6, 'P4': 16, 'm10': 4, 'P1': 342, 'm3': 16, 'm6': 5, 'm2': 2, 'M3': 3}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 52, 'm7': 6, 'P1': 271, 'M2': 8, 'P4': 2, 'm10': 1, 'm6': 4, 'm3': 4, 'M3': 1}}, banshi{'manban': {'P8': 52, 'm7': 6, 'P1': 271, 'M2': 7, 'P4': 2, 'm10': 1, 'm6': 3, 'm3': 3, 'M3': 1}, 'yaoban': {'m3': 1, 'm6': 1, 'M2': 1}}, roleType{'dan': {'P8': 52, 'm7': 6, 'P1': 271, 'M2': 8, 'P4': 2, 'm10': 1, 'm6': 4, 'm3': 4, 'M3': 1}}
# 	Couplet 1
# 	Opening line: 我主爷金沙滩早把命丧，
# 	Closing line: 众文武扶哀家执掌军房。
#
#
# 	Couplet 2
# 	Opening line: 众卿随忙挂点亲率官员，
# 	Closing line: 一心心要夺取宋室江山。
#
#
# 	Couplet 3
# 	Opening line: 叫番儿忙摆驾银安殿，
# 	Closing line: 阅兵书看何人前来何安。
#
#
# Score daxp-XiRiLi-LongFengChengXiang.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 165, 'M6': 12, 'M2': 47, 'P1': 323, 'P5': 4, 'P4': 13, 'M9': 8, 'm7': 17, 'm2': 11, 'm3': 21, 'M3': 10, 'M7': 2, 'm10': 1, 'm6': 2, 'm9': 1, 'P11': 1}}, banshi{'manban': {'P8': 165, 'M6': 12, 'M2': 47, 'P1': 323, 'P5': 4, 'P4': 13, 'M9': 8, 'm7': 17, 'm2': 11, 'm3': 21, 'M3': 10, 'M7': 2, 'm10': 1, 'm6': 2, 'm9': 1, 'P11': 1}}, roleType{'dan': {'P8': 165, 'M6': 12, 'M2': 47, 'P1': 323, 'P5': 4, 'P4': 13, 'M9': 8, 'm7': 17, 'm2': 11, 'm3': 21, 'M3': 10, 'M7': 2, 'm10': 1, 'm6': 2, 'm9': 1, 'P11': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 115, 'P1': 220, 'm3': 8, 'M2': 9, 'M9': 2, 'm2': 6, 'P4': 3, 'm7': 2, 'M3': 3, 'P11': 1, 'M6': 1}}, banshi{'manban': {'P8': 115, 'P1': 220, 'm3': 8, 'M2': 9, 'M9': 2, 'm2': 6, 'P4': 3, 'm7': 2, 'M3': 3, 'P11': 1, 'M6': 1}}, roleType{'dan': {'P8': 115, 'P1': 220, 'm3': 8, 'M2': 9, 'M9': 2, 'm2': 6, 'P4': 3, 'm7': 2, 'M3': 3, 'P11': 1, 'M6': 1}}
# 	Couplet 1
# 	Opening line: 昔日里梁鸿配孟光，
# 	Closing line: 今朝仙女会襄王。
#
#
# 	Couplet 2
# 	Opening line: 暗地堪笑奴兄长，
# 	Closing line: 安排虎计害刘王。
#
#
# 	Couplet 3
# 	Opening line: 月老本是乔国丈，
# 	Closing line: 纵有大事料无妨。
#
#
# Score daxp-XiRiLiang-LongFengChengXiang.xml containing 2 couplets
# Voice staves: [0]
# Instrumental staves: [1]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 102, 'm7': 10, 'P1': 177, 'P5': 4, 'P4': 4, 'm3': 7, 'M2': 6, 'M9': 3, 'M3': 2, 'M6': 4}}, banshi{'manban': {'P8': 102, 'm7': 10, 'P1': 177, 'P5': 4, 'P4': 4, 'm3': 7, 'M2': 6, 'M9': 3, 'M3': 2, 'M6': 4}}, roleType{'dan': {'P8': 102, 'm7': 10, 'P1': 177, 'P5': 4, 'P4': 4, 'm3': 7, 'M2': 6, 'M9': 3, 'M3': 2, 'M6': 4}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 79, 'm7': 2, 'P1': 157, 'm3': 2, 'M6': 2, 'M2': 1}}, banshi{'manban': {'P8': 79, 'm7': 2, 'P1': 157, 'm3': 2, 'M6': 2, 'M2': 1}}, roleType{'dan': {'P8': 79, 'm7': 2, 'P1': 157, 'm3': 2, 'M6': 2, 'M2': 1}}
# 	Couplet 1
# 	Opening line: 昔日梁鸿配孟光，
# 	Closing line: 今朝仙女会襄王。
#
#
# 	Couplet 2
# 	Opening line: 暗地堪笑我兄长，
# 	Closing line: 安排巧计害刘王。
#
#
# Score daxp-XiShiNv-XiShi.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P8': 94, 'P5': 10, 'M2': 67, 'M6': 12, 'P1': 352, 'P4': 16, 'm7': 16, 'm3': 28, 'M9': 5, 'M3': 3, 'm6': 6, 'm10': 2, 'm2': 6, 'd5': 1, 'M7': 1}}, banshi{'manban': {'P8': 94, 'P5': 10, 'M2': 67, 'M6': 12, 'P1': 352, 'P4': 16, 'm7': 16, 'm3': 28, 'M9': 5, 'M3': 3, 'm6': 6, 'm10': 2, 'm2': 6, 'd5': 1, 'M7': 1}}, roleType{'dan': {'P8': 94, 'P5': 10, 'M2': 67, 'M6': 12, 'P1': 352, 'P4': 16, 'm7': 16, 'm3': 28, 'M9': 5, 'M3': 3, 'm6': 6, 'm10': 2, 'm2': 6, 'd5': 1, 'M7': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P8': 72, 'P1': 250, 'P4': 1, 'M2': 11, 'M3': 1, 'm3': 6, 'm7': 3, 'M6': 2, 'M7': 1}}, banshi{'manban': {'P8': 72, 'P1': 250, 'P4': 1, 'M2': 11, 'M3': 1, 'm3': 6, 'm7': 3, 'M6': 2, 'M7': 1}}, roleType{'dan': {'P8': 72, 'P1': 250, 'P4': 1, 'M2': 11, 'M3': 1, 'm3': 6, 'm7': 3, 'M6': 2, 'M7': 1}}
# 	Couplet 1
# 	Opening line: 西施女生长在苎萝村里，
# 	Closing line: 难得有开怀事常锁双眉。
#
#
# 	Couplet 2
# 	Opening line: 只为着守清寒柴门近水，
# 	Closing line: 每日里浣纱去又傍清溪。
#
#
# 	Couplet 3
# 	Opening line: 怕只怕损玉颜姣容自惜，
# 	Closing line: 对清溪时照影自整罗农。
#
#
# Score dldeh-ShouBiPo-ChunQiuPei.xml containing 3 couplets
# Voice staves: [1, 2]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P8': 352, 'm7': 65, 'm10': 9, 'm6': 12, 'M9': 36, 'P5': 24, 'M6': 27, 'P1': 120, 'P4': 17, 'M3': 3, 'P11': 2, 'm3': 15, 'M2': 28, 'm2': 4, 'P12': 5, 'A4': 1, 'm9': 1, 'M13': 1, 'M10': 1, 'd5': 1}}, banshi{'manban': {'P8': 346, 'm7': 65, 'm10': 9, 'm6': 12, 'M9': 36, 'P5': 21, 'M6': 26, 'P1': 43, 'P4': 11, 'M3': 3, 'P11': 2, 'm3': 6, 'M2': 11, 'm2': 3, 'P12': 5, 'A4': 1, 'm9': 1, 'M13': 1, 'M10': 1}, 'sanyan': {'P1': 77, 'P5': 3, 'm3': 9, 'M2': 17, 'P4': 6, 'm2': 1, 'P8': 6, 'M6': 1, 'd5': 1}}, roleType{'dan': {'P8': 346, 'm7': 65, 'm10': 9, 'm6': 12, 'M9': 36, 'P5': 21, 'M6': 26, 'P1': 43, 'P4': 11, 'M3': 3, 'P11': 2, 'm3': 6, 'M2': 11, 'm2': 3, 'P12': 5, 'A4': 1, 'm9': 1, 'M13': 1, 'M10': 1}, 'laodan': {'P1': 77, 'P5': 3, 'm3': 9, 'M2': 17, 'P4': 6, 'm2': 1, 'P8': 6, 'M6': 1, 'd5': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P8': 279, 'm7': 9, 'P1': 96, 'M9': 6, 'm6': 3, 'M3': 1, 'm10': 1, 'M2': 9, 'm2': 4, 'P5': 2, 'M6': 4, 'P4': 7, 'm3': 3, 'd5': 1}}, banshi{'manban': {'P8': 275, 'm7': 9, 'P1': 31, 'M9': 6, 'm6': 3, 'M3': 1, 'm10': 1, 'M2': 5, 'm2': 3, 'P5': 1, 'M6': 3, 'P4': 1}, 'sanyan': {'P1': 65, 'm3': 3, 'M2': 4, 'P4': 6, 'm2': 1, 'P8': 4, 'M6': 1, 'd5': 1, 'P5': 1}}, roleType{'dan': {'P8': 275, 'm7': 9, 'P1': 31, 'M9': 6, 'm6': 3, 'M3': 1, 'm10': 1, 'M2': 5, 'm2': 3, 'P5': 1, 'M6': 3, 'P4': 1}, 'laodan': {'P1': 65, 'm3': 3, 'M2': 4, 'P4': 6, 'm2': 1, 'P8': 4, 'M6': 1, 'd5': 1, 'P5': 1}}
# 	Couplet 1
# 	Opening line: 受逼迫去捡柴泪如雨下，
# 	Closing line: 病恹恹身无力难以挣扎。
#
#
# 	Couplet 2
# 	Opening line: 奴好比花未开风吹雨打，
# 	Closing line: 想亲娘和老父心乱如麻。
#
#
# 	Couplet 3
# 	Opening line: 你继母心毒狠将你打骂，
# 	Closing line: 全（呐）不顾你身有病气力不佳。
#
#
# Score lseh-LaoZhangBu-WuPenJi.xml containing 4 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 222, 'm3': 14, 'M2': 55, 'M6': 2, 'P5': 3, 'P8': 13, 'M3': 7, 'P4': 7, 'm2': 1, 'm7': 3}}, banshi{'yuanban': {'P1': 222, 'm3': 14, 'M2': 55, 'M6': 2, 'P5': 3, 'P8': 13, 'M3': 7, 'P4': 7, 'm2': 1, 'm7': 3}}, roleType{'laosheng': {'P1': 222, 'm3': 14, 'M2': 55, 'M6': 2, 'P5': 3, 'P8': 13, 'M3': 7, 'P4': 7, 'm2': 1, 'm7': 3}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 176, 'M2': 18, 'M6': 2, 'm3': 7, 'P5': 2, 'P8': 10, 'M3': 6, 'm2': 1, 'm7': 1, 'P4': 2}}, banshi{'yuanban': {'P1': 176, 'M2': 18, 'M6': 2, 'm3': 7, 'P5': 2, 'P8': 10, 'M3': 6, 'm2': 1, 'm7': 1, 'P4': 2}}, roleType{'laosheng': {'P1': 176, 'M2': 18, 'M6': 2, 'm3': 7, 'P5': 2, 'P8': 10, 'M3': 6, 'm2': 1, 'm7': 1, 'P4': 2}}
# 	Couplet 1
# 	Opening line: 老丈不（哇）必胆怕惊，
# 	Closing line: 我有言来你是（喏）听。
#
#
# 	Couplet 2
# 	Opening line: 休把我当作了妖魔论，
# 	Closing line: 我本屈死一鬼魂。
#
#
# 	Couplet 3
# 	Opening line: 我忙将树（呃）枝摆摇（哇）动，
# 	Closing line: 抓一（呀）把沙土扬灰尘。
#
#
# 	Couplet 4
# 	Opening line: 我和你远无冤近无有仇恨，
# 	Closing line: 望求老丈把冤伸。
#
#
# Score lseh-NiangZiBu-SouGuJiuGu.xml containing 7 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 257, 'M2': 64, 'm3': 21, 'P4': 15, 'P8': 17, 'M3': 12, 'P5': 9, 'M6': 6, 'm2': 1, 'm9': 1, 'm10': 1}}, banshi{'yuanban': {'P1': 257, 'M2': 64, 'm3': 21, 'P4': 15, 'P8': 17, 'M3': 12, 'P5': 9, 'M6': 6, 'm2': 1, 'm9': 1, 'm10': 1}}, roleType{'laosheng': {'P1': 257, 'M2': 64, 'm3': 21, 'P4': 15, 'P8': 17, 'M3': 12, 'P5': 9, 'M6': 6, 'm2': 1, 'm9': 1, 'm10': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 213, 'M2': 9, 'P8': 15, 'M3': 2, 'P4': 9, 'P5': 7, 'M6': 5, 'm3': 5, 'm9': 1}}, banshi{'yuanban': {'P1': 213, 'M2': 9, 'P8': 15, 'M3': 2, 'P4': 9, 'P5': 7, 'M6': 5, 'm3': 5, 'm9': 1}}, roleType{'laosheng': {'P1': 213, 'M2': 9, 'P8': 15, 'M3': 2, 'P4': 9, 'P5': 7, 'M6': 5, 'm3': 5, 'm9': 1}}
# 	Couplet 1
# 	Opening line: 娘子不（哇）必太烈性，
# 	Closing line: 卑（呀）人言来你是（喏）听。
#
#
# 	Couplet 2
# 	Opening line: 赵屠二家有仇恨，
# 	Closing line: 三百余口命赴幽冥。
#
#
# 	Couplet 3
# 	Opening line: 我与那公孙杵臼把计定，
# 	Closing line: 他舍命来你我舍亲生。
#
#
# 	Couplet 4
# 	Opening line: 舍子搭救忠（呃）良的后，
# 	Closing line: 老天爷不绝我的后代根。
#
#
# 	Couplet 5
# 	Opening line: 你今舍了亲生子，
# 	Closing line: 来年必定降麒麟。
#
#
# 	Couplet 6
# 	Opening line: 千言万（哪）语她不肯，
# 	Closing line: 不舍娇儿难救孤身。
#
#
# 	Couplet 7
# 	Opening line: 无奈何我只得双（呃）膝跪，
# 	Closing line: 哀求娘子（喏）舍亲（呐）生。
#
#
# Score lseh-TanXiongDi-SangYuanJiZi.xml containing 2 couplets
# Voice staves: [0]
# Instrumental staves: [1]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 171, 'm3': 14, 'P5': 12, 'M2': 43, 'P4': 10, 'P8': 16, 'M6': 10, 'M3': 5, 'm10': 2, 'm7': 3}}, banshi{'manban': {'P1': 171, 'm3': 14, 'P5': 12, 'M2': 43, 'P4': 10, 'P8': 16, 'M6': 10, 'M3': 5, 'm10': 2, 'm7': 3}}, roleType{'laosheng': {'P1': 171, 'm3': 14, 'P5': 12, 'M2': 43, 'P4': 10, 'P8': 16, 'M6': 10, 'M3': 5, 'm10': 2, 'm7': 3}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 136, 'M2': 2, 'P8': 14, 'P4': 6, 'M3': 1, 'M6': 5, 'm7': 2, 'm3': 3}}, banshi{'manban': {'P1': 136, 'M2': 2, 'P8': 14, 'P4': 6, 'M3': 1, 'M6': 5, 'm7': 2, 'm3': 3}}, roleType{'laosheng': {'P1': 136, 'M2': 2, 'P8': 14, 'P4': 6, 'M3': 1, 'M6': 5, 'm7': 2, 'm3': 3}}
# 	Couplet 1
# 	Opening line: 叹兄兀弟遭不幸一旦丧命，
# 	Closing line: 丢下了年幼儿好不伤情。
#
#
# 	Couplet 2
# 	Opening line: 眼望着孤坟台珠泪难忍，
# 	Closing line: 见坟台不见人刀割我心。
#
#
# Score lseh-WeiGuoJia-HongYangDong-1.xml containing 2 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 163, 'P5': 4, 'M2': 37, 'm3': 11, 'm2': 1, 'M3': 1, 'P4': 6, 'M6': 3, 'P8': 10, 'm9': 1}}, banshi{'yuanban': {'P1': 163, 'P5': 4, 'M2': 37, 'm3': 11, 'm2': 1, 'M3': 1, 'P4': 6, 'M6': 3, 'P8': 10, 'm9': 1}}, roleType{'laosheng': {'P1': 163, 'P5': 4, 'M2': 37, 'm3': 11, 'm2': 1, 'M3': 1, 'P4': 6, 'M6': 3, 'P8': 10, 'm9': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 141, 'M2': 14, 'm3': 6, 'P5': 2, 'm2': 1, 'P4': 5, 'M6': 3, 'P8': 6}}, banshi{'yuanban': {'P1': 141, 'M2': 14, 'm3': 6, 'P5': 2, 'm2': 1, 'P4': 5, 'M6': 3, 'P8': 6}}, roleType{'laosheng': {'P1': 141, 'M2': 14, 'm3': 6, 'P5': 2, 'm2': 1, 'P4': 5, 'M6': 3, 'P8': 6}}
# 	Couplet 1
# 	Opening line: 为国家那何曾半日闲空，
# 	Closing line: 我也曾平服了塞北西东。
#
#
# 	Couplet 2
# 	Opening line: 官封到节度使（喏）皇王恩重，
# 	Closing line: 身不爽不由人瞌睡朦胧（呃）。
#
#
# Score lseh-WeiGuoJia-HongYangDong-3.xml containing 2 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 168, 'P4': 11, 'M2': 41, 'm3': 12, 'M3': 9, 'M6': 2, 'P5': 1, 'm6': 1, 'P8': 6, 'm7': 1}}, banshi{'yuanban': {'P1': 168, 'P4': 11, 'M2': 41, 'm3': 12, 'M3': 9, 'M6': 2, 'P5': 1, 'm6': 1, 'P8': 6, 'm7': 1}}, roleType{'laosheng': {'P1': 168, 'P4': 11, 'M2': 41, 'm3': 12, 'M3': 9, 'M6': 2, 'P5': 1, 'm6': 1, 'P8': 6, 'm7': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 129, 'P4': 4, 'M2': 12, 'M6': 2, 'P5': 1, 'm6': 1, 'M3': 4, 'm3': 3, 'P8': 5}}, banshi{'yuanban': {'P1': 129, 'P4': 4, 'M2': 12, 'M6': 2, 'P5': 1, 'm6': 1, 'M3': 4, 'm3': 3, 'P8': 5}}, roleType{'laosheng': {'P1': 129, 'P4': 4, 'M2': 12, 'M6': 2, 'P5': 1, 'm6': 1, 'M3': 4, 'm3': 3, 'P8': 5}}
# 	Couplet 1
# 	Opening line: 为国家哪何曾半日闲空，
# 	Closing line: 我也曾平服了塞北西东。
#
#
# 	Couplet 2
# 	Opening line: 官封到节度史（喏）皇王恩重，
# 	Closing line: 身不爽不由人瞌睡朦胧。
#
#
# Score lseh-WeiKaiYan-RangXuZhou.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 178, 'M2': 44, 'm3': 24, 'P8': 23, 'P4': 6, 'M3': 3, 'm2': 3, 'P5': 4, 'm6': 1, 'm10': 2, 'M6': 3, 'm7': 1, 'M7': 1}}, banshi{'yuanban': {'P1': 178, 'M2': 44, 'm3': 24, 'P8': 23, 'P4': 6, 'M3': 3, 'm2': 3, 'P5': 4, 'm6': 1, 'm10': 2, 'M6': 3, 'm7': 1, 'M7': 1}}, roleType{'laosheng': {'P1': 178, 'M2': 44, 'm3': 24, 'P8': 23, 'P4': 6, 'M3': 3, 'm2': 3, 'P5': 4, 'm6': 1, 'm10': 2, 'M6': 3, 'm7': 1, 'M7': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 140, 'm3': 8, 'P8': 20, 'M2': 10, 'P4': 1, 'm2': 2, 'P5': 1, 'M6': 2, 'm7': 1}}, banshi{'yuanban': {'P1': 140, 'm3': 8, 'P8': 20, 'M2': 10, 'P4': 1, 'm2': 2, 'P5': 1, 'M6': 2, 'm7': 1}}, roleType{'laosheng': {'P1': 140, 'm3': 8, 'P8': 20, 'M2': 10, 'P4': 1, 'm2': 2, 'P5': 1, 'M6': 2, 'm7': 1}}
# 	Couplet 1
# 	Opening line: 未开言不由人（呐）珠泪滚滚，
# 	Closing line: 天卸重任我就要（哇）你担承。
#
#
# 	Couplet 2
# 	Opening line: 二犬子（呃）皆年幼（哇）难当（呃）重任，
# 	Closing line: 老朽年迈我也不能够担承。
#
#
# 	Couplet 3
# 	Opening line: 望使君放开怀慨然（呐）应（呐）允，
# 	Closing line: 救生灵（呐）积阴（呐）功也免得我坐卧不宁。
#
#
# Score lseh-YiLunMing-WenZhaoGuan-1.xml containing 18 couplets
# Voice staves: [0]
# Instrumental staves: [1]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 1079, 'm3': 83, 'm2': 9, 'P4': 18, 'M2': 171, 'P5': 10, 'm7': 13, 'P8': 50, 'M6': 10, 'M3': 24, 'm10': 2, 'm6': 4, 'm9': 1}}, banshi{'manban': {'P1': 525, 'm3': 37, 'm2': 2, 'P4': 8, 'M2': 59, 'P5': 8, 'm7': 8, 'P8': 30, 'M6': 9, 'M3': 13, 'm10': 2, 'm6': 4, 'm9': 1}, 'yuanban': {'P1': 554, 'M2': 112, 'M3': 11, 'm3': 46, 'M6': 1, 'm7': 5, 'P4': 10, 'm2': 7, 'P8': 20, 'P5': 2}}, roleType{'laosheng': {'P1': 1079, 'm3': 83, 'm2': 9, 'P4': 18, 'M2': 171, 'P5': 10, 'm7': 13, 'P8': 50, 'M6': 10, 'M3': 24, 'm10': 2, 'm6': 4, 'm9': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 810, 'm3': 33, 'M2': 67, 'P4': 9, 'm7': 10, 'P8': 40, 'M3': 14, 'M6': 5, 'm6': 4, 'm2': 3, 'P5': 5, 'm9': 1}}, banshi{'manban': {'P1': 451, 'm3': 16, 'M2': 21, 'P4': 5, 'm7': 7, 'P8': 28, 'M3': 9, 'M6': 5, 'm6': 4, 'm2': 1, 'P5': 3, 'm9': 1}, 'yuanban': {'P1': 359, 'M2': 46, 'M3': 5, 'm3': 17, 'm7': 3, 'P4': 4, 'm2': 2, 'P8': 12, 'P5': 2}}, roleType{'laosheng': {'P1': 810, 'm3': 33, 'M2': 67, 'P4': 9, 'm7': 10, 'P8': 40, 'M3': 14, 'M6': 5, 'm6': 4, 'm2': 3, 'P5': 5, 'm9': 1}}
# 	Couplet 1
# 	Opening line: 一轮明月照窗前，
# 	Closing line: 愁人心（哪）中似箭穿。
#
#
# 	Couplet 2
# 	Opening line: 实指（惹）望到吴国借兵回转，
# 	Closing line: 谁知昭关有阻拦。
#
#
# 	Couplet 3
# 	Opening line: 幸遇那东皋公行方便，
# 	Closing line: 他将我隐藏在后花园。
#
#
# 	Couplet 4
# 	Opening line: 一连几天我的眉不（哇）展，
# 	Closing line: 夜夜何曾得安眠。
#
#
# 	Couplet 5
# 	Opening line: 俺伍员好一似丧家犬，
# 	Closing line: 满腹的含冤我向谁言（哪）！
#
#
# 	Couplet 6
# 	Opening line: 我好（哇）比哀哀长空雁，
# 	Closing line: 我好比龙游在浅沙滩。
#
#
# 	Couplet 7
# 	Opening line: 我好（哇）比鱼儿吞了钩线，
# 	Closing line: 我好（哇）比波浪中失舵的舟船（哪）。
#
#
# 	Couplet 8
# 	Opening line: 思来想去我的肝肠断，
# 	Closing line: 今夜晚怎能够盼到明天。
#
#
# 	Couplet 9
# 	Opening line: 心中有事难合眼，
# 	Closing line: 翻来覆去睡不（哇）安。
#
#
# 	Couplet 10
# 	Opening line: 背地里只把东皋公怨，
# 	Closing line: 叫人难解巧机关，
#
#
# 	Couplet 11
# 	Opening line: 若是真心来救我，
# 	Closing line: 为何几日他不言。
#
#
# 	Couplet 12
# 	Opening line: 贪图富贵来害我，
# 	Closing line: 你就该把我献与昭关。
#
#
# 	Couplet 13
# 	Opening line: 哭一声爹娘不能相见，
# 	K line: 不能（哪）哎见爹娘（兀）！
# 	Closing line: 要相逢陈非是梦（兀）里团圆。
#
#
# 	Couplet 14
# 	Opening line: 鸡鸣犬吠五更（哪）天，
# 	Closing line: 越思越想好伤惨，
#
#
# 	Couplet 15
# 	Opening line: 想当初在朝为官宦，
# 	Closing line: 朝臣待漏（哇）五更寒，
#
#
# 	Couplet 16
# 	Opening line: 到如今夜宿在荒村院，
# 	Closing line: 我冷冷清清向谁言（哪）。
#
#
# 	Couplet 17
# 	Opening line: 我本当拔宝剑自寻短见，
# 	K line: 寻短（哪）哎见爹娘（兀）！
# 	Closing line: 父母的冤仇化尘烟，
#
#
# 	Couplet 18
# 	Opening line: 对天发不宏誓愿，
# 	Closing line: 我不杀平王我的心怎甘（哪）。
#
#
# Score lseh-YiLunMing-WenZhaoGuan-2.xml containing 8 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 516, 'm3': 39, 'P4': 16, 'M2': 68, 'M3': 14, 'P5': 9, 'm7': 7, 'P8': 34, 'M6': 12, 'm10': 2, 'm9': 1, 'm6': 5, 'm2': 3}}, banshi{'manban': {'P1': 516, 'm3': 39, 'P4': 16, 'M2': 68, 'M3': 14, 'P5': 9, 'm7': 7, 'P8': 34, 'M6': 12, 'm10': 2, 'm9': 1, 'm6': 5, 'm2': 3}}, roleType{'laosheng': {'P1': 516, 'm3': 39, 'P4': 16, 'M2': 68, 'M3': 14, 'P5': 9, 'm7': 7, 'P8': 34, 'M6': 12, 'm10': 2, 'm9': 1, 'm6': 5, 'm2': 3}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 446, 'm3': 14, 'P4': 9, 'M2': 24, 'm7': 7, 'P8': 30, 'M3': 9, 'M6': 8, 'm6': 5, 'm2': 3, 'P5': 5}}, banshi{'manban': {'P1': 446, 'm3': 14, 'P4': 9, 'M2': 24, 'm7': 7, 'P8': 30, 'M3': 9, 'M6': 8, 'm6': 5, 'm2': 3, 'P5': 5}}, roleType{'laosheng': {'P1': 446, 'm3': 14, 'P4': 9, 'M2': 24, 'm7': 7, 'P8': 30, 'M3': 9, 'M6': 8, 'm6': 5, 'm2': 3, 'P5': 5}}
# 	Couplet 1
# 	Opening line: 一轮明月照窗前，
# 	Closing line: 愁人心（呐）中似箭穿。
#
#
# 	Couplet 2
# 	Opening line: 实指望到吴国借兵回转，
# 	Closing line: 谁知昭关有阻拦。
#
#
# 	Couplet 3
# 	Opening line: 幸遇那东皋公行方便，
# 	Closing line: 他将我隐藏在后花园。
#
#
# 	Couplet 4
# 	Opening line: 一连几天我的眉不（呃）展，
# 	Closing line: 夜夜何曾得安眠。
#
#
# 	Couplet 5
# 	Opening line: 俺伍员好一似丧家犬，
# 	Closing line: 满腹的含冤我向谁言（喏）。
#
#
# 	Couplet 6
# 	Opening line: 我好（呃）比哀哀长空雁，
# 	Closing line: 我好比龙游在浅沙滩。
#
#
# 	Couplet 7
# 	Opening line: 我好（呃）比鱼儿吞了钩线，
# 	Closing line: 我好（呃）比波浪中失舵的舟船（喏）。
#
#
# 	Couplet 8
# 	Opening line: 思来想去我的肝肠断，
# 	Closing line: 今夜晚怎能够盼到明天。
#
#
# Score lseh-YiLunMing-ZhuoFangCao-1.xml containing 13 couplets
# Voice staves: [0]
# Instrumental staves: [1]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 698, 'M2': 162, 'm3': 47, 'M3': 27, 'P8': 81, 'P4': 25, 'P5': 15, 'P11': 1, 'M6': 29, 'm2': 7, 'm7': 5, 'm6': 3, 'm9': 1, 'm10': 2}}, banshi{'manban': {'P1': 442, 'M2': 95, 'm3': 32, 'M3': 14, 'P8': 66, 'P4': 12, 'P5': 9, 'P11': 1, 'M6': 18, 'm2': 3, 'm7': 5, 'm6': 1, 'm9': 1, 'm10': 2}, 'yuanban': {'P1': 256, 'M2': 67, 'm3': 15, 'M3': 13, 'P4': 13, 'M6': 11, 'P8': 15, 'P5': 6, 'm6': 2, 'm2': 4}}, roleType{'laosheng': {'P1': 698, 'M2': 162, 'm3': 47, 'M3': 27, 'P8': 81, 'P4': 25, 'P5': 15, 'P11': 1, 'M6': 29, 'm2': 7, 'm7': 5, 'm6': 3, 'm9': 1, 'm10': 2}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 567, 'M2': 40, 'P8': 63, 'M6': 10, 'm2': 3, 'M3': 7, 'm7': 1, 'P4': 4, 'm3': 10, 'm9': 1, 'P5': 3}}, banshi{'manban': {'P1': 371, 'M2': 20, 'P8': 50, 'M6': 7, 'm2': 3, 'M3': 5, 'm7': 1, 'P4': 1, 'm3': 4, 'm9': 1, 'P5': 1}, 'yuanban': {'P1': 196, 'M2': 20, 'M3': 2, 'P8': 13, 'm3': 6, 'M6': 3, 'P4': 3, 'P5': 2}}, roleType{'laosheng': {'P1': 567, 'M2': 40, 'P8': 63, 'M6': 10, 'm2': 3, 'M3': 7, 'm7': 1, 'P4': 4, 'm3': 10, 'm9': 1, 'P5': 3}}
# 	Couplet 1
# 	Opening line: 一轮明月照窗下，
# 	Closing line: 陈宫心（呐）中乱如麻，
#
#
# 	Couplet 2
# 	Opening line: 悔不该心猿并意马。
# 	Closing line: 悔不该随他人到吕家，
#
#
# 	Couplet 3
# 	Opening line: 吕伯奢可算得义气（呀）大，
# 	Closing line: 杀猪（喏）沽（哇）酒款待于他，
#
#
# 	Couplet 4
# 	Opening line: 又谁知此贼的疑心（呐）太（呀）大，
# 	Closing line: 拔出剑将他的满门杀，
#
#
# 	Couplet 5
# 	Opening line: 一家人倶丧在宝剑之（喏）下，
# 	Closing line: 年迈的老丈命（呐）染黄沙。
#
#
# 	Couplet 6
# 	Opening line: 屈死的冤鬼魂休来怨（呐）咱，
# 	Closing line: 自有那神灵（啊）天地鉴察。
#
#
# 	Couplet 7
# 	Opening line: 听谯楼打罢了二（喏）更鼓下，
# 	Closing line: 越思越想把事来作差。
#
#
# 	Couplet 8
# 	Opening line: 悔不该把家属一（呀）旦撇下，
# 	Closing line: 悔不该弃县今抛却了乌（哇）纱，
#
#
# 	Couplet 9
# 	Opening line: 我只说贼是个宽宏量大，
# 	Closing line: 汉室后来贼是个惹祸的根芽。
#
#
# 	Couplet 10
# 	Opening line: 观此贼睡卧真（呐）潇洒，
# 	Closing line: 安眠好似井底之蛙，
#
#
# 	Couplet 11
# 	Opening line: 贼好比蛟龙未生鳞甲，
# 	Closing line: 贼好比猛虎未（呀）曾长牙，
#
#
# 	Couplet 12
# 	Opening line: 虎在笼中我不打，
# 	Closing line: 我岂肯放虎归山又（哇）把人抓。
#
#
# 	Couplet 13
# 	Opening line: 执宝剑将贼的（呀）头割下，
# 	Closing line: 险些儿把事（喏）又（哇）作差。
#
#
# Score lseh-YiLunMing-ZhuoFangCao-2.xml containing 6 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 380, 'P4': 8, 'M3': 5, 'M2': 67, 'm3': 22, 'P8': 57, 'm7': 4, 'P11': 1, 'M6': 6, 'm10': 4, 'P5': 3, 'm2': 1}}, banshi{'sanyan': {'P1': 380, 'P4': 8, 'M3': 5, 'M2': 67, 'm3': 22, 'P8': 57, 'm7': 4, 'P11': 1, 'M6': 6, 'm10': 4, 'P5': 3, 'm2': 1}}, roleType{'laosheng': {'P1': 380, 'P4': 8, 'M3': 5, 'M2': 67, 'm3': 22, 'P8': 57, 'm7': 4, 'P11': 1, 'M6': 6, 'm10': 4, 'P5': 3, 'm2': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 312, 'M2': 19, 'm3': 5, 'P8': 46, 'm7': 2, 'P11': 1, 'P4': 4, 'P5': 2, 'm2': 1, 'M6': 1}}, banshi{'sanyan': {'P1': 312, 'M2': 19, 'm3': 5, 'P8': 46, 'm7': 2, 'P11': 1, 'P4': 4, 'P5': 2, 'm2': 1, 'M6': 1}}, roleType{'laosheng': {'P1': 312, 'M2': 19, 'm3': 5, 'P8': 46, 'm7': 2, 'P11': 1, 'P4': 4, 'P5': 2, 'm2': 1, 'M6': 1}}
# 	Couplet 1
# 	Opening line: 一轮明月照窗下，
# 	Closing line: 陈宫心中乱如麻。
#
#
# 	Couplet 2
# 	Opening line: 悔不该心猿并意马，
# 	Closing line: 悔不该随他人到吕家。
#
#
# 	Couplet 3
# 	Opening line: 吕伯奢可算得义气大，
# 	Closing line: 杀猪沽酒款待与他。
#
#
# 	Couplet 4
# 	Opening line: 又谁知此贼的疑心太大，
# 	Closing line: 拔出剑将他的满门杀。
#
#
# 	Couplet 5
# 	Opening line: 一家人倶丧在宝剑之下，
# 	Closing line: 年迈老丈命染黄沙。
#
#
# 	Couplet 6
# 	Opening line: 屈死的冤鬼魂休要怨咱，
# 	Closing line: 自有那神灵儿天地鉴察。
#
#
# Score lsxp-CiShiJian-HuaiHeYing-1.xml containing 4 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 74, 'M2': 15, 'm3': 11, 'P4': 3, 'P8': 65, 'm7': 4, 'M6': 9, 'M3': 1, 'm10': 2, 'M10': 1, 'M9': 2}}, banshi{'liushui': {'P1': 74, 'M2': 15, 'm3': 11, 'P4': 3, 'P8': 65, 'm7': 4, 'M6': 9, 'M3': 1, 'm10': 2, 'M10': 1, 'M9': 2}}, roleType{'laosheng': {'P1': 74, 'M2': 15, 'm3': 11, 'P4': 3, 'P8': 65, 'm7': 4, 'M6': 9, 'M3': 1, 'm10': 2, 'M10': 1, 'M9': 2}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 68, 'M2': 6, 'P8': 51, 'M6': 3, 'm3': 5, 'P4': 1, 'M9': 1}}, banshi{'liushui': {'P1': 68, 'M2': 6, 'P8': 51, 'M6': 3, 'm3': 5, 'P4': 1, 'M9': 1}}, roleType{'laosheng': {'P1': 68, 'M2': 6, 'P8': 51, 'M6': 3, 'm3': 5, 'P4': 1, 'M9': 1}}
# 	Couplet 1
# 	Opening line: 此时间不可闹笑话，
# 	Closing line: 胡言乱语怎瞒（呐）咱。
#
#
# 	Couplet 2
# 	Opening line: 在长安是你夸大话，
# 	Closing line: 为什么事到如今耍奸滑。
#
#
# 	Couplet 3
# 	Opening line: 左手拉住了李左车，
# 	Closing line: 右手再把栾布拉。
#
#
# 	Couplet 4
# 	Opening line: 三人同把那鬼门关上踏（啊），
# 	Closing line: 生死二字（喏）且由他。
#
#
# Score lsxp-CiShiJian-HuaiHeYing-2.xml containing 4 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 78, 'M2': 19, 'M3': 4, 'P4': 4, 'm3': 12, 'P8': 50, 'm7': 8, 'M6': 11, 'P5': 2, 'm10': 2, 'M9': 2, 'M10': 1, 'm9': 1}}, banshi{'liushui': {'P1': 78, 'M2': 19, 'M3': 4, 'P4': 4, 'm3': 12, 'P8': 50, 'm7': 8, 'M6': 11, 'P5': 2, 'm10': 2, 'M9': 2, 'M10': 1, 'm9': 1}}, roleType{'laosheng': {'P1': 78, 'M2': 19, 'M3': 4, 'P4': 4, 'm3': 12, 'P8': 50, 'm7': 8, 'M6': 11, 'P5': 2, 'm10': 2, 'M9': 2, 'M10': 1, 'm9': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 69, 'M2': 6, 'P4': 1, 'P8': 37, 'M6': 4, 'm7': 3, 'm3': 3, 'P5': 1, 'm9': 1}}, banshi{'liushui': {'P1': 69, 'M2': 6, 'P4': 1, 'P8': 37, 'M6': 4, 'm7': 3, 'm3': 3, 'P5': 1, 'm9': 1}}, roleType{'laosheng': {'P1': 69, 'M2': 6, 'P4': 1, 'P8': 37, 'M6': 4, 'm7': 3, 'm3': 3, 'P5': 1, 'm9': 1}}
# ...
#
#
# 	Couplet 2
# 	Opening line: 一不是响马与贼寇，
# 	Closing line: 二不是歹人（呐）把城偷。
#
#
# 	Couplet 3
# 	Opening line: 杨林与我来争斗，
# 	Closing line: 因此上发配到登州。
#
#
# 	Couplet 4
# 	Opening line: 舍不得太爷的恩情厚，
# 	Closing line: 舍不得衙役们众班头。
#
#
# 	Couplet 5
# 	Opening line: 实难舍街坊四邻与我的好朋友，
# 	Closing line: 舍不得老娘（呃）白了头。
#
#
# 	Couplet 6
# 	Opening line: 娘生儿连心肉，
# 	Closing line: 儿行千里母担忧。
#
#
# 	Couplet 7
# 	Opening line: 儿想娘亲难叩首，
# 	Closing line: 娘想儿来泪双流。
#
#
# 	Couplet 8
# 	Opening line: 眼见得红日坠落在西山后，
# 	Closing line: 叫一声解差把店役。
#
#
# Score lsxp-LiangGuoJiao-ShiJieTing-2.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 131, 'M2': 38, 'm3': 23, 'P4': 12, 'P5': 2, 'P8': 5, 'M6': 1, 'M3': 3}}, banshi{'yuanban': {'P1': 131, 'M2': 38, 'm3': 23, 'P4': 12, 'P5': 2, 'P8': 5, 'M6': 1, 'M3': 3}}, roleType{'laosheng': {'P1': 131, 'M2': 38, 'm3': 23, 'P4': 12, 'P5': 2, 'P8': 5, 'M6': 1, 'M3': 3}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 105, 'M2': 8, 'm3': 4, 'P8': 3, 'P4': 2}}, banshi{'yuanban': {'P1': 105, 'M2': 8, 'm3': 4, 'P8': 3, 'P4': 2}}, roleType{'laosheng': {'P1': 105, 'M2': 8, 'm3': 4, 'P8': 3, 'P4': 2}}
# 	Couplet 1
# 	Opening line: 两国交锋龙虎斗，
# 	Closing line: 各为其（呀）主统貔貅。
#
#
# 	Couplet 2
# 	Opening line: 管带三（呐）军要宽厚，
# 	Closing line: 赏罚中公（呃）平莫要自由。
#
#
# 	Couplet 3
# 	Opening line: 此一番领（呃）兵去镇守，
# 	Closing line: 靠山近水把营收。
#
#
# Score lsxp-ShenGongWu-LongFengChengXiang.xml containing 2 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 93, 'M3': 1, 'm3': 10, 'M2': 20, 'P4': 5, 'P8': 4, 'm7': 1}}, banshi{'yuanban': {'P1': 93, 'M3': 1, 'm3': 10, 'M2': 20, 'P4': 5, 'P8': 4, 'm7': 1}}, roleType{'laosheng': {'P1': 93, 'M3': 1, 'm3': 10, 'M2': 20, 'P4': 5, 'P8': 4, 'm7': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 81, 'M2': 5, 'm3': 3, 'P8': 2}}, banshi{'yuanban': {'P1': 81, 'M2': 5, 'm3': 3, 'P8': 2}}, roleType{'laosheng': {'P1': 81, 'M2': 5, 'm3': 3, 'P8': 2}}
# 	Couplet 1
# 	Opening line: 深宫无（哇）处不飞花，
# 	Closing line: 年老得配女娇娃。
#
#
# 	Couplet 2
# 	Opening line: 朝欢暮乐无牵挂，
# 	Closing line: 耳听笙歌闹喧哗。
#
#
# Score lsxp-TingTaYan-ZhuoFangCao-1.xml containing 4 couplets
# Voice staves: [0]
# Instrumental staves: [1]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 210, 'M2': 22, 'm3': 22, 'm7': 6, 'P5': 4, 'P8': 120, 'M6': 11, 'M9': 8, 'P4': 6, 'm2': 2, 'P11': 5, 'm9': 1, 'M3': 6, 'm10': 7}}, banshi{'manban': {'P1': 210, 'M2': 22, 'm3': 22, 'm7': 6, 'P5': 4, 'P8': 120, 'M6': 11, 'M9': 8, 'P4': 6, 'm2': 2, 'P11': 5, 'm9': 1, 'M3': 6, 'm10': 7}}, roleType{'laosheng': {'P1': 210, 'M2': 22, 'm3': 22, 'm7': 6, 'P5': 4, 'P8': 120, 'M6': 11, 'M9': 8, 'P4': 6, 'm2': 2, 'P11': 5, 'm9': 1, 'M3': 6, 'm10': 7}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 171, 'm3': 7, 'm7': 2, 'P8': 107, 'M9': 2, 'M2': 5, 'P4': 1, 'm10': 1, 'M6': 1}}, banshi{'manban': {'P1': 171, 'm3': 7, 'm7': 2, 'P8': 107, 'M9': 2, 'M2': 5, 'P4': 1, 'm10': 1, 'M6': 1}}, roleType{'laosheng': {'P1': 171, 'm3': 7, 'm7': 2, 'P8': 107, 'M9': 2, 'M2': 5, 'P4': 1, 'm10': 1, 'M6': 1}}
# 	Couplet 1
# 	Opening line: 听他言吓得我心（呐）惊胆怕，
# 	Closing line: 背转身只埋怨我自（呃）己作差，
#
#
# 	Couplet 2
# 	Opening line: 我先前只望他宽宏量（呃）大，
# 	Closing line: 却原（呐）来贼是个无（哇）义（呀）的冤家！
#
#
# 	Couplet 3
# 	Opening line: 马行在来道内我难（呐）以回（呀）马，
# 	Closing line: 这才是花随水水不（哇）能恋（呐）花。
#
#
# 	Couplet 4
# 	Opening line: 这时候我只得暂且忍耐在心下，
# 	Closing line: 既同行共（呃）大事必须要劝解于他（呀呃）。
#
#
# Score lsxp-TingTaYan-ZhuoFangCao-2.xml containing 4 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 212, 'm3': 26, 'M2': 30, 'm7': 7, 'P5': 4, 'P8': 128, 'M6': 13, 'M9': 9, 'P4': 10, 'm2': 2, 'P11': 5, 'm9': 1, 'M3': 6, 'm10': 8, 'M10': 1}}, banshi{'sanyan': {'P1': 212, 'm3': 26, 'M2': 30, 'm7': 7, 'P5': 4, 'P8': 128, 'M6': 13, 'M9': 9, 'P4': 10, 'm2': 2, 'P11': 5, 'm9': 1, 'M3': 6, 'm10': 8, 'M10': 1}}, roleType{'laosheng': {'P1': 212, 'm3': 26, 'M2': 30, 'm7': 7, 'P5': 4, 'P8': 128, 'M6': 13, 'M9': 9, 'P4': 10, 'm2': 2, 'P11': 5, 'm9': 1, 'M3': 6, 'm10': 8, 'M10': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 166, 'M2': 6, 'm3': 7, 'm7': 2, 'P8': 110, 'M9': 2, 'P4': 1, 'm10': 1, 'M6': 2}}, banshi{'sanyan': {'P1': 166, 'M2': 6, 'm3': 7, 'm7': 2, 'P8': 110, 'M9': 2, 'P4': 1, 'm10': 1, 'M6': 2}}, roleType{'laosheng': {'P1': 166, 'M2': 6, 'm3': 7, 'm7': 2, 'P8': 110, 'M9': 2, 'P4': 1, 'm10': 1, 'M6': 2}}
# 	Couplet 1
# 	Opening line: 听他言吓得我心（呐）惊胆怕，
# 	Closing line: 背转身自埋怨我自（呃）已做差。
#
#
# 	Couplet 2
# 	Opening line: 我先前只望他宽宏量（呃）大，
# 	Closing line: 却愿（呐）来贼是个无（哇）义（呀）的冤家！
#
#
# 	Couplet 3
# 	Opening line: 马行在来道内我难（呐）以回（呀）马，
# 	Closing line: 这才是花随水水不（哇）能恋（呐）花。
#
#
# 	Couplet 4
# 	Opening line: 这时候我只得暂且忍耐在心下，
# 	Closing line: 既同行共（呃）大事必须要劝解于他（呀呃）。
#
#
# Score lsxp-WeiCengKai-QiYuanBao.xml containing 5 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 114, 'm3': 13, 'm2': 1, 'M3': 2, 'M2': 20, 'P4': 8, 'm7': 1}}, banshi{'liushui': {'P1': 114, 'm3': 13, 'm2': 1, 'M3': 2, 'M2': 20, 'P4': 8, 'm7': 1}}, roleType{'laosheng': {'P1': 114, 'm3': 13, 'm2': 1, 'M3': 2, 'M2': 20, 'P4': 8, 'm7': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 107, 'm3': 4, 'm2': 1, 'M2': 1}}, banshi{'liushui': {'P1': 107, 'm3': 4, 'm2': 1, 'M2': 1}}, roleType{'laosheng': {'P1': 107, 'm3': 4, 'm2': 1, 'M2': 1}}
# 	Couplet 1
# 	Opening line: 未曾开言泪汪汪，
# 	Closing line: 尊一声太爷听端详。
#
#
# 	Couplet 2
# 	Opening line: 家住在南阳太平庄，
# 	Closing line: 姓刘名安字世昌。
#
#
# 	Couplet 3
# 	Opening line: 奉母命京城往，
# 	Closing line: 贩卖绸缎转还乡。
#
#
# 	Couplet 4
# 	Opening line: 行至在中途把雨降，
# 	Closing line: 借宿一宵起祸殃。
#
#
# 	Couplet 5
# 	Opening line: 赵大夫妻图财害命害我一命亡，
# 	Closing line: 望求太爷与我作主张（啊）。
#
#
# Score lsxp-WoBenShi-KongChengJi-2.xml containing 5 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 278, 'M2': 29, 'm2': 7, 'm3': 27, 'P8': 101, 'm10': 10, 'm7': 9, 'M9': 5, 'M6': 10, 'M10': 1, 'P4': 10, 'm9': 3, 'm14': 1, 'M3': 8, 'P5': 3, 'm6': 2, 'P12': 1}}, banshi{'sanyan': {'P1': 262, 'M2': 24, 'm2': 6, 'm3': 26, 'P8': 98, 'm10': 10, 'm7': 9, 'M9': 5, 'M6': 8, 'M10': 1, 'P4': 7, 'm9': 3, 'm14': 1, 'M3': 5, 'P5': 2, 'm6': 2, 'P12': 1}, 'yuanban': {'P1': 16, 'M2': 5, 'P4': 3, 'm2': 1, 'M3': 3, 'm3': 1, 'P8': 3, 'M6': 2, 'P5': 1}}, roleType{'laosheng': {'P1': 278, 'M2': 29, 'm2': 7, 'm3': 27, 'P8': 101, 'm10': 10, 'm7': 9, 'M9': 5, 'M6': 10, 'M10': 1, 'P4': 10, 'm9': 3, 'm14': 1, 'M3': 8, 'P5': 3, 'm6': 2, 'P12': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 228, 'P8': 73, 'M2': 6, 'm3': 7, 'M6': 5, 'm10': 1, 'm2': 2, 'P5': 2, 'm6': 1, 'P4': 4, 'm7': 1, 'M3': 1}}, banshi{'sanyan': {'P1': 212, 'P8': 71, 'M2': 4, 'm3': 7, 'M6': 5, 'm10': 1, 'm2': 2, 'P5': 1, 'm6': 1, 'P4': 1, 'm7': 1}, 'yuanban': {'P1': 16, 'M2': 2, 'P4': 3, 'M3': 1, 'P8': 2, 'P5': 1}}, roleType{'laosheng': {'P1': 228, 'P8': 73, 'M2': 6, 'm3': 7, 'M6': 5, 'm10': 1, 'm2': 2, 'P5': 2, 'm6': 1, 'P4': 4, 'm7': 1, 'M3': 1}}
# 	Couplet 1
# 	Opening line: 我本是卧龙岗散淡（呐）的人，
# 	Closing line: 凭阴阳如反掌保定乾坤。
#
#
# 	Couplet 2
# 	Opening line: 先帝（呀）爷下南阳（呃）御驾三（呃）请，
# 	Closing line: 算就了汉家的业鼎足（呃）三分。
#
#
# 	Couplet 3
# 	Opening line: 官封到武乡侯（呃）执掌帅印，
# 	Closing line: 东西战南北剿博古（呃）通（哦）今。
#
#
# 	Couplet 4
# 	Opening line: 周文王访姜尚周室大振，
# 	Closing line: 我诸葛怎比得前辈（呃）的先（呃）生。
#
#
# 	Couplet 5
# 	Opening line: 闲无（呃）事在敌楼（呃）我亮一亮琴（呢）音，
# 	Closing line: 我面前却少个知（呃）音的人。
#
#
# Score lsxp-WoZhuYe-ZhuiHanXin.xml containing 8 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 141, 'm3': 24, 'M2': 25, 'P8': 64, 'P5': 3, 'P11': 5, 'M6': 6, 'M9': 6, 'P4': 9, 'm10': 4, 'm2': 1, 'M3': 1}}, banshi{'liushui': {'P1': 140, 'm3': 22, 'M2': 23, 'P8': 64, 'P5': 3, 'P11': 5, 'M6': 6, 'M9': 6, 'P4': 8, 'm10': 4, 'm2': 1, 'M3': 1}, 'yaoban': {'P4': 1, 'm3': 2, 'P1': 1, 'M2': 2}}, roleType{'laosheng': {'P1': 141, 'm3': 24, 'M2': 25, 'P8': 64, 'P5': 3, 'P11': 5, 'M6': 6, 'M9': 6, 'P4': 9, 'm10': 4, 'm2': 1, 'M3': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 135, 'm3': 4, 'P8': 61, 'P11': 2, 'M2': 2, 'M9': 2, 'P4': 1}}, banshi{'liushui': {'P1': 135, 'm3': 3, 'P8': 61, 'P11': 2, 'M2': 2, 'M9': 2}, 'yaoban': {'P4': 1, 'm3': 1}}, roleType{'laosheng': {'P1': 135, 'm3': 4, 'P8': 61, 'P11': 2, 'M2': 2, 'M9': 2, 'P4': 1}}
# 	Couplet 1
# 	Opening line: 我主爷起义在芒砀，
# 	Closing line: 拔剑斩蛇天下扬。
#
#
# 	Couplet 2
# 	Opening line: 怀王也曾把旨降，
# 	Closing line: 两路分（呐）兵定咸阳。
#
#
# 	Couplet 3
# 	Opening line: 先进咸阳为皇上，
# 	Closing line: 后进咸阳扶保在朝纲。
#
#
# 	Couplet 4
# 	Opening line: 也是我主洪福广，
# 	Closing line: 一路上得遇陆贾、郦生与张良。
#
#
# 	Couplet 5
# 	Opening line: 一路上秋毫无犯军威壮，
# 	Closing line: 我也曾约法定过三章。
#
#
# 	Couplet 6
# 	Opening line: 项羽不遵怀王约，
# 	Closing line: 反将我主贬汉王。
#
#
# 	Couplet 7
# 	Opening line: 今日里萧何荐良将，
# 	Closing line: 但愿得言听计从重整汉家邦、一同回故乡。
#
#
# 	Couplet 8
# 	Opening line: 撩袍端带我把金殿上，
# 	Closing line: 扬尘舞蹈见大王。
#
#
# Score lsxp-ZhangGongDao-ZhuangYuanPu.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 150, 'M3': 3, 'm3': 25, 'M2': 24, 'm2': 2, 'P4': 7, 'P8': 29, 'm7': 4, 'M9': 4, 'P5': 2, 'M6': 4, 'm13': 1, 'm9': 1}}, banshi{'kuaisanyan': {'P1': 150, 'M3': 3, 'm3': 25, 'M2': 24, 'm2': 2, 'P4': 7, 'P8': 29, 'm7': 4, 'M9': 4, 'P5': 2, 'M6': 4, 'm13': 1, 'm9': 1}}, roleType{'laosheng': {'P1': 150, 'M3': 3, 'm3': 25, 'M2': 24, 'm2': 2, 'P4': 7, 'P8': 29, 'm7': 4, 'M9': 4, 'P5': 2, 'M6': 4, 'm13': 1, 'm9': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 129, 'm3': 7, 'P4': 3, 'P8': 25, 'm7': 2, 'M6': 2, 'm13': 1, 'P5': 1, 'M2': 2}}, banshi{'kuaisanyan': {'P1': 129, 'm3': 7, 'P4': 3, 'P8': 25, 'm7': 2, 'M6': 2, 'm13': 1, 'P5': 1, 'M2': 2}}, roleType{'laosheng': {'P1': 129, 'm3': 7, 'P4': 3, 'P8': 25, 'm7': 2, 'M6': 2, 'm13': 1, 'P5': 1, 'M2': 2}}
# 	Couplet 1
# 	Opening line: 张公道三十五六（哇）子有靠，
# 	Closing line: 陈伯愚年半百无有后苗。
#
#
# 	Couplet 2
# 	Opening line: 为（呀）儿（啼）女我也曾朝山拜庙，
# 	Closing line: 为儿（喏）女我也曾补路修桥。
#
#
# 	Couplet 3
# 	Opening line: 怕将（呃）来老天爷无（哇）有果报，
# 	Closing line: 眼睁（呐）睁有何人去（呀）把纸烧。
#
#
# Score lsxp-ZuoRiLi-YuanMenZhanZi.xml containing 3 couplets
# Voice staves: [1]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 53, 'M2': 9, 'm3': 5, 'M3': 1}}, banshi{'kuaiban': {'P1': 47, 'M2': 9, 'm3': 5, 'M3': 1}, 'yaoban': {'P1': 6}}, roleType{'laosheng': {'P1': 53, 'M2': 9, 'm3': 5, 'M3': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 52, 'M3': 1}}, banshi{'kuaiban': {'P1': 46, 'M3': 1}, 'yaoban': {'P1': 6}}, roleType{'laosheng': {'P1': 52, 'M3': 1}}
# 	Couplet 1
# 	Opening line: 昨日里斩八将头挂营外，
# 	Closing line: 老娘亲为什么不讲情来？
#
#
# 	Couplet 2
# 	Opening line: 今日里斩宗保娘把儿怪，
# 	Closing line: 哭啼啼坐宝帐所为何来。
#
#
# 	Couplet 3
# 	Opening line: 叫焦赞将宝剑悬挂帐外，
# 	Closing line: 老娘亲再讲情儿自刎头来。
#
#
# Score sdeh-WenSanNiang-SanNiangJiaoZi.xml containing 3 couplets
# Voice staves: [1, 2]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'erhuang': {'P1': 40, 'M2': 8, 'P8': 89, 'M6': 3, 'P4': 2, 'P5': 4, 'm10': 2, 'm6': 1, 'm7': 18, 'm3': 3, 'P11': 1, 'M9': 6, 'm2': 1, 'M10': 1}}, banshi{'yuanban': {'P1': 40, 'M2': 8, 'P8': 89, 'M6': 3, 'P4': 2, 'P5': 4, 'm10': 2, 'm6': 1, 'm7': 18, 'm3': 3, 'P11': 1, 'M9': 6, 'm2': 1, 'M10': 1}}, roleType{'laosheng': {'P1': 25, 'M2': 6, 'P8': 1, 'M6': 1, 'P4': 1, 'P5': 1}, 'dan': {'P8': 88, 'm10': 2, 'm6': 1, 'm7': 18, 'M2': 2, 'm3': 3, 'P5': 3, 'M6': 2, 'P1': 15, 'P11': 1, 'M9': 6, 'P4': 1, 'm2': 1, 'M10': 1}}
# IntervalsPS: shengqiang:{'erhuang': {'P1': 38, 'M2': 1, 'P8': 78, 'M6': 2, 'P4': 1, 'm10': 1, 'P5': 2, 'm7': 5, 'M9': 1, 'm2': 1}}, banshi{'yuanban': {'P1': 38, 'M2': 1, 'P8': 78, 'M6': 2, 'P4': 1, 'm10': 1, 'P5': 2, 'm7': 5, 'M9': 1, 'm2': 1}}, roleType{'laosheng': {'P1': 24, 'M2': 1, 'P8': 1, 'M6': 1, 'P4': 1}, 'dan': {'P8': 77, 'm10': 1, 'P5': 2, 'P1': 14, 'm7': 5, 'M6': 1, 'M9': 1, 'm2': 1}}
# 	Couplet 1
# 	Opening line:
# 	Closing line: 问三娘发雷霆却是为何？
#
#
# 	Couplet 2
# 	Opening line: 老薛保你不必苦哀告，
# 	Closing line: 背转身来哭嚎啕。
#
#
# 	Couplet 3
# 	Opening line: 实指望教训他终身有靠，
# 	Closing line: 又谁知平白的闪跌一跤。
#
#
# Score sdxp-SuLongWei-WuJiaPo.xml containing 21 couplets
# Voice staves: [1, 2]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 471, 'm3': 10, 'M2': 9, 'P8': 23, 'M3': 2, 'm2': 1}}, banshi{'kuaiban': {'P1': 471, 'm3': 10, 'M2': 9, 'P8': 23, 'M3': 2, 'm2': 1}}, roleType{'laosheng': {'P1': 249, 'm3': 6, 'M2': 5, 'P8': 4, 'M3': 1}, 'dan': {'P8': 19, 'P1': 222, 'm3': 4, 'M2': 4, 'M3': 1, 'm2': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 463, 'P8': 23, 'm3': 2, 'M2': 3, 'm2': 1}}, banshi{'kuaiban': {'P1': 463, 'P8': 23, 'm3': 2, 'M2': 3, 'm2': 1}}, roleType{'laosheng': {'P1': 249, 'P8': 4}, 'dan': {'P8': 19, 'P1': 214, 'm3': 2, 'M2': 3, 'm2': 1}}
# 	Couplet 1
# 	Opening line: 苏龙魏虎为媒证，
# 	Closing line: 王丞相是我的主婚人（哪）。
#
#
# 	Couplet 2
# 	Opening line: 他三人与我有仇恨，
# 	Closing line: 咬定牙关他就不认承。
#
#
# 	Couplet 3
# 	Opening line: 西凉川四十单八站，
# 	Closing line: 为军的要人我是不要钱。
#
#
# 	Couplet 4
# 	Opening line: 大嫂说话礼不端，
# 	Closing line: 为军哪怕到官前。
#
#
# 	Couplet 5
# 	Opening line: 衙里衙外我打点，
# 	Closing line: 管保大嫂就断与咱。
#
#
# 	Couplet 6
# 	Opening line: 好一个贞节王宝钏，
# 	Closing line: 百般调戏也枉然。
#
#
# 	Couplet 7
# 	Opening line: 腰中取出银一锭，
# 	Closing line: 将银放在地平川。
#
#
# 	Couplet 8
# 	Opening line: 这锭银、三两三，
# 	Closing line: 送与大嫂把家安。
#
#
# 	Couplet 9
# 	Opening line: 买绫罗与绸缎、打首饰和簪环，
# 	Closing line: 我与你露水的夫妻就过几年（呐）。
#
#
# 	Couplet 10
# 	Opening line: 是烈女就该在家院，
# 	Closing line: 为何来在大道边。
#
#
# 	Couplet 11
# 	Opening line: 为军起下不良的意（呀），
# 	Closing line: 一马双跨到西凉。
#
#
# 	Couplet 12
# 	Opening line: 提起了旁人我不晓，
# 	Closing line: 苏龙魏虎是内亲。
#
#
# 	Couplet 13
# 	Opening line: 你我同把相府进，
# 	Closing line: 三人对面（就）说分明。
#
#
# 	Couplet 14
# 	Opening line: 我父在朝为官宦，
# 	Closing line: 府内金银堆如山。
#
#
# 	Couplet 15
# 	Opening line: 本利算来有多少，
# 	Closing line: 命人送到（那）西凉川。
#
#
# 	Couplet 16
# 	Opening line: 我进相府对父言，
# 	Closing line: 家人小厮有万千。
#
#
# 	Couplet 17
# 	Opening line: 将你带到官衙内，
# 	Closing line: 打板子、上夹棍、丢南牢、坐监禁、管叫你思前容易退后难。
#
#
# 	Couplet 18
# 	Opening line: 军爷说话理不端，
# 	Closing line: 欺奴犹如欺了天。
#
#
# 	Couplet 19
# 	Opening line: 西凉的鞑子将你斩，
# 	Closing line: 妻儿老小与奴一般。
#
#
# 	Couplet 20
# 	Opening line: 这锭银子奴不要，
# 	Closing line: 与你娘做一个安家钱。
#
#
# 	Couplet 21
# 	Opening line: 买绫罗、做衣衫、买白纸、糊白幡、打首饰、做妆奁，
# 	Closing line: 落得个孝子的名儿在那天下传。
#
#
# Score sdxp-WoHeNi-SiLangTanMu.xml containing 16 couplets
# Voice staves: [1, 2]
# Instrumental staves: [0]
# Separated accompaniment: yes
# IntervalsSS: shengqiang:{'xipi': {'P1': 283, 'm3': 44, 'M2': 56, 'M3': 13, 'm2': 7, 'P4': 16, 'P8': 22, 'P5': 6, 'M6': 2, 'M9': 1, 'M7': 1, 'm7': 5, 'm6': 1}}, banshi{'kuaiban': {'P1': 281, 'm3': 43, 'M2': 54, 'M3': 13, 'm2': 7, 'P4': 16, 'P8': 22, 'P5': 6, 'M6': 2, 'M9': 1, 'M7': 1, 'm7': 5, 'm6': 1}, 'yaoban': {'P1': 2, 'M2': 2, 'm3': 1}}, roleType{'laosheng': {'P1': 155, 'm3': 31, 'M2': 37, 'M3': 13, 'm2': 4, 'P4': 13, 'P8': 13, 'P5': 6, 'M6': 2, 'M9': 1, 'M7': 1}, 'dan': {'P8': 9, 'm7': 5, 'm3': 13, 'P1': 128, 'M2': 19, 'm2': 3, 'P4': 3, 'm6': 1}}
# IntervalsPS: shengqiang:{'xipi': {'P1': 262, 'M2': 24, 'M3': 9, 'm3': 26, 'P8': 22, 'P5': 5, 'P4': 3, 'M7': 1, 'M6': 1}}, banshi{'kuaiban': {'P1': 261, 'M2': 22, 'M3': 9, 'm3': 25, 'P8': 22, 'P5': 5, 'P4': 3, 'M7': 1, 'M6': 1}, 'yaoban': {'P1': 1, 'M2': 2, 'm3': 1}}, roleType{'laosheng': {'P1': 144, 'M2': 21, 'M3': 9, 'm3': 19, 'P8': 13, 'P5': 5, 'P4': 2, 'M7': 1, 'M6': 1}, 'dan': {'P8': 9, 'P1': 118, 'm3': 7, 'M2': 3, 'P4': 1}}
# 	Couplet 1
# 	Opening line: 我和你好夫妻恩德不浅，
# 	Closing line: 贤公主又何必过于谦言。
#
#
# 	Couplet 2
# 	Opening line: 杨廷辉有一日愁眉得展，
# 	Closing line: 誓不忘贤公主恩重如山。
#
#
# 	Couplet 3
# 	Opening line: 非是我这几日愁眉不展，
# 	Closing line: 有一桩心腹事不敢明言。
#
#
# 	Couplet 4
# 	Opening line: 萧天佐摆天门两国交战，
# 	Closing line: 我的娘押粮草来到北番。
#
#
# 	Couplet 5
# 	Opening line: 我有心回宋营见母一面，
# 	Closing line: 怎奈我身在番难以过关。
#
#
# 	Couplet 6
# 	Opening line: 公主虽然不阻拦，
# 	Closing line: 无有令箭怎过关。
#
#
# 	Couplet 7
# 	Opening line: 公主赠我的金鈚箭，
# 	Closing line: 见母一面即刻还。
#
#
# 	Couplet 8
# 	Opening line: 宋营（哪）虽然路途远，
# 	Closing line: 快马加鞭我一夜还。
#
#
# 	Couplet 9
# 	Opening line: 公主叫我盟誓愿，
# 	Closing line: 将身跪在地平川。
#
#
# 	Couplet 10
# 	Opening line: 我若探母不回转，
# 	Closing line: 黄沙盖脸尸骨不全。
#
#
# 	Couplet 11
# 	Opening line: 讲什么夫妻情恩德不浅，
# 	Closing line: 咱与你隔南北千里姻缘。
#
#
# 	Couplet 12
# 	Opening line: 因何故终日里愁眉不展，
# 	Closing line: 有什么心腹事你只管明言。
#
#
# 	Couplet 13
# 	Opening line: 你那里休得要巧言舌辨，
# 	Closing line: 你要见高堂母我不阻拦。
#
#
# 	Couplet 14
# 	Opening line: 有心赠你金鈚箭，
# 	Closing line: 怕你一去就不回还。
#
#
# 	Couplet 15
# 	Opening line: 宋营离此路途远，
# 	Closing line: 一夜之间你怎能回还。
#
#
# 	Couplet 16
# 	Opening line: 适才叫咱盟誓愿，
# 	Closing line: 你也对苍天就表一番。

# %% [markdown]
# The following cell defines a function that adds the intervals in a score list inputed in the first argument. The type of intervals to be summarized in the score list can be set in the `intervalType` argument.
#
# Since the number of `banshi` in the collection is relatively high (`12`), here the `bashi` are grouped according to their tempo ranges, like this:
# - `yuanban`: `yuanban` and `erliu` - 2/4 metre and medium tempo ranges.
# - `manban`: `manban`, `sanyan`, `zhongsanyan`, `kuaisanyan` - 4/4 metre and slow tempo.
# - `kuaiban`: `kuaiban` and `liushui` - 1/4 metre and fast tempo.

# %%
# summarizing the intervals in a score list
def summarizeIntervals(scoreList, intervalType = 'SS'):
    I = Intervals() # object to store summarized intervals
    
    # banshi groups
    BGs ={'yuanban':'yuanban', 'erliu':'yuanban',
          'manban': 'manban', 'sanyan': 'manban', 'zhongsanyan': 'manban', 'kuaisanyan': 'manban', 
          'kuaiban': 'kuaiban', 'liushui': 'kuaiban',
          'daoban': '', 'sanban': '', 'yaoban':''} 
    
    for score in scoreList:
        if intervalType == 'SS':
            scoreIntervals = score.intervalsSS
        else:
            scoreIntervals = score.intervalsPS
        
        # shengqiang
        for shengqiang, intervals in scoreIntervals.shengqiang.items():
            if I.shengqiang.get(shengqiang) == None: # create shengqiang if not exist
                I.shengqiang[shengqiang] = {} 
            for interval, number in intervals.items():                           
                if I.shengqiang[shengqiang].get(interval) == None: # assign current number if not exist
                    I.shengqiang[shengqiang][interval] = number
                else:
                    I.shengqiang[shengqiang][interval] += number
                    
        # role type
        for roleType, intervals in scoreIntervals.roleType.items():
            if I.roleType.get(roleType) == None: # create roleType if not exist
                I.roleType[roleType] = {} 
            for interval, number in intervals.items():                           
                if I.roleType[roleType].get(interval) == None: # assign current number if not exist
                    I.roleType[roleType][interval] = number
                else:
                    I.roleType[roleType][interval] += number
                               
        # banshi
        for banshi, intervals in scoreIntervals.banshi.items():
            banshiGroup = BGs[banshi]
            if I.banshi.get(banshiGroup) == None: # create banshi if not exist
                I.banshi[banshiGroup] = {} 
            for interval, number in intervals.items():                           
                if I.banshi[banshiGroup].get(interval) == None: # assign current number if not exist
                    I.banshi[banshiGroup][interval] = number
                else:
                    I.banshi[banshiGroup][interval] += number
                    
    return I

# %%
# applying summarizeIntervals functions to the filteredScoreList
ISS = summarizeIntervals(filteredScoreList, intervalType = 'SS')
IPS = summarizeIntervals(filteredScoreList, intervalType = 'PS')

print('Intervals between notes that sound simultaneously\n', ISS, '\n')
print('Intervals between notes that are played simultaneously\n', IPS, '\n')
# Out:
# Intervals between notes that sound simultaneously
#  shengqiang:{'erhuang': {'P8': 3758, 'm7': 545, 'm6': 128, 'P4': 205, 'P1': 4462, 'P5': 215, 'M9': 210, 'm3': 406, 'm10': 103, 'M6': 201, 'M2': 886, 'M7': 8, 'P12': 15, 'P11': 14, 'm2': 41, 'M10': 8, 'M3': 122, 'm9': 11, 'A4': 1, 'M13': 1, 'd5': 1}, 'xipi': {'P8': 1810, 'm7': 198, 'P1': 7099, 'm3': 696, 'M9': 84, 'M2': 909, 'm2': 106, 'P5': 93, 'P4': 237, 'M6': 156, 'm10': 63, 'M3': 112, 'm6': 36, 'P11': 21, 'M7': 7, 'm9': 9, 'd5': 1, 'M10': 4, 'm14': 1, 'P12': 1, 'm13': 1}}, banshi{'manban': {'P8': 3959, 'm7': 496, 'm6': 121, 'P4': 199, 'P1': 4951, 'P5': 199, 'M9': 221, 'm3': 445, 'm10': 116, 'M6': 232, 'M2': 722, 'M7': 11, 'P12': 16, 'P11': 22, 'm2': 56, 'M10': 7, 'M3': 106, 'm9': 13, 'd5': 2, 'A4': 1, 'M13': 1, 'm14': 1, 'm13': 1}, 'yuanban': {'P8': 1284, 'P1': 3696, 'M2': 711, 'M9': 57, 'M6': 91, 'm10': 38, 'm7': 211, 'm6': 34, 'm3': 315, 'P4': 140, 'P5': 88, 'M3': 89, 'm2': 51, 'M10': 3, 'm9': 5, 'P11': 5, 'M7': 3}, 'kuaiban': {'P8': 325, 'm7': 36, 'P1': 2905, 'M2': 355, 'm2': 40, 'm3': 333, 'P4': 99, 'm10': 12, 'P5': 19, 'M3': 39, 'm6': 8, 'M6': 34, 'M10': 2, 'M9': 16, 'm9': 2, 'P11': 8, 'M7': 1}, '': {'m3': 9, 'P4': 4, 'm6': 1, 'M2': 7, 'P5': 2, 'P1': 9}}, roleType{'dan': {'P8': 4609, 'm7': 663, 'm6': 148, 'P4': 206, 'P1': 5191, 'P5': 200, 'M9': 251, 'm3': 494, 'm10': 118, 'M6': 198, 'M2': 632, 'M7': 13, 'P12': 15, 'P11': 14, 'm2': 89, 'M10': 8, 'M3': 64, 'm9': 7, 'd5': 1, 'A4': 1, 'M13': 1}, 'laodan': {'P1': 77, 'P5': 3, 'm3': 9, 'M2': 17, 'P4': 6, 'm2': 1, 'P8': 6, 'M6': 1, 'd5': 1}, 'laosheng': {'P1': 6293, 'm3': 599, 'M2': 1146, 'M6': 158, 'P5': 105, 'P8': 953, 'M3': 170, 'P4': 230, 'm2': 57, 'm7': 80, 'm9': 13, 'm10': 48, 'm6': 16, 'M7': 2, 'P11': 21, 'M10': 4, 'M9': 43, 'm14': 1, 'P12': 1, 'm13': 1}}
#
# Intervals between notes that are played simultaneously
#  shengqiang:{'erhuang': {'P8': 2996, 'P1': 3577, 'P5': 66, 'M7': 4, 'm10': 21, 'P11': 3, 'm2': 25, 'M6': 66, 'M10': 3, 'm7': 98, 'M9': 32, 'm3': 115, 'M3': 52, 'M2': 262, 'P4': 76, 'm6': 18, 'm9': 4, 'd5': 1}, 'xipi': {'P8': 1461, 'm7': 43, 'P1': 6138, 'M9': 18, 'M2': 198, 'm3': 225, 'P4': 49, 'm10': 8, 'P5': 23, 'M3': 29, 'm2': 22, 'm6': 11, 'M6': 40, 'M7': 4, 'P11': 3, 'm9': 1, 'm13': 1}}, banshi{'manban': {'P8': 3102, 'P1': 4029, 'P5': 39, 'M7': 6, 'm10': 17, 'P11': 3, 'm2': 26, 'M6': 61, 'M10': 3, 'm7': 87, 'M9': 28, 'm3': 115, 'M3': 38, 'M2': 181, 'P4': 50, 'm6': 24, 'd5': 1, 'm9': 2, 'm13': 1}, 'yuanban': {'P8': 1072, 'P1': 3002, 'M9': 18, 'm7': 48, 'M2': 203, 'M6': 36, 'm3': 101, 'P5': 34, 'm10': 11, 'P4': 52, 'M3': 32, 'm2': 13, 'P11': 1, 'm9': 2, 'm6': 2, 'M7': 1}, 'kuaiban': {'P8': 283, 'P1': 2677, 'm3': 119, 'M2': 72, 'P4': 21, 'P5': 14, 'm2': 8, 'm6': 2, 'm10': 1, 'm7': 6, 'M6': 9, 'M9': 4, 'm9': 1, 'M3': 11, 'P11': 2, 'M7': 1}, '': {'m3': 5, 'm6': 1, 'M2': 4, 'P5': 2, 'P4': 2, 'P1': 7}}, roleType{'dan': {'P8': 3664, 'P1': 4386, 'P5': 45, 'M7': 7, 'm10': 26, 'P11': 3, 'm2': 27, 'M6': 42, 'M10': 3, 'm7': 106, 'M9': 42, 'm3': 147, 'M3': 21, 'M2': 160, 'P4': 44, 'm6': 18, 'm9': 1}, 'laodan': {'P1': 65, 'm3': 3, 'M2': 4, 'P4': 6, 'm2': 1, 'P8': 4, 'M6': 1, 'd5': 1, 'P5': 1}, 'laosheng': {'P1': 5264, 'M2': 296, 'M6': 63, 'm3': 190, 'P5': 43, 'P8': 789, 'M3': 60, 'm2': 19, 'm7': 35, 'P4': 75, 'm9': 4, 'm6': 11, 'P11': 3, 'M9': 8, 'm10': 3, 'm13': 1, 'M7': 1}}

# %%
# Create a dictionary with the equivalence of each interval's size in semitones and its name.
intervalsOrder = {}
for k in filteredScoreList[0].intervalsSS.shengqiang['erhuang'].keys():
    itv = interval.Interval(k)
    intervalsOrder[itv.semitones] = k
    
# Ordered list of intervals by semitones size
xValues = sorted(intervalsOrder.keys())
# Oredred list of interval names by their semitiones size to be use as ticks for the x axis.
xTicks = [intervalsOrder[i] for i in xValues]
# Ordered list of y axis values
yValues = [filteredScoreList[0].intervalsSS.shengqiang['erhuang'][i] for i in xTicks]

plt.bar(xValues, yValues)
plt.xticks(xValues, xTicks)
plt.show()
